# %%
# !nvidia-cdl
# Out:
# Driver version: 510.85.02
# ------------------- Device 0 -------------------
# Name: NVIDIA GeForce RTX 3090
# Memory usage: 24196MiB / 24576MiB
# Temperature: 67C
# Running processes not found
#
# ------------------- Device 1 -------------------
# Name: NVIDIA GeForce RTX 3090
# Memory usage: 22125MiB / 24576MiB
# Temperature: 68C
# Running processes not found
#
# ------------------- Device 2 -------------------
# Name: NVIDIA GeForce RTX 3090
# Memory usage:  2939MiB / 24576MiB
# Temperature: 40C
# Running processes not found
#
# ------------------- Device 3 -------------------
# Name: NVIDIA GeForce RTX 3090
# Memory usage:  3193MiB / 24576MiB
# Temperature: 28C
# Running processes not found
#
# ------------------- Device 4 -------------------
# Name: NVIDIA GeForce RTX 2080 Ti
# Memory usage:   247MiB / 11264MiB
# Temperature: 35C
# Running processes not found
#
# ------------------- Device 5 -------------------
# Name: NVIDIA GeForce RTX 2080 Ti
# Memory usage:  3668MiB / 11264MiB
# Temperature: 32C
# Running processes not found

# %%
# !pip install -U requests
# !pip install spacy
# !pip install sentencepiece
# !pip install -U transformers
# Out:
# Requirement already satisfied: requests in /home/petrakov/anaconda3/lib/python3.7/site-packages (2.28.0)
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests) (2019.9.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests) (1.24.2)
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.0
#     Uninstalling requests-2.28.0:
#       Successfully uninstalled requests-2.28.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 4.14.0 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# Successfully installed requests-2.28.1
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: spacy in /home/petrakov/anaconda3/lib/python3.7/site-packages (3.3.1)
# Requirement already satisfied: pathy>=0.3.5 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (4.64.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (1.21.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: jinja2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (2.10.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: setuptools in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (41.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (0.9.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (2.4.3)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (4.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (0.7.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from spacy) (8.0.17)
# Requirement already satisfied: zipp>=0.5 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from packaging>=20.0->spacy) (2.4.2)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: importlib-metadata in /home/petrakov/anaconda3/lib/python3.7/site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy) (3.10.1)
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sentencepiece in /home/petrakov/anaconda3/lib/python3.7/site-packages (0.1.95)
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: transformers in /home/petrakov/anaconda3/lib/python3.7/site-packages (4.19.3)
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 16.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tqdm>=4.27 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (4.64.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (5.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 52.8 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (3.10.1)
# Requirement already satisfied: packaging>=20.0 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from packaging>=20.0->transformers) (2.4.2)
# Requirement already satisfied: zipp>=0.5 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests->transformers) (1.24.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/petrakov/anaconda3/lib/python3.7/site-packages (from requests->transformers) (2019.9.11)
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.7.0
#     Uninstalling huggingface-hub-0.7.0:
#       Successfully uninstalled huggingface-hub-0.7.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.19.3
#     Uninstalling transformers-4.19.3:
#       Successfully uninstalled transformers-4.19.3
# Successfully installed huggingface-hub-0.10.1 transformers-4.24.0
#
# [notice] A new release of pip available: 22.1.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import random
import scipy.stats
import math
import torch
from torch import nn
import pandas as pd
import matplotlib.pyplot as plt
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

from tqdm import tqdm
import pickle
from wikidataintegrator import wdi_core
from wikidata.client import Client
import wikidata
from itertools import compress

import en_core_web_sm
import spacy
import warnings
warnings.filterwarnings("ignore")

# spacy.prefer_gpu()
nlp = spacy.load("en_core_web_sm")

#nlp = en_core_web_sm.load()
client = wikidata.client.Client()

# %%
#! wget https://dl.fbaipublicfiles.com/GENRE/lang_title2wikidataID-normalized_with_redirect.pkl
    
with open("lang_title2wikidataID-normalized_with_redirect.pkl", "rb") as f:
    lang_title2wikidataID = pickle.load(f)

# %%
def get_description_name(idd):
    '''
    This function returns a name of an entity and its description given WikiData id
    
        input:  (str) wikidata id, e.x. 'Q2'
        output: (str) concatenated 'name, description' of a given entity
    '''
    entity = client.get(idd, load=True)
    name = "None"
    description = "None"
    try:
        name = entity.data["labels"]["en"]["value"]
        
    except:
        pass
    return name


def text_to_id(x):
    #splits = x.split(" >> ")
    if len(x) > 1:
        return max(lang_title2wikidataID[tuple(reversed(x))], key=lambda y: int(y[1:]))
    else:
        return 'Empty'
    
def from_text_to_id(x):
    return list(lang_title2wikidataID[("en", x)])[0]
    
    
    
### For top k sample
    
def getScores(ids, scores, pad_token_id):
    """get sequence scores from model.generate output"""
    scores = torch.stack(scores, dim=1)
    log_probs = torch.log_softmax(scores, dim=2)
    # remove start token
    ids = ids[:,1:]
    # gather needed probs
    x = ids.unsqueeze(-1).expand(log_probs.shape)
    needed_logits = torch.gather(log_probs, 2, x)
    final_logits = needed_logits[:, :, 0]
    padded_mask = (ids == pad_token_id)
    final_logits[padded_mask] = 0
    final_scores = final_logits.sum(dim=-1)
    return final_scores.cpu().detach().numpy()

def topkSample(input, model, tokenizer, 
                num_samples=5,
                num_beams=1,
                max_output_length=128):
    tokenized = tokenizer(input, return_tensors="pt")
    tokenized.to(device)
    out = model.generate(**tokenized,
                        do_sample=True,
                        num_return_sequences = num_samples,
                        num_beams = num_beams,
                        eos_token_id = tokenizer.eos_token_id,
                        pad_token_id = tokenizer.pad_token_id,
                        output_scores = True,
                        return_dict_in_generate=True,
                        max_length=max_output_length,)
    out_tokens = out.sequences
    out_str = tokenizer.batch_decode(out_tokens, skip_special_tokens=True)
    out_scores = getScores(out_tokens, out.scores, tokenizer.pad_token_id)
    
    pair_list = [(x[0], x[1]) for x in zip(out_str, out_scores)]
    sorted_pair_list = sorted(pair_list, key=lambda x:x[1], reverse=True)
    return sorted_pair_list

def greedyPredict(input, model, tokenizer):
    input_ids = tokenizer([input], return_tensors="pt").input_ids
    out_tokens = model.generate(input_ids)
    out_str = tokenizer.batch_decode(out_tokens, skip_special_tokens=True)
    return out_str[0]


def check_t5_sq(t5_tok, t5_qa_model):
    
    sq_test_data = np.load("simple_questions_test.npy")
    questions = sq_test_data[:,3]


    answers = []
    for i in tqdm(range(len(questions))):
        input_ids = t5_tok(questions[i], return_tensors="pt").input_ids
        input_ids = input_ids.to(device)
        gen_output = t5_qa_model.generate(input_ids)[0]
        answers.append(gen_output)


    preds_sq = []
    for x in answers:
        preds_sq.append(t5_tok.decode(x, skip_special_tokens=True))


    preds_id_sq = []
    for i in range(len(preds_sq)):
        try:
            x = from_text_to_id(preds_sq[i])
        except:
            x = "None"

        preds_id_sq.append(x)

    right_sq = 0
    for i in tqdm(range(len(preds_id_sq))):
        if preds_id_sq[i] == sq_test_data[i,2]:
            right_sq += 1
        else:
            pass

    acc = right_sq/len(preds_id_sq)
    
    return acc, preds_id_sq

softmax = nn.Softmax()

# %%
t5_qa_model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-xl-ssm-nq")
t5_tok = AutoTokenizer.from_pretrained("google/t5-xl-ssm-nq")

# t5_qa_model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-3b-ssm")#"google/t5-11b-ssm-tqa")
# t5_tok = AutoTokenizer.from_pretrained("google/t5-3b-ssm")

device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
t5_qa_model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 2048)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
# ...
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=2048, out_features=32128, bias=False)
# )

# %%
# data
rubq_test = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")
rubq_answers = np.load("all_rubq_test_answers_1_hop_uri.npy", allow_pickle=True)

entities_test_rubq = np.load("entities_test_rubq.npy")
rubq_test_answers = np.load("all_rubq_test_answers_1_hop_uri.npy", allow_pickle=True)
rubq_test = pd.DataFrame({"subject":entities_test_rubq, "question":rubq_test})

# %%
def predict_and_proba(question, model, tokenizer, device, num_beams = 10, max_sequence_length = 32):
    """This function generates sequence = answer on given question
    
    1) it encodes qustion using tokenizer
    2) converts tokenized text to device
    3) generate answer with dredefined beam size using tokenized text
    4) as output we receive answers and their probabilities
    
    """
    
    input_ids = tokenizer([question], return_tensors="pt").input_ids
    input_ids = input_ids.to(device)

    out = model.generate(input_ids,
                         num_return_sequences = num_beams,
                         num_beams = num_beams,
                         eos_token_id = tokenizer.eos_token_id,
                         pad_token_id = tokenizer.pad_token_id,
                         output_scores = True,
                         return_dict_in_generate=True,
                         early_stopping=True,
                         max_length=max_sequence_length)
    
    prediction = [tokenizer.decode(out.sequences[i], skip_special_tokens=True) for i in range(num_beams)]
    probs = softmax(out.sequences_scores)
    
    return prediction, probs


def stable_experiments(seed_num):
    
    torch.manual_seed(seed_num)
    random.seed(seed_num)
    np.random.seed(seed_num)

# %%
def stable_experiments(seed_num):
    
    torch.manual_seed(seed_num)
    random.seed(seed_num)
    np.random.seed(seed_num)

# %%
stable_experiments(42)
sample_questions = len(rubq_test)
three_quest = list(rubq_test.question)[:sample_questions]

# %%
result = [predict_and_proba(three_quest[i], model = t5_qa_model, tokenizer=t5_tok, device=device) for i in range(sample_questions)]

# %%
predictions = [i[0] for i in result]
probas = [i[1] for i in result]
probas = [i.detach().to("cpu") for i in probas]

# %% [markdown]
# # Experiments with uncertainty on a single model (Entropy, Maxprob, Delta)

# %% [markdown]
# # RuBQ 2.0

# %% [markdown]
# ### Entropy

# %%
num_quantiles = 20

quants = [thresh / num_quantiles for thresh in range(1, num_quantiles+1)]
entropies = [scipy.stats.entropy(i) for i in probas]
thresholds_entropy = [np.quantile(entropies, q) for q in quants]

accuracy_for_each_topk_entropy = []

#top_k pred
for top_k in [1, 2, 5, 10]:
    
    accuracy_for_each_quantile = {}

    for quantile in range(num_quantiles):

        # list of predictions
        list_of_predictions = list(compress(predictions, entropies <= thresholds_entropy[quantile]))
        
        #list of correct answers
        list_of_correct_answers = list(compress(rubq_test_answers[:sample_questions], entropies <= thresholds_entropy[quantile]))
        
        # choose top k predictions
        top_k_list_of_predictions = [i[:top_k] for i in list_of_predictions]

        top_k_list_of_predicted_ids= []
        for sample in top_k_list_of_predictions:
            new = []
            for prediction in sample:
                try:
                    x = from_text_to_id(prediction)
                except:
                    x = "None"
                new.append(x)

            top_k_list_of_predicted_ids.append(new)


        right = 0
        for i in range(len(list_of_correct_answers)):
            if any(item in top_k_list_of_predicted_ids[i] for item in list_of_correct_answers[i]):
                right += 1
            else:
                pass

        accuracy = np.round(right/len(list_of_correct_answers), 4)*100
        print(f"Top-{top_k} accuracy on the {(quantile+1)*(int(100/num_quantiles))}% the most confident from the entropy point of view = {accuracy}%")

        accuracy_for_each_quantile[(quantile+1)*(int(100/num_quantiles))] = accuracy
        accuracy_for_each_topk_entropy.append(accuracy_for_each_quantile)
        
    print("\n")
# Out:
# Top-1 accuracy on the 5% the most confident from the entropy point of view = 76.67%
# Top-1 accuracy on the 10% the most confident from the entropy point of view = 71.43%
# Top-1 accuracy on the 15% the most confident from the entropy point of view = 69.1%
# Top-1 accuracy on the 20% the most confident from the entropy point of view = 69.33%
# Top-1 accuracy on the 25% the most confident from the entropy point of view = 70.03%
# Top-1 accuracy on the 30% the most confident from the entropy point of view = 66.29%
# Top-1 accuracy on the 35% the most confident from the entropy point of view = 64.1%
# Top-1 accuracy on the 40% the most confident from the entropy point of view = 61.050000000000004%
# Top-1 accuracy on the 45% the most confident from the entropy point of view = 57.489999999999995%
# Top-1 accuracy on the 50% the most confident from the entropy point of view = 53.790000000000006%
# Top-1 accuracy on the 55% the most confident from the entropy point of view = 50.61%
# Top-1 accuracy on the 60% the most confident from the entropy point of view = 47.89%
# Top-1 accuracy on the 65% the most confident from the entropy point of view = 45.65%
# Top-1 accuracy on the 70% the most confident from the entropy point of view = 43.49%
# Top-1 accuracy on the 75% the most confident from the entropy point of view = 41.06%
# Top-1 accuracy on the 80% the most confident from the entropy point of view = 39.2%
# Top-1 accuracy on the 85% the most confident from the entropy point of view = 37.7%
# Top-1 accuracy on the 90% the most confident from the entropy point of view = 36.18%
# Top-1 accuracy on the 95% the most confident from the entropy point of view = 34.55%
# Top-1 accuracy on the 100% the most confident from the entropy point of view = 32.800000000000004%
#
#
# Top-2 accuracy on the 5% the most confident from the entropy point of view = 78.33%
# Top-2 accuracy on the 10% the most confident from the entropy point of view = 73.95%
# Top-2 accuracy on the 15% the most confident from the entropy point of view = 71.35000000000001%
# Top-2 accuracy on the 20% the most confident from the entropy point of view = 71.43%
# Top-2 accuracy on the 25% the most confident from the entropy point of view = 73.4%
# Top-2 accuracy on the 30% the most confident from the entropy point of view = 70.78999999999999%
# Top-2 accuracy on the 35% the most confident from the entropy point of view = 67.95%
# Top-2 accuracy on the 40% the most confident from the entropy point of view = 66.95%
# Top-2 accuracy on the 45% the most confident from the entropy point of view = 64.03999999999999%
# Top-2 accuracy on the 50% the most confident from the entropy point of view = 60.540000000000006%
# Top-2 accuracy on the 55% the most confident from the entropy point of view = 56.89999999999999%
# Top-2 accuracy on the 60% the most confident from the entropy point of view = 54.49%
# Top-2 accuracy on the 65% the most confident from the entropy point of view = 52.14%
# Top-2 accuracy on the 70% the most confident from the entropy point of view = 50.0%
# Top-2 accuracy on the 75% the most confident from the entropy point of view = 47.58%
# Top-2 accuracy on the 80% the most confident from the entropy point of view = 45.519999999999996%
# Top-2 accuracy on the 85% the most confident from the entropy point of view = 43.85%
# Top-2 accuracy on the 90% the most confident from the entropy point of view = 41.99%
# Top-2 accuracy on the 95% the most confident from the entropy point of view = 40.050000000000004%
# Top-2 accuracy on the 100% the most confident from the entropy point of view = 38.03%
#
#
# Top-5 accuracy on the 5% the most confident from the entropy point of view = 78.33%
# Top-5 accuracy on the 10% the most confident from the entropy point of view = 76.47%
# Top-5 accuracy on the 15% the most confident from the entropy point of view = 74.72%
# Top-5 accuracy on the 20% the most confident from the entropy point of view = 75.63%
# Top-5 accuracy on the 25% the most confident from the entropy point of view = 77.78%
# Top-5 accuracy on the 30% the most confident from the entropy point of view = 75.0%
# Top-5 accuracy on the 35% the most confident from the entropy point of view = 72.77%
# Top-5 accuracy on the 40% the most confident from the entropy point of view = 72.21%
# Top-5 accuracy on the 45% the most confident from the entropy point of view = 70.22%
# Top-5 accuracy on the 50% the most confident from the entropy point of view = 66.95%
# Top-5 accuracy on the 55% the most confident from the entropy point of view = 63.800000000000004%
# Top-5 accuracy on the 60% the most confident from the entropy point of view = 61.38%
# Top-5 accuracy on the 65% the most confident from the entropy point of view = 58.75%
# Top-5 accuracy on the 70% the most confident from the entropy point of view = 56.75%
# Top-5 accuracy on the 75% the most confident from the entropy point of view = 54.779999999999994%
# Top-5 accuracy on the 80% the most confident from the entropy point of view = 52.690000000000005%
# Top-5 accuracy on the 85% the most confident from the entropy point of view = 50.79%
# Top-5 accuracy on the 90% the most confident from the entropy point of view = 48.64%
# Top-5 accuracy on the 95% the most confident from the entropy point of view = 46.54%
# Top-5 accuracy on the 100% the most confident from the entropy point of view = 44.269999999999996%
#
#
# Top-10 accuracy on the 5% the most confident from the entropy point of view = 83.33%
# Top-10 accuracy on the 10% the most confident from the entropy point of view = 82.35%
# Top-10 accuracy on the 15% the most confident from the entropy point of view = 80.9%
# Top-10 accuracy on the 20% the most confident from the entropy point of view = 81.51%
# Top-10 accuracy on the 25% the most confident from the entropy point of view = 82.49%
# Top-10 accuracy on the 30% the most confident from the entropy point of view = 80.06%
# Top-10 accuracy on the 35% the most confident from the entropy point of view = 78.07%
# Top-10 accuracy on the 40% the most confident from the entropy point of view = 77.25999999999999%
# Top-10 accuracy on the 45% the most confident from the entropy point of view = 75.47%
# Top-10 accuracy on the 50% the most confident from the entropy point of view = 72.18%
# Top-10 accuracy on the 55% the most confident from the entropy point of view = 68.87%
# Top-10 accuracy on the 60% the most confident from the entropy point of view = 66.99000000000001%
# Top-10 accuracy on the 65% the most confident from the entropy point of view = 64.59%
# Top-10 accuracy on the 70% the most confident from the entropy point of view = 62.41%
# Top-10 accuracy on the 75% the most confident from the entropy point of view = 60.519999999999996%
# Top-10 accuracy on the 80% the most confident from the entropy point of view = 58.269999999999996%
# Top-10 accuracy on the 85% the most confident from the entropy point of view = 56.45%
# Top-10 accuracy on the 90% the most confident from the entropy point of view = 54.36%
# Top-10 accuracy on the 95% the most confident from the entropy point of view = 52.22%
# Top-10 accuracy on the 100% the most confident from the entropy point of view = 49.75%

# %%
font = {'family': 'serif',
            'color': 'darkred',
            'weight': 'normal',
            'size': 16
            }

font_title = {'family': 'serif',
              'color': 'darkred',
              'weight': 'normal',
              'size': 20
              }

plt.figure(figsize = (15, 9))
plt.title("Rejection curves based on Entropy for test set RuBQ 2.0 (1186 questions)", fontdict=font_title)

plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Entropy", c="blue", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Entropy", c="red", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Entropy", c="green", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Entropy", c="orange", marker='.', markersize=13, linewidth=0.8);


accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_Entropy_for_test_set_RuBQ_2_0_1186_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# # Maxprob

# %%
num_quantiles = 20

quants = [thresh / num_quantiles for thresh in range(0, num_quantiles)]
max_probs = [i[0] for i in probas]
thresholds_maxprob = [np.quantile(max_probs, q) for q in quants]
thresholds_maxprob = thresholds_maxprob[::-1]

accuracy_for_each_topk_maxprob = []

#top_k pred
for top_k in [1, 2, 5, 10]:
    
    accuracy_for_each_quantile = {}

    for quantile in range(num_quantiles):

        # list of predictions
        list_of_predictions = list(compress(predictions, max_probs >= thresholds_maxprob[quantile]))
        #print("len(list_of_predictions)", len(list_of_predictions))
        
        #list of correct answers
        list_of_correct_answers = list(compress(rubq_test_answers[:sample_questions], max_probs >= thresholds_maxprob[quantile]))
        
        #print("list_of_correct_answers", list_of_correct_answers)
        
        # choose top k predictions
        top_k_list_of_predictions = [i[:top_k] for i in list_of_predictions]

        top_k_list_of_predicted_ids= []
        for sample in top_k_list_of_predictions:
            new = []
            for prediction in sample:
                try:
                    x = from_text_to_id(prediction)
                except:
                    x = "None"
                new.append(x)

            top_k_list_of_predicted_ids.append(new)

        #print("top_k_list_of_predicted_ids", top_k_list_of_predicted_ids)
        right = 0
        for i in range(len(list_of_correct_answers)):
            if any(item in top_k_list_of_predicted_ids[i] for item in list_of_correct_answers[i]):
                right += 1
            else:
                pass

        accuracy = np.round(right/len(list_of_correct_answers), 4)*100
        print(f"Top-{top_k} accuracy on the {(quantile+1)*(int(100/num_quantiles))}% the most confident from the Maxprob point of view = {accuracy}%")

        accuracy_for_each_quantile[(quantile+1)*(int(100/num_quantiles))] = accuracy
        accuracy_for_each_topk_maxprob.append(accuracy_for_each_quantile)
        
    print("\n")
# Out:
# Top-1 accuracy on the 5% the most confident from the Maxprob point of view = 76.67%
# Top-1 accuracy on the 10% the most confident from the Maxprob point of view = 73.11%
# Top-1 accuracy on the 15% the most confident from the Maxprob point of view = 71.91%
# Top-1 accuracy on the 20% the most confident from the Maxprob point of view = 69.33%
# Top-1 accuracy on the 25% the most confident from the Maxprob point of view = 69.02000000000001%
# Top-1 accuracy on the 30% the most confident from the Maxprob point of view = 68.54%
# Top-1 accuracy on the 35% the most confident from the Maxprob point of view = 64.34%
# Top-1 accuracy on the 40% the most confident from the Maxprob point of view = 60.629999999999995%
# Top-1 accuracy on the 45% the most confident from the Maxprob point of view = 56.93%
# Top-1 accuracy on the 50% the most confident from the Maxprob point of view = 53.959999999999994%
# Top-1 accuracy on the 55% the most confident from the Maxprob point of view = 50.92%
# Top-1 accuracy on the 60% the most confident from the Maxprob point of view = 49.02%
# Top-1 accuracy on the 65% the most confident from the Maxprob point of view = 46.82%
# Top-1 accuracy on the 70% the most confident from the Maxprob point of view = 44.46%
# Top-1 accuracy on the 75% the most confident from the Maxprob point of view = 41.959999999999994%
# Top-1 accuracy on the 80% the most confident from the Maxprob point of view = 39.519999999999996%
# Top-1 accuracy on the 85% the most confident from the Maxprob point of view = 37.7%
# Top-1 accuracy on the 90% the most confident from the Maxprob point of view = 36.18%
# Top-1 accuracy on the 95% the most confident from the Maxprob point of view = 34.55%
# Top-1 accuracy on the 100% the most confident from the Maxprob point of view = 32.800000000000004%
#
#
# Top-2 accuracy on the 5% the most confident from the Maxprob point of view = 78.33%
# Top-2 accuracy on the 10% the most confident from the Maxprob point of view = 74.79%
# Top-2 accuracy on the 15% the most confident from the Maxprob point of view = 74.16%
# Top-2 accuracy on the 20% the most confident from the Maxprob point of view = 71.43%
# Top-2 accuracy on the 25% the most confident from the Maxprob point of view = 72.05%
# Top-2 accuracy on the 30% the most confident from the Maxprob point of view = 71.63000000000001%
# Top-2 accuracy on the 35% the most confident from the Maxprob point of view = 68.67%
# Top-2 accuracy on the 40% the most confident from the Maxprob point of view = 65.68%
# Top-2 accuracy on the 45% the most confident from the Maxprob point of view = 63.3%
# Top-2 accuracy on the 50% the most confident from the Maxprob point of view = 60.029999999999994%
# Top-2 accuracy on the 55% the most confident from the Maxprob point of view = 56.89999999999999%
# Top-2 accuracy on the 60% the most confident from the Maxprob point of view = 55.059999999999995%
# Top-2 accuracy on the 65% the most confident from the Maxprob point of view = 52.66%
# Top-2 accuracy on the 70% the most confident from the Maxprob point of view = 50.12%
# Top-2 accuracy on the 75% the most confident from the Maxprob point of view = 47.81%
# Top-2 accuracy on the 80% the most confident from the Maxprob point of view = 45.629999999999995%
# Top-2 accuracy on the 85% the most confident from the Maxprob point of view = 43.75%
# Top-2 accuracy on the 90% the most confident from the Maxprob point of view = 41.99%
# Top-2 accuracy on the 95% the most confident from the Maxprob point of view = 40.050000000000004%
# Top-2 accuracy on the 100% the most confident from the Maxprob point of view = 38.03%
#
#
# Top-5 accuracy on the 5% the most confident from the Maxprob point of view = 78.33%
# Top-5 accuracy on the 10% the most confident from the Maxprob point of view = 77.31%
# Top-5 accuracy on the 15% the most confident from the Maxprob point of view = 76.97%
# Top-5 accuracy on the 20% the most confident from the Maxprob point of view = 75.63%
# Top-5 accuracy on the 25% the most confident from the Maxprob point of view = 76.77000000000001%
# Top-5 accuracy on the 30% the most confident from the Maxprob point of view = 76.12%
# Top-5 accuracy on the 35% the most confident from the Maxprob point of view = 73.25%
# Top-5 accuracy on the 40% the most confident from the Maxprob point of view = 70.53%
# Top-5 accuracy on the 45% the most confident from the Maxprob point of view = 68.16%
# Top-5 accuracy on the 50% the most confident from the Maxprob point of view = 65.09%
# Top-5 accuracy on the 55% the most confident from the Maxprob point of view = 62.419999999999995%
# Top-5 accuracy on the 60% the most confident from the Maxprob point of view = 60.67%
# Top-5 accuracy on the 65% the most confident from the Maxprob point of view = 59.01%
# Top-5 accuracy on the 70% the most confident from the Maxprob point of view = 56.63%
# Top-5 accuracy on the 75% the most confident from the Maxprob point of view = 54.669999999999995%
# Top-5 accuracy on the 80% the most confident from the Maxprob point of view = 52.900000000000006%
# Top-5 accuracy on the 85% the most confident from the Maxprob point of view = 50.690000000000005%
# Top-5 accuracy on the 90% the most confident from the Maxprob point of view = 48.55%
# Top-5 accuracy on the 95% the most confident from the Maxprob point of view = 46.45%
# Top-5 accuracy on the 100% the most confident from the Maxprob point of view = 44.269999999999996%
#
#
# Top-10 accuracy on the 5% the most confident from the Maxprob point of view = 83.33%
# Top-10 accuracy on the 10% the most confident from the Maxprob point of view = 82.35%
# Top-10 accuracy on the 15% the most confident from the Maxprob point of view = 81.46%
# Top-10 accuracy on the 20% the most confident from the Maxprob point of view = 81.51%
# Top-10 accuracy on the 25% the most confident from the Maxprob point of view = 81.47999999999999%
# Top-10 accuracy on the 30% the most confident from the Maxprob point of view = 81.17999999999999%
# Top-10 accuracy on the 35% the most confident from the Maxprob point of view = 77.83%
# Top-10 accuracy on the 40% the most confident from the Maxprob point of view = 75.58%
# Top-10 accuracy on the 45% the most confident from the Maxprob point of view = 73.41%
# Top-10 accuracy on the 50% the most confident from the Maxprob point of view = 70.32000000000001%
# Top-10 accuracy on the 55% the most confident from the Maxprob point of view = 67.47999999999999%
# Top-10 accuracy on the 60% the most confident from the Maxprob point of view = 66.14999999999999%
# Top-10 accuracy on the 65% the most confident from the Maxprob point of view = 64.72%
# Top-10 accuracy on the 70% the most confident from the Maxprob point of view = 62.29%
# Top-10 accuracy on the 75% the most confident from the Maxprob point of view = 60.519999999999996%
# Top-10 accuracy on the 80% the most confident from the Maxprob point of view = 58.69%
# Top-10 accuracy on the 85% the most confident from the Maxprob point of view = 56.45%
# Top-10 accuracy on the 90% the most confident from the Maxprob point of view = 54.26%
# Top-10 accuracy on the 95% the most confident from the Maxprob point of view = 52.129999999999995%
# Top-10 accuracy on the 100% the most confident from the Maxprob point of view = 49.75%

# %%
plt.figure(figsize = (15, 9))
plt.title("Rejection curves based on Maxprob for test set RuBQ 2.0 (1186 questions)", fontdict=font_title)
plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Maxprob", c="blue", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Maxprob", c="red", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Maxprob", c="green", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Maxprob", c="orange", marker='.', markersize=13, linewidth=0.8);


accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_Maxprob_for_test_set_RuBQ_2_0_1186_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# # Delta

# %%
num_quantiles = 20

quants = [thresh / num_quantiles for thresh in range(0, num_quantiles)]
deltas = [i[0] - i[1] for i in probas]
thresholds_delta = [np.quantile(deltas, q) for q in quants]
thresholds_delta = thresholds_delta[::-1]

accuracy_for_each_topk_delta = []

#top_k pred
for top_k in [1, 2, 5, 10]:
    
    accuracy_for_each_quantile = {}

    for quantile in range(num_quantiles):

        # list of predictions
        list_of_predictions = list(compress(predictions, deltas >= thresholds_delta[quantile]))
        print("len(list_of_predictions)", len(list_of_predictions))
        
        #print("list_of_predictions", list_of_predictions)
        
        #list of correct answers
        list_of_correct_answers = list(compress(rubq_test_answers[:sample_questions], deltas >= thresholds_delta[quantile]))
        print("len(list_of_correct_answers)", len(list_of_correct_answers))
        
        # choose top k predictions
        top_k_list_of_predictions = [i[:top_k] for i in list_of_predictions]
        
        top_k_list_of_predicted_ids= []
        for sample in top_k_list_of_predictions:
            new = []
            for prediction in sample:
                try:
                    x = from_text_to_id(prediction)
                except:
                    x = "None"
                new.append(x)

            top_k_list_of_predicted_ids.append(new)
        
        print("len(top_k_list_of_predicted_ids)", len(top_k_list_of_predicted_ids))

        right = 0
        for i in range(len(list_of_correct_answers)):
            if any(item in top_k_list_of_predicted_ids[i] for item in list_of_correct_answers[i]):
                right += 1
            else:
                pass

        accuracy = np.round(right/len(list_of_correct_answers), 4)*100
        print(f"Top-{top_k} accuracy on the {(quantile+1)*(int(100/num_quantiles))}% the most confident from the Delta point of view = {accuracy}%")

        accuracy_for_each_quantile[(quantile+1)*(int(100/num_quantiles))] = accuracy
        accuracy_for_each_topk_delta.append(accuracy_for_each_quantile)
        
    print("\n")
# Out:
# len(list_of_predictions) 60
# len(list_of_correct_answers) 60
# len(top_k_list_of_predicted_ids) 60
# Top-1 accuracy on the 5% the most confident from the Delta point of view = 80.0%
# len(list_of_predictions) 119
# len(list_of_correct_answers) 119
# len(top_k_list_of_predicted_ids) 119
# Top-1 accuracy on the 10% the most confident from the Delta point of view = 73.11%
# len(list_of_predictions) 178
# len(list_of_correct_answers) 178
# len(top_k_list_of_predicted_ids) 178
# Top-1 accuracy on the 15% the most confident from the Delta point of view = 71.91%
# len(list_of_predictions) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-1 accuracy on the 20% the most confident from the Delta point of view = 71.43%
# len(list_of_predictions) 297
# len(list_of_correct_answers) 297
# len(top_k_list_of_predicted_ids) 297
# Top-1 accuracy on the 25% the most confident from the Delta point of view = 70.71%
# len(list_of_predictions) 356
# len(list_of_correct_answers) 356
# len(top_k_list_of_predicted_ids) 356
# Top-1 accuracy on the 30% the most confident from the Delta point of view = 68.82000000000001%
# len(list_of_predictions) 415
# len(list_of_correct_answers) 415
# len(top_k_list_of_predicted_ids) 415
# Top-1 accuracy on the 35% the most confident from the Delta point of view = 63.129999999999995%
# len(list_of_predictions) 475
# len(list_of_correct_answers) 475
# len(top_k_list_of_predicted_ids) 475
# Top-1 accuracy on the 40% the most confident from the Delta point of view = 59.37%
# len(list_of_predictions) 534
# len(list_of_correct_answers) 534
# len(top_k_list_of_predicted_ids) 534
# Top-1 accuracy on the 45% the most confident from the Delta point of view = 56.18%
# len(list_of_predictions) 593
# len(list_of_correct_answers) 593
# len(top_k_list_of_predicted_ids) 593
# Top-1 accuracy on the 50% the most confident from the Delta point of view = 54.300000000000004%
# len(list_of_predictions) 652
# len(list_of_correct_answers) 652
# len(top_k_list_of_predicted_ids) 652
# Top-1 accuracy on the 55% the most confident from the Delta point of view = 50.61%
# len(list_of_predictions) 712
# len(list_of_correct_answers) 712
# len(top_k_list_of_predicted_ids) 712
# Top-1 accuracy on the 60% the most confident from the Delta point of view = 48.309999999999995%
# len(list_of_predictions) 771
# len(list_of_correct_answers) 771
# len(top_k_list_of_predicted_ids) 771
# Top-1 accuracy on the 65% the most confident from the Delta point of view = 45.910000000000004%
# len(list_of_predictions) 830
# len(list_of_correct_answers) 830
# len(top_k_list_of_predicted_ids) 830
# Top-1 accuracy on the 70% the most confident from the Delta point of view = 43.49%
# len(list_of_predictions) 889
# len(list_of_correct_answers) 889
# len(top_k_list_of_predicted_ids) 889
# Top-1 accuracy on the 75% the most confident from the Delta point of view = 41.730000000000004%
# len(list_of_predictions) 949
# len(list_of_correct_answers) 949
# len(top_k_list_of_predicted_ids) 949
# Top-1 accuracy on the 80% the most confident from the Delta point of view = 39.73%
# len(list_of_predictions) 1008
# len(list_of_correct_answers) 1008
# len(top_k_list_of_predicted_ids) 1008
# Top-1 accuracy on the 85% the most confident from the Delta point of view = 37.6%
# len(list_of_predictions) 1067
# len(list_of_correct_answers) 1067
# len(top_k_list_of_predicted_ids) 1067
# Top-1 accuracy on the 90% the most confident from the Delta point of view = 36.18%
# len(list_of_predictions) 1126
# len(list_of_correct_answers) 1126
# len(top_k_list_of_predicted_ids) 1126
# Top-1 accuracy on the 95% the most confident from the Delta point of view = 34.55%
# len(list_of_predictions) 1186
# len(list_of_correct_answers) 1186
# len(top_k_list_of_predicted_ids) 1186
# Top-1 accuracy on the 100% the most confident from the Delta point of view = 32.800000000000004%
#
#
# len(list_of_predictions) 60
# len(list_of_correct_answers) 60
# len(top_k_list_of_predicted_ids) 60
# Top-2 accuracy on the 5% the most confident from the Delta point of view = 81.67%
# len(list_of_predictions) 119
# len(list_of_correct_answers) 119
# len(top_k_list_of_predicted_ids) 119
# Top-2 accuracy on the 10% the most confident from the Delta point of view = 74.79%
# len(list_of_predictions) 178
# len(list_of_correct_answers) 178
# len(top_k_list_of_predicted_ids) 178
# Top-2 accuracy on the 15% the most confident from the Delta point of view = 74.16%
# len(list_of_predictions) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-2 accuracy on the 20% the most confident from the Delta point of view = 73.53%
# len(list_of_predictions) 297
# len(list_of_correct_answers) 297
# len(top_k_list_of_predicted_ids) 297
# Top-2 accuracy on the 25% the most confident from the Delta point of view = 73.4%
# len(list_of_predictions) 356
# len(list_of_correct_answers) 356
# len(top_k_list_of_predicted_ids) 356
# Top-2 accuracy on the 30% the most confident from the Delta point of view = 71.35000000000001%
# len(list_of_predictions) 415
# len(list_of_correct_answers) 415
# len(top_k_list_of_predicted_ids) 415
# Top-2 accuracy on the 35% the most confident from the Delta point of view = 67.23%
# len(list_of_predictions) 475
# len(list_of_correct_answers) 475
# len(top_k_list_of_predicted_ids) 475
# Top-2 accuracy on the 40% the most confident from the Delta point of view = 64.21%
# len(list_of_predictions) 534
# len(list_of_correct_answers) 534
# len(top_k_list_of_predicted_ids) 534
# Top-2 accuracy on the 45% the most confident from the Delta point of view = 61.419999999999995%
# len(list_of_predictions) 593
# len(list_of_correct_answers) 593
# len(top_k_list_of_predicted_ids) 593
# Top-2 accuracy on the 50% the most confident from the Delta point of view = 59.36%
# len(list_of_predictions) 652
# len(list_of_correct_answers) 652
# len(top_k_list_of_predicted_ids) 652
# Top-2 accuracy on the 55% the most confident from the Delta point of view = 55.669999999999995%
# len(list_of_predictions) 712
# len(list_of_correct_answers) 712
# len(top_k_list_of_predicted_ids) 712
# Top-2 accuracy on the 60% the most confident from the Delta point of view = 53.65%
# len(list_of_predictions) 771
# len(list_of_correct_answers) 771
# len(top_k_list_of_predicted_ids) 771
# Top-2 accuracy on the 65% the most confident from the Delta point of view = 50.970000000000006%
# len(list_of_predictions) 830
# len(list_of_correct_answers) 830
# len(top_k_list_of_predicted_ids) 830
# Top-2 accuracy on the 70% the most confident from the Delta point of view = 48.43%
# len(list_of_predictions) 889
# len(list_of_correct_answers) 889
# len(top_k_list_of_predicted_ids) 889
# Top-2 accuracy on the 75% the most confident from the Delta point of view = 46.57%
# len(list_of_predictions) 949
# len(list_of_correct_answers) 949
# len(top_k_list_of_predicted_ids) 949
# Top-2 accuracy on the 80% the most confident from the Delta point of view = 44.89%
# len(list_of_predictions) 1008
# len(list_of_correct_answers) 1008
# len(top_k_list_of_predicted_ids) 1008
# Top-2 accuracy on the 85% the most confident from the Delta point of view = 42.86%
# len(list_of_predictions) 1067
# len(list_of_correct_answers) 1067
# len(top_k_list_of_predicted_ids) 1067
# Top-2 accuracy on the 90% the most confident from the Delta point of view = 41.33%
# len(list_of_predictions) 1126
# len(list_of_correct_answers) 1126
# len(top_k_list_of_predicted_ids) 1126
# Top-2 accuracy on the 95% the most confident from the Delta point of view = 39.879999999999995%
# len(list_of_predictions) 1186
# len(list_of_correct_answers) 1186
# len(top_k_list_of_predicted_ids) 1186
# Top-2 accuracy on the 100% the most confident from the Delta point of view = 38.03%
#
#
# len(list_of_predictions) 60
# len(list_of_correct_answers) 60
# len(top_k_list_of_predicted_ids) 60
# Top-5 accuracy on the 5% the most confident from the Delta point of view = 81.67%
# len(list_of_predictions) 119
# len(list_of_correct_answers) 119
# len(top_k_list_of_predicted_ids) 119
# Top-5 accuracy on the 10% the most confident from the Delta point of view = 78.14999999999999%
# len(list_of_predictions) 178
# len(list_of_correct_answers) 178
# len(top_k_list_of_predicted_ids) 178
# Top-5 accuracy on the 15% the most confident from the Delta point of view = 76.97%
# len(list_of_predictions) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-5 accuracy on the 20% the most confident from the Delta point of view = 76.89%
# len(list_of_predictions) 297
# len(list_of_correct_answers) 297
# len(top_k_list_of_predicted_ids) 297
# Top-5 accuracy on the 25% the most confident from the Delta point of view = 78.11%
# len(list_of_predictions) 356
# len(list_of_correct_answers) 356
# len(top_k_list_of_predicted_ids) 356
# Top-5 accuracy on the 30% the most confident from the Delta point of view = 75.84%
# len(list_of_predictions) 415
# len(list_of_correct_answers) 415
# len(top_k_list_of_predicted_ids) 415
# Top-5 accuracy on the 35% the most confident from the Delta point of view = 71.81%
# len(list_of_predictions) 475
# len(list_of_correct_answers) 475
# len(top_k_list_of_predicted_ids) 475
# Top-5 accuracy on the 40% the most confident from the Delta point of view = 69.47%
# len(list_of_predictions) 534
# len(list_of_correct_answers) 534
# len(top_k_list_of_predicted_ids) 534
# Top-5 accuracy on the 45% the most confident from the Delta point of view = 66.47999999999999%
# len(list_of_predictions) 593
# len(list_of_correct_answers) 593
# len(top_k_list_of_predicted_ids) 593
# Top-5 accuracy on the 50% the most confident from the Delta point of view = 64.25%
# len(list_of_predictions) 652
# len(list_of_correct_answers) 652
# len(top_k_list_of_predicted_ids) 652
# Top-5 accuracy on the 55% the most confident from the Delta point of view = 60.42999999999999%
# len(list_of_predictions) 712
# len(list_of_correct_answers) 712
# len(top_k_list_of_predicted_ids) 712
# Top-5 accuracy on the 60% the most confident from the Delta point of view = 58.57%
# len(list_of_predictions) 771
# len(list_of_correct_answers) 771
# len(top_k_list_of_predicted_ids) 771
# Top-5 accuracy on the 65% the most confident from the Delta point of view = 56.42%
# len(list_of_predictions) 830
# len(list_of_correct_answers) 830
# len(top_k_list_of_predicted_ids) 830
# Top-5 accuracy on the 70% the most confident from the Delta point of view = 54.339999999999996%
# len(list_of_predictions) 889
# len(list_of_correct_answers) 889
# len(top_k_list_of_predicted_ids) 889
# Top-5 accuracy on the 75% the most confident from the Delta point of view = 52.080000000000005%
# len(list_of_predictions) 949
# len(list_of_correct_answers) 949
# len(top_k_list_of_predicted_ids) 949
# Top-5 accuracy on the 80% the most confident from the Delta point of view = 50.68%
# len(list_of_predictions) 1008
# len(list_of_correct_answers) 1008
# len(top_k_list_of_predicted_ids) 1008
# Top-5 accuracy on the 85% the most confident from the Delta point of view = 48.91%
# len(list_of_predictions) 1067
# len(list_of_correct_answers) 1067
# len(top_k_list_of_predicted_ids) 1067
# Top-5 accuracy on the 90% the most confident from the Delta point of view = 47.42%
# len(list_of_predictions) 1126
# len(list_of_correct_answers) 1126
# len(top_k_list_of_predicted_ids) 1126
# Top-5 accuracy on the 95% the most confident from the Delta point of view = 45.910000000000004%
# len(list_of_predictions) 1186
# len(list_of_correct_answers) 1186
# len(top_k_list_of_predicted_ids) 1186
# Top-5 accuracy on the 100% the most confident from the Delta point of view = 44.269999999999996%
#
#
# len(list_of_predictions) 60
# len(list_of_correct_answers) 60
# len(top_k_list_of_predicted_ids) 60
# Top-10 accuracy on the 5% the most confident from the Delta point of view = 83.33%
# len(list_of_predictions) 119
# len(list_of_correct_answers) 119
# len(top_k_list_of_predicted_ids) 119
# Top-10 accuracy on the 10% the most confident from the Delta point of view = 83.19%
# len(list_of_predictions) 178
# len(list_of_correct_answers) 178
# len(top_k_list_of_predicted_ids) 178
# Top-10 accuracy on the 15% the most confident from the Delta point of view = 81.46%
# len(list_of_predictions) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-10 accuracy on the 20% the most confident from the Delta point of view = 81.93%
# len(list_of_predictions) 297
# len(list_of_correct_answers) 297
# len(top_k_list_of_predicted_ids) 297
# Top-10 accuracy on the 25% the most confident from the Delta point of view = 82.15%
# len(list_of_predictions) 356
# len(list_of_correct_answers) 356
# len(top_k_list_of_predicted_ids) 356
# Top-10 accuracy on the 30% the most confident from the Delta point of view = 80.9%
# len(list_of_predictions) 415
# len(list_of_correct_answers) 415
# len(top_k_list_of_predicted_ids) 415
# Top-10 accuracy on the 35% the most confident from the Delta point of view = 76.87%
# len(list_of_predictions) 475
# len(list_of_correct_answers) 475
# len(top_k_list_of_predicted_ids) 475
# Top-10 accuracy on the 40% the most confident from the Delta point of view = 74.11%
# len(list_of_predictions) 534
# len(list_of_correct_answers) 534
# len(top_k_list_of_predicted_ids) 534
# Top-10 accuracy on the 45% the most confident from the Delta point of view = 71.35000000000001%
# len(list_of_predictions) 593
# len(list_of_correct_answers) 593
# len(top_k_list_of_predicted_ids) 593
# Top-10 accuracy on the 50% the most confident from the Delta point of view = 68.97%
# len(list_of_predictions) 652
# len(list_of_correct_answers) 652
# len(top_k_list_of_predicted_ids) 652
# Top-10 accuracy on the 55% the most confident from the Delta point of view = 66.10000000000001%
# len(list_of_predictions) 712
# len(list_of_correct_answers) 712
# len(top_k_list_of_predicted_ids) 712
# Top-10 accuracy on the 60% the most confident from the Delta point of view = 64.61%
# len(list_of_predictions) 771
# len(list_of_correct_answers) 771
# len(top_k_list_of_predicted_ids) 771
# Top-10 accuracy on the 65% the most confident from the Delta point of view = 62.39%
# len(list_of_predictions) 830
# len(list_of_correct_answers) 830
# len(top_k_list_of_predicted_ids) 830
# Top-10 accuracy on the 70% the most confident from the Delta point of view = 60.24%
# len(list_of_predictions) 889
# len(list_of_correct_answers) 889
# len(top_k_list_of_predicted_ids) 889
# Top-10 accuracy on the 75% the most confident from the Delta point of view = 58.160000000000004%
# len(list_of_predictions) 949
# len(list_of_correct_answers) 949
# len(top_k_list_of_predicted_ids) 949
# Top-10 accuracy on the 80% the most confident from the Delta point of view = 56.48%
# len(list_of_predictions) 1008
# len(list_of_correct_answers) 1008
# len(top_k_list_of_predicted_ids) 1008
# Top-10 accuracy on the 85% the most confident from the Delta point of view = 54.459999999999994%
# len(list_of_predictions) 1067
# len(list_of_correct_answers) 1067
# len(top_k_list_of_predicted_ids) 1067
# Top-10 accuracy on the 90% the most confident from the Delta point of view = 52.76%
# len(list_of_predictions) 1126
# len(list_of_correct_answers) 1126
# len(top_k_list_of_predicted_ids) 1126
# Top-10 accuracy on the 95% the most confident from the Delta point of view = 51.33%
# len(list_of_predictions) 1186
# len(list_of_correct_answers) 1186
# len(top_k_list_of_predicted_ids) 1186
# Top-10 accuracy on the 100% the most confident from the Delta point of view = 49.75%

# %%
plt.figure(figsize = (15, 9))
plt.title("Rejection curves based on Delta for test set RuBQ 2.0 (1186 questions)", fontdict=font_title)
plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Delta", c="blue", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Delta", c="red", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Delta", c="green", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Delta", c="orange", marker='.', markersize=13, linewidth=0.8);


accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_Delta_for_test_set_RuBQ_2_0_1186_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# ### aggregation together

# %%
plt.figure(figsize = (16, 13))
plt.title("Rejection curves based on Single model UE measures for test set RuBQ 2.0 (1186 questions)", fontdict=font_title)
plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Delta", c="blue", marker='.', markersize=7, linewidth=1.5);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Maxprob", c="blue", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Entropy", c="blue", marker='.', markersize=7, linewidth=1.5, linestyle = ':');

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Delta", c="red", marker='.', markersize=9, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Maxprob", c="red", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Entropy", c="red", marker='.', markersize=7, linewidth=1.5, linestyle = ':');

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Delta", c="green", marker='.', markersize=9, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Maxprob", c="green", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Entropy", c="green", marker='.', markersize=7, linewidth=1.5, linestyle = ':');


plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Delta", c="orange", marker='.', markersize=9, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Maxprob", c="orange", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Entropy", c="orange", marker='.', markersize=7, linewidth=1.5, linestyle = ':');



accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_single_model_UE_mes_for_test_set_RuBQ_2_0_1186_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# # Simple Questions

# %%
sq_test = list(np.load("simple_questions_test.npy")[:,3])
sample_questions = len(sq_test)
three_quest = sq_test[:sample_questions]

result_sq = [predict_and_proba(three_quest[i], model = t5_qa_model, tokenizer=t5_tok, device=device) for i in range(sample_questions)]

predictions_sq = [i[0] for i in result_sq]
probas_sq = [i[1] for i in result_sq]
probas_sq = [i.detach().to("cpu") for i in probas_sq]

# %%
predictions_sq
# Out:
# [['Los Angeles',
#   'the United States',
#   'at age three',
#   'San Jose, California',
#   'New York',
#   'in the South Pacific',
#   'at age 29',
#   'New Orleans',
#   'Los Angeles County',
#   'Mexico'],
#  ['a drug overdose',
#   'a brain tumor',
#   'a fatal car accident',
#   'a heart attack',
#   'cerebral palsy',
#   'heart attack',
#   'a liver ectomy',
#   'a liver bleed',
#   'hanging',
#   'a suicide'],
#  ['the opera singer',
#   "the artist's signature",
#   "the artist's model",
#   'the murderer',
#   "his father's portrait",
#   'the obscene',
#   'the TARDIS',
#   'the criminal',
#   'the mummy',
#   "the artist's medium"],
#  ['second baseman',
#   'Second baseman',
#   'outfielder',
#   'third baseman',
#   'infielder',
#   'Third baseman',
#   'first baseman',
#   'pitcher',
#   'First baseman',
#   'utility player'],
#  ['Charles Dutoit',
#   'Pierre Boulez',
#   'Daniele Gatti',
#   'Haitink',
#   'Kurt Masur',
#   'Seiji Ozawa',
#   'Herbert von Karajan',
#   'Daniel Rahbari',
#   'Daniel Harding',
#   'Daniel Barenbock'],
#  ['New York City',
#   'New York',
#   'Newry Prison',
#   'Phoenix Park, Belfast',
#   'the United States',
#   'White Mountains, California',
#   'Phoenix Park, Johannesburg',
#   'Newry Jail',
#   'White House',
#   'Whitehall'],
#  ['Bristol, England',
#   'London, England',
#   'New York City',
#   'Sheffield, England',
#   'Norwich, England',
#   'Liberia',
#   'Birmingham, England',
#   'Boston, Massachusetts',
#   'London',
#   'Norwich, Norfolk'],
#  ['Who is Zerzan',
#   'Isis Press',
#   'Monthly Review Press',
#   'Who is Bataille?',
#   'Who is the New Communist',
#   'Who is Zer0',
#   'Isis',
#   'Who is Bataille',
#   'Why Not Press',
#   'What If'],
#  ['registered nurse',
#   'registered nursing assistant',
#   'registered dietician',
#   'attending nurse',
#   'pharmaceutical sales rep',
#   'florist',
#   'businesswoman',
#   'Registered Nursing',
#   'an actress',
#   'registered nursing student'],
#  ['left fielder',
#   'second baseman',
#   'Second baseman',
#   'outfielder',
#   'second half back',
#   'left cornerback',
#   'leftfielder',
#   'SS',
#   'left field',
#   'forward'],
#  ['Daniel Olbrychski',
#   'Aleks Paunovic',
#   'Daniel Brühl',
#   'Daniel Day-Lewis',
#   'Daniel von Bargen',
#   'Alain Chabat',
#   'Ralph Fiennes',
#   'Daniel Auteuil',
#   'Aleksander Zelenko',
#   'Al Pacino'],
#  ['Mozart',
#   'Josef Kajetán Tyl',
#   'Wolfgang Amadeus Mozart',
#   'Czech composer Janáek',
#   'Johann Wolfgang von Goethe',
#   'Svatopluk Presl',
#   'Aesop',
#   'Václav Havel',
#   'Svatopluk Machar',
#   'Alois Jirásk'],
#  ['Safed',
#   'Safed, Israel',
#   'Nazareth',
#   'Tel Aviv',
#   'Jerusalem',
#   'Netanya',
#   'Israel',
#   'Jaffa',
#   'Safed, Iraq',
#   'Safed, Kuwait'],
#  ['United States',
#   'Canada',
#   'South Africa',
#   'United Kingdom',
#   'USA',
#   'Australia',
#   'South Korea',
#   'Israel',
#   'US',
#   'United states'],
#  ['Le Corbusier',
#   'Henri Perret',
#   'Henri Labrouste',
#   'Henri Prost',
#   'Louis I. Kahn',
#   'Louis-Auguste Perret',
#   'Louis Perret',
#   'Louis-Émile Nouguier',
#   'Hector Guimard',
#   'Louis-Hippolyte'],
#  ['asteroid',
#   'dwarf smoot',
#   'Main-Belt Object',
#   'dwarf m42',
#   'dwarf spheroidal',
#   'dwarf m-type',
#   'Main-beam',
#   'Main-Belt',
#   'dwarf planet',
#   'T dwarf'],
#  ['robot battles',
#   'robot combat',
#   'robot battle',
#   'turn-based',
#   'free for all',
#   'robot fights',
#   'robot warfare',
#   'robot fighting',
#   'turn-based strategy',
#   'turn-based combat'],
#  ['A Star Is Born',
#   'Titanic (1997)',
#   'Romeo + Juliet',
#   'Eragon',
#   'Erotic romance',
#   'Titanic',
#   'Erin Brockovich',
#   'Finding Neverland',
#   'Erotica',
#   'My Week with Marilyn'],
#  ['Okayama Prefecture',
#   'tsu',
#   'Osaka, Japan',
#   'Kyoto, Japan',
#   'Yamaguchi Prefecture',
#   'Wakayama Prefecture',
#   'Kamakura',
#   'Sakai',
#   'gaki, Japan',
#   'gaki'],
#  ['Israeli',
#   'British Israeli',
#   'Israeli citizen',
#   'Belgian',
#   'Jewish Israeli',
#   'Israeli actor',
#   'Israeli citizenship',
#   'American',
#   'Israel',
#   'British'],
#  ['Malappuram',
#   'Thrissur',
#   'Ernakulam',
#   'Malabar',
#   'Trivandrum',
#   'Mavelikkara',
#   'Mavelikara',
#   'Kannur',
#   'Malabar, India',
#   'Kozhikode'],
#  ['Granada, Spain',
#   'Seville, Spain',
#   'Xalapa, Mexico',
#   'Madrid, Spain',
#   'vila, Spain',
#   'Xalapa, Spain',
#   ', a small village',
#   'lava, Spain',
#   'lava',
#   '1578'],
#  ['Female',
#   'F/M',
#   'Ftm',
#   'young Italian actress',
#   'Male',
#   'F/F',
#   'young Italian actor',
#   'young Italian composer',
#   'Young Italian composer',
#   'female'],
#  ['United States',
#   'Canada',
#   'New Zealand',
#   'Australia',
#   'Guam',
#   'Vancouver',
#   'Finland',
#   'San Francisco',
#   'Sweden',
#   'Hawaii'],
#  ['Copa Joo Havelange',
#   'Série A2',
#   'Campeonato do Interior',
#   'Ligas Superiores',
#   'Serie B',
#   'Copa FGF',
#   'Liga de Elite',
#   'Série B',
#   'second level',
#   'second division'],
#  ['Waar',
#   'Bhagam Bhag',
#   'Tanhaiyaan',
#   'Lagaan',
#   'Wajah Tum Ho',
#   'Koi Aap Sa',
#   'Deewana',
#   'Tanhai',
#   'Dangal',
#   'Fashion'],
#  ['Crawford County, Pennsylvania',
#   'Butler County',
#   'Monongalia County',
#   'Crawford County',
#   'Greene County',
#   'Indiana County',
#   'Crawford County, PA',
#   'Elk County',
#   'Washington County',
#   'Indiana County, Pennsylvania'],
#  ['Jerry Leiber',
#   'Art Rupe',
#   'Al Gorgoni',
#   'Rudy Vallée',
#   'the Ventures',
#   'Elvis Presley',
#   'Phil Spector',
#   'the Who',
#   'Rudy Clark',
#   'Ray Charles'],
#  ['John Farnham',
#   'Wayne Cochran',
#   'John Lee Hooker',
#   'John Lennon',
#   'Billie Myers',
#   'John Paul Young',
#   'Wayne Newton',
#   'John Hartford',
#   'John Legend',
#   'John Farrar'],
#  ['a turn-based strategy',
#   'a multiplayer mode',
#   'a multiplayer option',
#   'a two-way mirror',
#   'a power-up mode',
#   'a gameplay mode',
#   'a strategy video game',
#   'a video game mode',
#   'a computer game mode',
#   'a game play mode'],
#  ['Comedy-drama',
#   'a romantic drama',
#   "children's film",
#   "Children's film",
#   'Comedy',
#   'action-drama',
#   'Comedy film',
#   "children's drama",
#   'an Indian soap opera',
#   "Children's drama"],
#  ['Night Watch',
#   'The Snow Queen',
#   'The Twelve Chairs',
#   'The First Circle',
#   'The Fifth Element',
#   'The Duelist',
#   'The Duel',
#   'The Third Mother',
#   'The Duelists',
#   'The Fifth Ear'],
#  ['male',
#   'a boy',
#   'a male',
#   'Male',
#   'boy',
#   'her male identity',
#   'Mt.',
#   'masculine',
#   'her male self',
#   'MTF'],
#  ['jazz',
#   'Contemporary jazz',
#   'classical music',
#   'contemporary jazz',
#   'Romantic',
#   'Rock',
#   'New Age',
#   'fingerstyle',
#   'Contemporary classical',
#   'classical'],
#  ['Earth',
#   'a dwarf planet',
#   'its Jupiter counterpart',
#   'its innermost planet',
#   'its Earthlike counterpart',
#   'dwarf planet',
#   'a Jupiter Trojan',
#   'panda',
#   'Jupiter',
#   'its Sun'],
#  ['Kristiania, Norway',
#   'Oslo, Norway',
#   'Kristiansand, Norway',
#   'Trondheim, Norway',
#   'Holmestrand, Norway',
#   'lesund, Norway',
#   'Lillehammer, Norway',
#   'Voss, Norway',
#   'Eidsvoll, Norway',
#   'Molde, Norway'],
#  ['the Mario series',
#   'the Mario Adventures series',
#   'the Super Mario series',
#   'the New Kid Adventures',
#   'the Mario adventure series',
#   'the Mario brothers',
#   'the Mario franchise',
#   'the New Kid',
#   'the Mario',
#   'Mario'],
#  ['heart defect',
#   'cancer',
#   'addiction to alcohol',
#   'starvation',
#   'cardiovascular disease',
#   'nervousness',
#   'heart disease',
#   'brain tumor',
#   'addiction to cocaine',
#   'addiction to drugs'],
#  ['Philadelphia Harbor',
#   'Philadelphia Inner Harbor',
#   'Philadelphia Bay',
#   'the Delaware River',
#   'Philadelphia, Pennsylvania',
#   'Delaware River',
#   'Philadelphia Bar',
#   'Delaware Bay',
#   'the Delaware Bay',
#   'Philadelphia Inner Bay'],
#  ['biography',
#   'Fact-fiction',
#   'True crime',
#   'Biography',
#   'Realistic fiction',
#   'Fact-based',
#   'true crime',
#   'True story',
#   'Historical Fiction',
#   'Historical'],
#  ['defensive back',
#   'Cornerback',
#   'cornerback',
#   'wide receiver',
#   'quarterback',
#   'defensive tackle',
#   'Wide receiver',
#   'Linemen',
#   'defensive half',
#   'defensive end'],
#  ['Vincenzo Bellini',
#   'Luciano Michelini',
#   'Giuseppe Verdi',
#   'Vito Acconci',
#   'Luciano Michele',
#   '- Vincenzo Bellini',
#   'Vito Rizzuto',
#   'Daniele Manfredonia',
#   'Simonetta Stefanelli',
#   '...'],
#  ['Carrasco',
#   'Ignacio Carrasco',
#   'Ingeborg Carrasco',
#   'Oswaldo Carrasco',
#   'E. C. Pickering',
#   'Ulysses Carrasco',
#   'Ingeborg Carstensen',
#   'Auguste Charlois',
#   'Iolanda Carmen Miranda',
#   'I. Carrasco'],
#  ['professional football player',
#   'professional baseball player',
#   'professional footballer',
#   'criminal prosecutor',
#   'criminal defense attorney',
#   'lawyer',
#   'criminal investigator',
#   'police officer',
#   'criminal psychologist',
#   'physician'],
#  ['Vienna, Austria',
#   'Munich, Germany',
#   'Zürich, Switzerland',
#   'Augsburg, Germany',
#   'in Vienna, Austria',
#   'Stuttgart, Germany',
#   'Munich, Austria',
#   'Munich',
#   'Augsburg, Austria',
#   'Augsburg'],
#  ['Microsoft Game Studios',
#   'Lionhead Studios',
#   'United Game Artists',
#   'Falling Leaf Games',
#   'Falling Leaf Interactive',
#   'Universal Interactive Studios',
#   'United Game Developers',
#   'Microsoft Studios',
#   'Falling Leaf Systems',
#   'Fallout Games'],
#  ['American',
#   'United States',
#   'Australian',
#   'United States citizen',
#   'Baltimore, Maryland',
#   'Baltimore Ravens',
#   'English',
#   'US citizen',
#   'American former player',
#   'British'],
#  ['The Conformist',
#   'The Godfather Part III',
#   'The Great Silence',
#   "L'Avventura",
#   "L'Italiano",
#   'Life Is Beautiful',
#   'The Gospel According to Matthew',
#   'The Gospel According to St Matthew',
#   'Death in Venice',
#   'Life is Beautiful'],
#  ['disco',
#   'island disco',
#   'Hi-NRG',
#   'rhythm and blues',
#   'Disco',
#   'R&B',
#   'island music',
#   'Electropop',
#   'discotheque',
#   'disco music'],
#  ['Westmoreland County',
#   'Buckley County',
#   'Buckingham County',
#   'Buckley County, Kentucky',
#   'Buckley County, Georgia',
#   'Buckley County, Virginia',
#   'West Virginia',
#   'Buckley County, Texas',
#   'Buckingham County, Virginia',
#   'Buckley County, VA'],
#  ['Spain',
#   'England',
#   'Argentina',
#   'Mexico',
#   'Italy',
#   'Romania',
#   'South America',
#   'San Francisco',
#   'Colombia',
#   'Brazil'],
#  ['New York',
#   'United States',
#   'the US',
#   'United Kingdom',
#   'American',
#   'America',
#   'US',
#   'USA',
#   'Israel',
#   'German'],
#  ['died of a stroke',
#   'a fatal car accident',
#   'dying of a stroke',
#   'of a brain tumor',
#   'died of heart defect',
#   'of a stroke',
#   'pancreatic cancer',
#   'a stroke',
#   'of a terminal illness',
#   'double stroke'],
#  ['Male',
#   'bisexual',
#   'a boy',
#   'a male',
#   'male',
#   'either male or female',
#   'two-gender',
#   'a male predator',
#   'inagua',
#   'two males'],
#  ['electronic music',
#   'electronic dance music',
#   'Australian rock music',
#   'modern rock',
#   'contemporary Christian music',
#   'Australian rock',
#   'contemporary Christian',
#   'up-tempo',
#   'heavy metal',
#   'electronica'],
#  ['romance novel',
#   'drama',
#   'romance',
#   'Romance',
#   'A drama',
#   'romantic drama',
#   'romantic comedy',
#   'comedy',
#   'Drama',
#   'novel'],
#  ['her male identity',
#   'M',
#   'Métis',
#   'a male',
#   'hero',
#   'her male',
#   'she',
#   'male',
#   'S',
#   'Male'],
#  ['English',
#   'Lenny Henry',
#   'Navajo',
#   'Lenny Welsh',
#   'Lenny Bruce',
#   'Lenny Basic',
#   'Lenny',
#   'Creole',
#   'Pitkern',
#   'Jingpho'],
#  ['20', '29', '15', '22', '6', 'single', '18', '5', '27', '17'],
#  ['Diablo',
#   'a video game',
#   'a computer game',
#   'Metroidvania',
#   'Grand Theft Auto',
#   'A Chinese Ghost Story',
#   'a video game engine',
#   'A combat system',
#   'Pokémon',
#   'Minecraft'],
#  ['American Revolutionary War',
#   'the Crimean War',
#   'American Revolution',
#   'English Civil War',
#   'the Napoleonic Wars',
#   'American War of Independence',
#   "Seven Years' War",
#   'Crimean War',
#   'American Revolutionary war',
#   'the American Revolution'],
#  ['male',
#   'Male',
#   "men's",
#   'a male',
#   'Gender neutral',
#   'masculine',
#   'German businessman',
#   ' male',
#   'German male',
#   'German'],
#  ['Iceland',
#   'South Korea',
#   'Chile',
#   'Mali',
#   'New Zealand',
#   'Panama',
#   'South Africa',
#   'Indonesia',
#   'Norway',
#   'Japan'],
#  ['John August',
#   'Julian Fellowes',
#   'the Brothers Quay',
#   'Jan Troell',
#   'the nun who taught Luther',
#   'the nun who taught them',
#   'Ron Howard',
#   'Lars von Trier',
#   'Chris Columbus',
#   'the nun who taught German'],
#  ['RHI Entertainment',
#   'Plan B Entertainment',
#   'American International Pictures',
#   'R&R Partners',
#   'RSO Films',
#   'RKO Pictures',
#   'RKO Radio Pictures',
#   'Nu Image',
#   'RKO Studios',
#   'Hollywood Pictures'],
#  ['English',
#   'French',
#   'Icelandic',
#   'Bosnian',
#   'Arabic',
#   'Russian',
#   'German',
#   'English language',
#   'Czech',
#   'Turkish'],
#  ['crisis manager',
#   'lawyer',
#   'costume designer',
#   'professional hockey player',
#   'professional football player',
#   'professional baseball player',
#   'paleontologist',
#   'professional tennis player',
#   'actress',
#   'professional basketball player'],
#  ['Nevada City, California',
#   'Nevada',
#   'in the south Pacific',
#   'Nevada city, California',
#   'at age six',
#   'at age 33',
#   'at age 36',
#   'at age three',
#   'Las Vegas',
#   'Las Vegas, Nevada'],
#  ['Australian',
#   'Irish',
#   'Northern Irish',
#   'Northern Ireland',
#   'British',
#   'American',
#   'Scottish',
#   'United States',
#   'English',
#   'American actor'],
#  ['Newsreel',
#   'newsreel',
#   'newsreels',
#   'real-life drama',
#   'Newsreels',
#   'newsreel',
#   'a documentary film',
#   'documentary film',
#   'war documentary',
#   'war report'],
#  ['FromSoftware',
#   'Acclaim Entertainment',
#   'Voyager Interactive',
#   'Voyager Japan',
#   'Enterbrain',
#   '505 Games',
#   'From Software',
#   'Acclaim',
#   'From Software Publishers',
#   'Voyager Entertainment'],
#  ['motor neurone disease',
#   'macular degeneration',
#   "Alzheimer's disease",
#   'Leukemia',
#   'neurological form of cancer',
#   'Hodgkins disease',
#   'nervousness',
#   'brain tumor',
#   'ALS',
#   'neurological form of autism'],
#  ['Warner Music Sweden',
#   'Warner Music Group',
#   'Sony Music Entertainment',
#   'Warner Music',
#   'earMUSIC',
#   'RCA Records',
#   'Warner Music Swedish',
#   'Stockholm Records',
#   'Sony Music Entertainment Sweden',
#   'Warner Bros.'],
#  ['Manoj Kumar',
#   'Theodore Sturgeon',
#   'Theodore Melfi',
#   'Roy Rowland',
#   'George Tomasini',
#   'Fred J. Balshofer',
#   'Theodore Sturges',
#   'Stuart Orme',
#   'Gordon Willis',
#   'Theodore Storch'],
#  ['meteor',
#   'meteorite',
#   'meteor meteorite',
#   'meteoroid',
#   'meteorodrome',
#   'meteor meteoret',
#   'meteorosis',
#   'meteor meteor',
#   'meteor meteorid',
#   'meteorid'],
#  ['United States',
#   'Spain',
#   'France',
#   'North America',
#   'Canada',
#   'United Kingdom',
#   'Mexico',
#   'Japan',
#   'Poland',
#   'Denmark'],
#  ['Italian Renaissance',
#   'Mediterranean Revival',
#   'Italianate',
#   'Italian Renaissance architecture',
#   'Palladian',
#   'Greek Revival',
#   'Italian Villa',
#   'French Second Empire style',
#   'Italian Villa deste',
#   'Renaissance Revival'],
#  ['star',
#   'star like a comet',
#   'star of German origin',
#   'star for its location',
#   'star that shaped the Earth',
#   'star of the German kingdom',
#   'star with no known destination',
#   'star of the German Democratic Republic',
#   'star for its name',
#   'star of starkenburg'],
#  ['Santa Monica Bay',
#   'the Pacific Ocean',
#   'Ventura County',
#   'Pacific Ocean',
#   'San Diego Bay',
#   'Puget Sound',
#   'the Pacific coast',
#   'Ventura Harbor',
#   'Newport Bay',
#   'Pacific coast'],
#  ['Mike Oldfield',
#   'Lionel Bart',
#   'Harold Faltermeyer',
#   'Mike Rutherford',
#   'The Trashmen',
#   'Mike Post',
#   'Lionel Newman',
#   'Frank Musker',
#   'Carry On',
#   'Carry on cruising'],
#  ['male',
#   'a male',
#   '18',
#   'Métis',
#   'young male model',
#   'young male lead',
#   '19',
#   '27',
#   'Male',
#   '28'],
#  ['Rob Minkoff',
#   'Mark Osborne',
#   'Mark Dindal',
#   'Peter Hewitt',
#   'Hy Averback',
#   'David Silverman',
#   'David Hand',
#   'Alex Zamm',
#   'Chris Sanders',
#   'Rob Minty'],
#  ['Female',
#   'female',
#   'a female',
#   'she is female',
#   'a woman',
#   'she is male',
#   'male',
#   'she is Female',
#   'She is female',
#   'FTM'],
#  ['Arch bridge',
#   'Covered bridge',
#   'bascule bridge',
#   'through Truss',
#   'through-arch bridge',
#   'arch bridge',
#   'through-tile',
#   'Arch Bridge',
#   'suspension bridge',
#   'Arch'],
#  ['Kiev, Ukraine',
#   'Ukrainian',
#   'Russian',
#   'Kiev Oblast',
#   'born in Ukraine',
#   'from the Ukraine',
#   'Kievan Russia',
#   'Ukraine',
#   'from Kiev',
#   'Kiev'],
#  ['English',
#   'Telugu',
#   'Aramaic',
#   'Bosnian',
#   'American Sign Language',
#   'Indonesian',
#   'American sign language',
#   'Tetum',
#   'German',
#   'Tamil'],
#  ['war drama',
#   'historical',
#   'a historical drama',
#   'historical-fiction',
#   'historical-drama',
#   'war-drama',
#   'a historical romance',
#   'historical period drama',
#   'historical fiction',
#   'war documentary'],
#  ['Jamie Foxx',
#   'Alicia Keys',
#   'Young Thug',
#   'August Alsina',
#   'Julia Michaels',
#   'August 17, 2018',
#   'August Rigo',
#   'Simple Plan',
#   'Pink',
#   'Warner Bros.'],
#  ['A politician',
#   'A Member of Parliament',
#   'Politician',
#   'A member of Parliament',
#   'a politician',
#   'politician',
#   'A Politician',
#   'A political actor',
#   'elected official',
#   'A'],
#  ['Female',
#   'a male',
#   'male',
#   'female',
#   'a female',
#   'a woman',
#   'a boy',
#   'Female Trill',
#   'Male',
#   'she-boy'],
#  ['Folk',
#   'Aldebaran',
#   'Renaissance and early music',
#   'Classical',
#   'classical music',
#   'New age',
#   'Renaissance and Folk',
#   'World music',
#   'Americana',
#   'Classical crossover'],
#  ['David Mamet',
#   'David Frankel',
#   'David Ayer',
#   'Michel Brault',
#   'Michel Drach',
#   'Michel Gondry',
#   'David Greene',
#   'David A. Prior',
#   'Stuart Gordon',
#   'David Ansen'],
#  ['a revival',
#   'a musical',
#   'an American version',
#   'a Lyric opera',
#   'a musical adaptation',
#   'a modernized version',
#   'mashups',
#   'a modern era',
#   'an Americanized version',
#   'a musical version'],
#  ['Andrew Lippa',
#   'Charlie Puth',
#   'Bret McKenzie',
#   'Adam Schlesinger',
#   'Homer Banks',
#   'Peter Lurye',
#   'Benj Pasek',
#   'Moby',
#   'Dave Stewart',
#   'composed by Jerome Kern'],
#  ['New York City',
#   'Warsaw',
#   'New England',
#   'New York',
#   'the Netherlands',
#   'Northern New Jersey',
#   'Northern New Mexico',
#   'New York city',
#   'New Mexico',
#   'Sweden'],
#  ['The Wheel of Time',
#   'The Sword of Summer',
#   'The Sword of Truth',
#   'The Wheel of Time series',
#   'The Sword of Truth series',
#   'The Skyclans series',
#   'The Haviland Chronicles',
#   'The Sword of Truth trilogy',
#   'The Skyclan series',
#   'The Sword of Summer series'],
#  ['8 Man',
#   'Akira',
#   'Ghost in the Shell',
#   'Kagemusha',
#   '20th Century Boys',
#   'Battle Royale',
#   '9:59 AM',
#   '9:46',
#   '9:59 pm',
#   '9: The Movie'],
#  ['Richard Yates',
#   'Harper Lee',
#   'Richard Wright',
#   'Booth Tarkington',
#   'William Inge',
#   'Richard Price Stern',
#   'Richard Price',
#   'Frank Norris',
#   'Richard Price Sternberg',
#   'Richard Price Sternheim'],
#  ['Pee Wee Herman',
#   'John Reubens',
#   'Melvin Reubens',
#   'Harry Reubens',
#   'Richard Reubens',
#   'Mel Brooks',
#   'Milton Reubens',
#   'George Reubens',
#   'Bert Reubens',
#   'Mel Blanc'],
#  ['John Byrum',
#   'Mike Figgis',
#   'Mike Hodges',
#   'John Canemaker',
#   'Bruce Beresford',
#   'Mike Leigh',
#   'Rupert Sanders',
#   'John Boorman',
#   'John Duigan',
#   'Rupert Murray'],
#  ['Rancid',
#   'Brett Gurewitz',
#   'Rise Against',
#   'Bad Religion',
#   'the Offspring',
#   'blink-182',
#   'The Offspring',
#   'Bane',
#   'Joan Jett',
#   'Rise Against.'],
#  ["Children's",
#   'Fantasy',
#   "children's musical",
#   "Children's (",
#   "children's",
#   'Children’s',
#   'Comedy',
#   'family comedy',
#   'Family',
#   'Gothic'],
#  ['T Tauri',
#   'a white dwarf',
#   'Luminous blue dwarf',
#   'ecliptic',
#   'Betelgeuse',
#   'dwarf stars',
#   'T dwarfs',
#   'dwarf star',
#   'Luminous blue variable',
#   'a dwarf  star'],
#  ['Gert Fröbe',
#   'Daniel Brühl',
#   'Christoph Koncz',
#   'Udo Kier',
#   'German actor Daniel Brühl',
#   'Thomas Kretschmann',
#   'Johannes Heesters',
#   'Gerard Butler',
#   'Christopher Walken',
#   'Christoph Koncz.'],
#  ['Conquest',
#   '"Conquer"',
#   'Call of the Wild',
#   'one-on-one',
#   'uprising',
#   '"Vendetta"',
#   'Call to Arms',
#   '"Conquest"',
#   'Armored Mission',
#   'single-player'],
#  ['Alvin Rakoff',
#   'John Huston',
#   'Milo Forman',
#   'John Schlesinger',
#   'George Cukor',
#   'Mel Brooks',
#   'Louis Malle',
#   'John Erman',
#   'John Casswell',
#   'John Cassava'],
#  ['Fort Worth, Texas',
#   'Waco, Texas',
#   'Fort Smith, Arkansas',
#   'Las Vegas, New Mexico',
#   'Memphis, Tennessee',
#   'Los Angeles, California',
#   'Arkansas',
#   'Los Angeles',
#   'Las Vegas, Nevada',
#   'Bastrop, Texas'],
#  ['United States',
#   'Canada',
#   'United Kingdom',
#   'Great Britain',
#   'France',
#   'United states',
#   'British Empire',
#   'United State',
#   'British',
#   'UK'],
#  ['English',
#   'Australian',
#   'American',
#   'Englishman',
#   'British',
#   'Irish',
#   'Scottish',
#   'Canadian',
#   'American actor',
#   'United States'],
#  ['United States',
#   'England',
#   'Kingdom Come',
#   'France',
#   'American country',
#   'the US',
#   'American South',
#   'America',
#   'American',
#   'Ireland'],
#  ['Roland Emmerich',
#   'David E. Kelley',
#   'David Kirschner',
#   'David Fincher',
#   'Edward Kitsis',
#   'J. Allen St John',
#   'J. Peter Robinson',
#   'David E. Goodman',
#   'David Coburn',
#   'J. Allen Strick'],
#  ['Kedu Plain',
#   'Indramayu',
#   'Magelang',
#   'Kediri',
#   'Purwokerto',
#   'in Jakarta',
#   'Purworejo',
#   'Bandung',
#   'Bandung, Indonesia',
#   'Tegal'],
#  ['clarinet',
#   'Theorbo',
#   'The clarinet',
#   'The banjo',
#   'melodica',
#   'Clarinet',
#   'banjo',
#   'The violin',
#   'The bansuri',
#   'electric guitar'],
#  ['Italian writer Giovanni Verga',
#   'Paula Hawkins',
#   'Italian American writer Mario Puzo',
#   'Italian author C. S. Lewis',
#   'Italian American writer Giovanni Verga',
#   'Jacqueline Susann',
#   'Helena Bonham Carter',
#   'Paul Auster',
#   'Jacqueline Rose',
#   'Eric Bentley'],
#  ['United States',
#   'the United States',
#   'U.S.',
#   'Cayman Islands',
#   'United States of America',
#   'United States citizen',
#   'Republic of Ireland',
#   'the Bahamas',
#   'Bahamas',
#   'Mexico'],
#  ['Female',
#   'transgender',
#   'male',
#   'MgH',
#   'MgA',
#   'Miss',
#   '18',
#   'M',
#   'F',
#   'FTM'],
#  ['The Hurricane',
#   "Wayne's World",
#   'The Game Plan',
#   'Thank You for Smoking',
#   'The Fugitive',
#   'The Breakfast Club',
#   'Snatch',
#   'The Last Samurai',
#   "Wayne's World 2",
#   'The English Patient'],
#  ['Male',
#   'male',
#   'Métis',
#   'Male identical twin',
#   'Male heterosexual',
#   'masculine',
#   'Male,',
#   'Male)',
#   'M.',
#   'boy'],
#  ['Historical fiction',
#   'historischer Musik',
#   'historischer Kunst',
#   'historische musik',
#   'historische drama',
#   'Historical Fiction',
#   'Historical',
#   'historische literatur',
#   'historische folktale',
#   'Gothic fiction'],
#  ['Mozambique',
#   'South Africa',
#   'the Congo Basin',
#   'basin country South Africa',
#   'southwestern Australia',
#   'southwestern Zambia',
#   '. Located',
#   '.......',
#   'DR Congo',
#   'Zimbabwe'],
#  ['Male',
#   'male',
#   'both male and female',
#   'either male or female',
#   'both male and male',
#   'Ernst Friedrich Kinzel',
#   'German sculptor',
#   'M.',
#   'Ernst (',
#   'German'],
#  ['Brazil',
#   'Cape Verde',
#   'the United States',
#   'Portugal',
#   'Angola',
#   'Salvador, Brazil',
#   'S. America',
#   'the Philippines',
#   'the US',
#   'Brazil.'],
#  ['English',
#   'American English',
#   'un-American English',
#   'un-interlingual',
#   'English (International)',
#   'English (2001)',
#   'English as an accent',
#   'un-English',
#   'English language',
#   'English translation'],
#  ['Canada',
#   'Mexico',
#   'United States',
#   'England',
#   'Ghana',
#   'China',
#   'Germany',
#   'Netherlands',
#   'the Netherlands',
#   'the UK'],
#  ['both male and female',
#   'Male',
#   'male',
#   'both Male and Female',
#   'a male',
#   'either male or female',
#   'his age is 29',
#   'both male and male',
#   'histrionic male',
#   'his age is unknown'],
#  ['Female',
#   'female',
#   'Ftm',
#   'a woman',
#   "women's",
#   'L/F',
#   'young woman',
#   'FTM',
#   'L',
#   'Male'],
#  ['Hindi',
#   'Haryanvi',
#   'Bhojpuri',
#   'Hindustani',
#   'Hindi-Urdu',
#   'Haryanvi languages',
#   'Haryanvi language',
#   'Haryanvi Language',
#   'Hindustani classical music',
#   'Marathi'],
#  ['turn-based',
#   'Single-player',
#   'single-player',
#   'standard RPG gameplay',
#   'simple turn-based',
#   'single-player campaign',
#   'straightforward',
#   'various game modes',
#   'various game options',
#   'Normal gameplay'],
#  ['video game',
#   'mobile phone strategy video game',
#   'fast-paced video game',
#   'mobile strategy video game',
#   'mobile phone video game',
#   'puzzle-action video game',
#   'Puzzle-based video game',
#   'Puzzle/Simulation',
#   'Puzzle/Simulation game',
#   'puzzle-action'],
#  ['Barbara Kopple',
#   'Eric Roth',
#   'Blake Edwards',
#   'Ronald Bass',
#   'Aaron Sorkin',
#   'the Wachowskis',
#   'Steven Spielberg',
#   'Blake Masters',
#   'Barbara Hall',
#   'Barbara Kohner'],
#  ['Art Tatum',
#   'Dave Brubeck',
#   'Fats Waller',
#   'Peter Serkin',
#   'Arthur Rubinstein',
#   'Liberace',
#   'Earl Hines',
#   'Billy Taylor',
#   'Peter Wood',
#   'Glenn Miller'],
#  ['English',
#   'Doric (English)',
#   'Domesday Book',
#   'English is the medium',
#   'Doric',
#   'British English',
#   'Manx English',
#   'English language',
#   'American English',
#   'None'],
#  ['Norway',
#   'United States',
#   'South Dakota',
#   'Norway.',
#   'Norwegian',
#   'United Kingdom',
#   'South Korea',
#   'Iceland',
#   'Norway (',
#   'Chile'],
#  ['Neversoft',
#   'Factor 5',
#   'David Jones',
#   'Yu Suzuki',
#   'SingleTrac',
#   'PopCap Games',
#   'Rare',
#   'Hudson Soft',
#   'Tim Burton',
#   'Greg Johnson'],
#  ['the Château de Chillon',
#   'Château de Chillon',
#   'Saint-Denis',
#   'place de la Concorde',
#   'Saint-Lazare',
#   'Château-Thierry',
#   'Saint-Lô',
#   'Hanoi',
#   'in Paris',
#   'Paris'],
#  ['Paul Verhoeven',
#   'Melton Barker',
#   'William Cameron Menzies',
#   'Henry King',
#   'Arthur Hiller',
#   'Paul Thomas Anderson',
#   'Paul Lynch',
#   'George Roy Hill',
#   'Melton Lee',
#   'Melton Stuart'],
#  ['Quebec City',
#   'Quebec',
#   'Quebec, Canada',
#   'Quebec City, Quebec',
#   'Quebec City, Canada',
#   'Quebec city',
#   'Quebec City, Ontario',
#   'Quebec City Ontario',
#   'Quebec City Canada',
#   'Quebec-Canada'],
#  ['asteroid',
#   'a comet',
#   'comet',
#   'a dwarf  star',
#   'a dwarf nova',
#   'eXtreme',
#   'ecliptic',
#   'Neutron star',
#   'TNO',
#   'star'],
#  ['the Bronx',
#   'Waxahachie, Texas',
#   'Sydney, Australia',
#   'in the U.S.',
#   'in the village of Hambleden',
#   'Wapping, London',
#   'in the village of Little Horton',
#   'in the village of Lathkill',
#   'Adelaide, Australia',
#   'Wagga Wagga'],
#  ['male',
#   'a male',
#   'He/She',
#   'Heisman',
#   'Heis male',
#   'He',
#   'she',
#   'Male',
#   'Female',
#   'female'],
#  ['Shooting guard',
#   'shooting guard',
#   'center',
#   'Second baseman',
#   'Shooting Guard',
#   'defensive back',
#   'defensive player',
#   'Shooter',
#   'defensive tackle',
#   'defensive forward'],
#  ['United States',
#   'Germany',
#   'South Dakota',
#   'German',
#   'American',
#   'Canada',
#   'South Africa',
#   'Switzerland',
#   'Australia',
#   'the US'],
#  ['United States',
#   'the United States',
#   'native of Seattle',
#   'native of Chicago',
#   'native of Wisconsin',
#   'native of Germany',
#   'United States.',
#   'native of Chile',
#   'Germany',
#   'Austria'],
#  ['action-thriller',
#   'Horror',
#   'indie video game',
#   'indie horror film',
#   'video game',
#   'horror',
#   'Gothic horror',
#   'action adventure',
#   'Gothic',
#   'adventure'],
#  ['Peoria County',
#   'Tazewell County',
#   'Woodford County',
#   'Piatt County',
#   'Fulton County',
#   'McLean County',
#   'Pike County',
#   'peoria county',
#   'Peotone County',
#   'peoria County'],
#  ['Single-player',
#   'Capture the Flag',
#   'Arcade',
#   'Freestyle',
#   'Be a Legend',
#   'Be a Master',
#   'Be a Pro',
#   'single-player',
#   'Capture the flag',
#   'Be a silhouette'],
#  ['Italy',
#   'France',
#   'Spain',
#   'Georgia',
#   'Ireland',
#   'Poland',
#   'Greece',
#   'Ukraine',
#   'Sweden',
#   'Croatia'],
#  ['Hamilton, Ontario',
#   'Hamilton, Nova Scotia',
#   'Brandon, Manitoba',
#   'Timmins, Ontario',
#   'Goderich, Ontario',
#   'Cobourg, Ontario',
#   'Goderich',
#   'Hamilton, Quebec City',
#   'Dundas, Ontario',
#   'Timmins, Alberta'],
#  ['Russian',
#   'Kazakhstani',
#   'Tajik',
#   'Chechen',
#   'Soviet citizen',
#   'Bashkir',
#   'Kazakhstani citizen',
#   'Kazakh',
#   'Soviet Russian',
#   'Russian citizen'],
#  ['Male',
#   'both male and female',
#   'same-sex',
#   'Paul Phoenix',
#   'Paul, an adult',
#   'Paul',
#   'Paul (',
#   'male',
#   'Paul,',
#   'Luke'],
#  ['defensive back',
#   'defensive tackle',
#   'defensive player',
#   'defensive half',
#   'defensive end',
#   'left guard',
#   'guard',
#   'left tackle',
#   'lock',
#   'defensive forward'],
#  ['Marathi',
#   'marathi',
#   'Devnagari',
#   'Marathi poetry',
#   'Maratha',
#   'the Hindi language',
#   'Dogri',
#   'Bengali',
#   'dogri',
#   'Hindi'],
#  ['reggae',
#   'Hip hop',
#   'R&B',
#   'electronic dance music',
#   'Club/Dance',
#   'disco',
#   'house',
#   'hip hop',
#   'House',
#   'house music'],
#  ['Ohm',
#   'Crater Ohm',
#   'Ohm Crater',
#   'Otto Crater',
#   'OHM Crater',
#   'Otto Ohm',
#   "Ohm's Revolution",
#   'Georgius Aper',
#   'R. Ohm',
#   "Ohm's"],
#  ['Hollywood',
#   'Hollywood Receiving Hospital',
#   'Hollywood Hospital',
#   'Hollywood Private Hospital',
#   'Hollywood private hospital',
#   'the Hollywood Roosevelt Hotel',
#   'Los Angeles',
#   'Hollywood Presbyterian Medical Center',
#   'Hollywood Roosevelt Hotel',
#   'Santa Monica Hospital'],
#  ['Liga Dominicana de Ftbol',
#   'Liga Nacional de Ftbol',
#   'Liga Nacional de Baloncesto',
#   'Primera División',
#   'Liga Nacional de Futbol',
#   'Liga Dominicana de Futbol',
#   'Liga Nacional',
#   'Liga Dominicana',
#   'Liga de Elite',
#   'Liga Mayor'],
#  ['John Lanchester',
#   'George Eliot',
#   'George Moore',
#   'John le Carré',
#   'John le Carre',
#   'William Boyd',
#   'William Thompson',
#   'Richard Bean',
#   'Richard Price',
#   'George Gisborne'],
#  ['goaltender',
#   'defenseman',
#   'winger',
#   'Swiss National Team',
#   '',
#   'a forward',
#   'Defenseman',
#   ' center',
#   '3',
#   'center'],
#  ['English',
#   'Australian English',
#   'Australian language',
#   'unicode',
#   'undetermined format',
#   'undetermined language',
#   'undetermined',
#   'undetermined length',
#   'Australian',
#   'in Canada'],
#  ['midfielder',
#   'forward',
#   'central forward',
#   'goalkeeper',
#   'striker',
#   'center forward',
#   'centre forward',
#   'defensive back',
#   'midfielders',
#   'midfield player'],
#  ['Basel',
#   'Munich',
#   'Zürich',
#   'Zurich',
#   'Baselt',
#   'Frankfurt am Main',
#   'Jena',
#   'Berlin',
#   'Leipzig',
#   'Vienna'],
#  ['paleontologist',
#   'break ups',
#   'executive for the FBI',
#   'white male entertainer',
#   'sports commentator',
#   'break into music',
#   'industrialist',
#   'break news',
#   'police officer',
#   'break up singer'],
#  ['Aaron Copland',
#   'Elmer Bernstein',
#   'Jean Sibelius',
#   'A.R. Rahman',
#   'T.A. Newsome',
#   'T.I. Miller',
#   'Gustav Holst',
#   'T.A.B.',
#   'T.I. Payne',
#   'Rachel Portman'],
#  ['Edward Bowell',
#   'Richard P. Binzel',
#   'Edward Calvin Griggs',
#   'Eleanor Helin',
#   'Edward Calvin Gliese',
#   'Richard Binzel',
#   'Edward Calvin Glicken',
#   'E. C. Watson',
#   'Edwin Hubble',
#   'E. Bowell'],
#  ['Scottish',
#   'African-American',
#   'Caucasian',
#   'African American',
#   'English',
#   'American',
#   'Scottish-American',
#   'American actor',
#   'African- American',
#   'African–American'],
#  ['Jacques Tati',
#   'Kenneth Anger',
#   'Jules Dassin',
#   'Roman Polanski',
#   'Jerzy Hoffman',
#   'Ken Loach',
#   'Jacques Demy',
#   'Joe Dante',
#   'Ken Russell',
#   'Jacques Tati.'],
#  ['Hamburg',
#   'Jena',
#   'Bremen, Germany',
#   'Leipzig',
#   'Dresden, Germany',
#   'Delft',
#   'Bonn',
#   'Hamburg, Germany',
#   'Munich',
#   'Münster'],
#  ['New York City',
#   'Boston',
#   'Boston, Massachusetts',
#   'Cincinnati, Ohio',
#   'in Philadelphia',
#   'Louisville, Kentucky',
#   'New York city',
#   'Baltimore',
#   'New York',
#   'Philadelphia'],
#  ['a grid',
#   'two players in pairs',
#   'two players using two cards',
#   'two players in two rows',
#   'a card game',
#   'two people in two rows',
#   'two people in two positions',
#   'two players using cards',
#   'a board game',
#   'two players using two dice'],
#  ['railway drama',
#   'transportation-themed film',
#   'railway fiction',
#   'transport-oriented narrative',
#   'railway themed film',
#   'railway metaphor',
#   'transport-themed comedy',
#   'transportation-themed comedy',
#   'a musical',
#   'railway opera'],
#  ['San Diego, California',
#   'Fort Worth, Texas',
#   'Dayton, Ohio',
#   'Los Angeles',
#   'El Paso, Texas',
#   'San Francisco, California',
#   'Dayton, Tennessee',
#   'Sydney, Australia',
#   'San Diego, CA',
#   'Muskogee,'],
#  ['Christian',
#   'Pop',
#   'Contemporary Christian',
#   'Christian rock',
#   'Electronic rock',
#   'electronic rock',
#   'Alternative rock',
#   'Commercial Pop',
#   'electronica',
#   'Jazz'],
#  ['M',
#   'Female',
#   'FTM',
#   'a female',
#   'Ftm',
#   'M/F',
#   'M.',
#   'a woman',
#   'MSM',
#   'LGB'],
#  ['architect',
#   'doctor',
#   'professional football player',
#   'Physician',
#   'master mason',
#   'professional baseball player',
#   'a doctor',
#   'a lawyer',
#   'criminal defense attorney',
#   'physician'],
#  ['Russia',
#   'Russian Federation',
#   'Yukon, Canada',
#   'the Russian Federation',
#   'Svalbard',
#   'Siberia',
#   'Russian Far East',
#   'the Russian Far East',
#   'in Alaska',
#   'Alaska'],
#  ['Folk',
#   'Americana',
#   'Christian',
#   'Country',
#   'contemporary Christian',
#   'Contemporary Christian',
#   'romantic folk',
#   'Pop',
#   'American country',
#   'American singer'],
#  ['Christie Golden',
#   'Sharon Elizabeth Doyle',
#   'Jeffery Deaver',
#   'Judith Tarr',
#   'Sharon Shinn',
#   'Yvonne Craig',
#   'Steve Alten',
#   'Yvonne Jones',
#   'Jeff Lindsay',
#   'Yvonne Joyce'],
#  ['Los Angeles',
#   'Los Angeles County',
#   'Los Angeles, California',
#   'San Diego, California',
#   'June 28, 1882',
#   'in Los Angeles',
#   'June 28, 1868',
#   'June 28, 1878',
#   'June 28, 1873',
#   'June 28, 1886'],
#  ['Themistian',
#   'Themis Group',
#   'Eos',
#   'Themistian group',
#   'Eos group',
#   'Eos system',
#   'Themistian Group',
#   'Themistian cluster',
#   'Themis',
#   'The Flora Group'],
#  ['English',
#   'American English',
#   'mainly in English',
#   'English as the medium',
#   'English (UK)',
#   'benga',
#   'in English',
#   'English language',
#   'English languages',
#   'English translation'],
#  ['José Quintero',
#   'José Luis Alcoriza',
#   'José Luis Merino',
#   'José Luis Alcaine',
#   'Aleksandar Petrov',
#   'Almodóvar',
#   'J. Lee Thompson',
#   'José Ferrer',
#   'John Erman',
#   'Carlos Saura'],
#  ['Germany',
#   'lake District of Germany',
#   'lake district of Berlin',
#   'lake District of Berlin',
#   'Germany[2]',
#   'the German Democratic Republic',
#   'Germany and Poland',
#   'Germany,',
#   'East Germany',
#   'Germany.'],
#  ['London',
#   'Sandringham House',
#   'Balmoral Castle',
#   'at the London Clinic',
#   'the Tower of London',
#   'Kenya',
#   'Munich, Germany',
#   'the United Kingdom',
#   'at home',
#   'Sandringham'],
#  ['Belfast',
#   'Stockport, England',
#   'Castleford, England',
#   'Chesterfield, England',
#   'Blackpool',
#   'in Stockport',
#   'West Yorkshire',
#   'in Hull',
#   'Chesterfield, Pennsylvania',
#   'Manchester'],
#  ['Andy Warhol',
#   'David (Jack) Carter',
#   'John Henry Carver',
#   'John "Jack" Carter',
#   'John Henry Anderson',
#   'David Carradine',
#   'John Henry Patterson',
#   'John Milton',
#   'David Carter',
#   'John Henry Cartier'],
#  ['American',
#   'American actress',
#   'British',
#   'English',
#   'French',
#   'United States',
#   'Canadian',
#   'Belgian',
#   'Australian',
#   'American actor'],
#  ['Denver, Colorado',
#   'Denver, CO',
#   'Vienna, Austria',
#   'Dublin, Ireland',
#   'in Philadelphia',
#   'Bristol, England',
#   'in 1890',
#   'Toronto, Ontario',
#   'in Leeds',
#   'Leeds'],
#  ['United States',
#   'Japan',
#   'the US',
#   'Australia',
#   'Brazil',
#   'China',
#   'the UK',
#   'Ghana',
#   'the USA',
#   'Nigeria'],
#  ['Martin Kahan',
#   'Martin Shkreli',
#   'Martin Weisz',
#   'Martin Bashir',
#   'Martin Breslow',
#   'Martin Bregman',
#   'Martin Campbell',
#   'Martin Johnson',
#   'Martin Lawrence',
#   'Martin Bress'],
#  ['Ireland',
#   'United States',
#   'the United States',
#   'Liberia',
#   'the United Kingdom',
#   'South Carolina',
#   'United Kingdom',
#   'Northern Ireland',
#   'North Carolina',
#   'United States citizenship'],
#  ['early music',
#   'Bill Evans',
#   'early music?',
#   'Bill Frisell',
#   'early music??',
#   'Mike Oldfield',
#   'Mike Viola',
#   'Bill Withers',
#   'Charles Lloyd',
#   'early music performers'],
#  ['Warhol',
#   'David Puttnam',
#   'Warwick Films',
#   'Brian Grazer',
#   'Michael Klinger',
#   'David Webb',
#   'Brian Pern',
#   'Jack Nance',
#   'Jack Nitzsche',
#   'David Foster'],
#  ['male',
#   'Female',
#   'Male',
#   'a male',
#   'He is male',
#   'He/She',
#   'female',
#   'He',
#   'Neither',
#   'guy'],
#  ['Last Vegas',
#   'A Time to Kill',
#   'Last Exorcism',
#   'The House Bunny',
#   'Last Exodus',
#   'The Last Samurai',
#   'A Time to Love',
#   'Last Exit to Brooklyn',
#   'Time Bandits',
#   'Gardens of Stone'],
#  ['male',
#   'his sister',
#   'a boy',
#   'his grandson',
#   'masculine',
#   'Male',
#   'his twin',
#   'Female',
#   'female',
#   'His'],
#  ['the hanging',
#   'Tom Held',
#   'the hand of God',
#   'what he held',
#   'the hand of another',
#   'the holding',
#   'the holding company',
#   'Tom',
#   'the hold',
#   'hanging'],
#  ['battle for the Sun',
#   'battle for the sun',
#   'Battleme',
#   'battle rapper Khalid',
#   'battle rapper Battleme',
#   'battle rapper Styles',
#   'Battlefield Band',
#   'Battles',
#   'battle rapper NF',
#   'Battlemesh'],
#  ['Nevers',
#   'Abbeville, France',
#   'Angers, France',
#   'Nemours',
#   'Sedan',
#   'Nevers, France',
#   'Sedan, France',
#   'Arras',
#   'Château-Thierry',
#   'Paris'],
#  ['rhythm and blues',
#   'Pop',
#   'American rock',
#   'R&B',
#   'contemporary Christian music',
#   '(instrumental)',
#   'hard rock',
#   'American soul',
#   'CCM',
#   'American soul music'],
#  ['Napa, California',
#   'the United States',
#   'Nero Wolfe',
#   'Gladstone, New Jersey',
#   'Gladstone, New York',
#   "St. John's",
#   'Gladstone, Pennsylvania',
#   'New York',
#   'Gladstone, Georgia',
#   'the US'],
#  ['Kiev, Ukraine',
#   'Kiev',
#   'Kiev, Ukrainian SSR',
#   'Donetsk',
#   'Kharkiv',
#   'Kyiv, Ukraine',
#   'Kiev, Soviet Union',
#   'Kyiv',
#   'Kiev, Soviet Union,',
#   'Lviv'],
#  ['wide receiver',
#   'defensive back',
#   'midfielder',
#   'cornerback',
#   'offensive tackle',
#   'offensive lineman',
#   'offensive frontman',
#   'placekicker',
#   'Truman Scholar',
#   'guard'],
#  ['Male',
#   'young male Viking',
#   'a boy',
#   'male',
#   'young male',
#   'young boy',
#   'two',
#   'young girl',
#   'teenage boy',
#   'Female'],
#  ['single-player action',
#   'single-player video game',
#   'single-player mode',
#   'single-player action game',
#   'single-player strategy game',
#   'Single-player action',
#   'single-player video games',
#   'single-player arcade game',
#   'Single-player video game',
#   'single-player'],
#  ['Japan',
#   'United States',
#   'South Korea',
#   'North America',
#   'Japan.',
#   'Japan (',
#   'Japan,',
#   'Japan)',
#   'Japan Japan',
#   'Australia'],
#  ['Action-drama',
#   'science fiction',
#   'action-drama',
#   'Dhallywood',
#   'Sports-drama',
#   'Science fiction',
#   'Action-Drama',
#   'Sci-Fi',
#   'Indie drama',
#   'Sports drama'],
#  ['Petrarch',
#   'Dante Alighieri',
#   'Giorgio Vasari',
#   'C. S. Lewis',
#   'Michelangelo',
#   'Pirandello',
#   'Stefano Bartoli',
#   'Petrarca',
#   'Stefano Bardini',
#   'Stendhal'],
#  ['Brazilian Série B',
#   'Primera Diviso',
#   'brasileiro',
#   'Brazilian Série A2',
#   'Série B',
#   "Brazil's Serie B",
#   'Primera B Nacional',
#   'Brazilian Série A',
#   'Liga de Elite',
#   "Brazil's Second Division"],
#  ['Spain',
#   'Kingdom of Spain',
#   'Spain and Portugal',
#   'Spain and France',
#   'Spain and Italy',
#   'Spain –',
#   'Spain -',
#   'United States',
#   'United Kingdom',
#   'Spain,'],
#  ['Argentina',
#   'the United States',
#   'Argentine',
#   'Dominican Republic',
#   'United States',
#   'Venezuela',
#   'Dominican republic',
#   'Italy',
#   'American',
#   'Uruguay'],
#  ['Comedy',
#   'Suspense',
#   'Family drama',
#   'Resurrection',
#   'Reality-drama',
#   'Reality-comic',
#   'Reality-based comedy',
#   'Reactionary drama',
#   'Domestic drama',
#   'Civilian'],
#  ['Sweden',
#   'South Africa',
#   'The Netherlands',
#   'The Bahamas',
#   'New Zealand',
#   'the Netherlands',
#   'South African',
#   'Australia',
#   'Norway',
#   'Swedish'],
#  ['John Stafford Smith',
#   'John Colby',
#   'John Sebastian',
#   'John Rutter',
#   'John Henry Newman',
#   'Tim Rice',
#   'John Rox',
#   'John Colbert',
#   'John Newman',
#   'John R. Cherry'],
#  ['England',
#   'London',
#   'Barbados',
#   'Ireland',
#   'in London',
#   'London England',
#   'Germany',
#   'Wales',
#   'in England',
#   'Spain'],
#  ['at age three',
#   'fictional hometown of Van Wert',
#   'fictional hometown of Lawrenceville',
#   'San Jose, California',
#   'Arkansas',
#   'fictional hometown of Lawrence',
#   'Seattle, Washington',
#   'at age five',
#   'Seattle',
#   'whatever'],
#  ['Gianluca Festa',
#   'Daniele De Rossi',
#   'Alessandro Diamanti',
#   'Matteo Darmian',
#   'Matteo Sereni',
#   'Giorgio Chiellini',
#   'Mattia Destro',
#   'Davide Santon',
#   'Federico Marchetti',
#   'Matteo Ferrari'],
#  ['Vienna, Austria',
#   'Riga, Germany',
#   'Germany',
#   'Munich, Germany',
#   'Munich, West Germany',
#   'Gotha, Germany',
#   '1893',
#   'New York City',
#   'Austria',
#   'Riga, Poland'],
#  ['defensive back',
#   'defensive end',
#   'defensive player',
#   'running back',
#   'defensive tackle',
#   'offensive tackle',
#   'defensive half',
#   'fullback',
#   'center',
#   'Center'],
#  ['male',
#   'Male',
#   'transitional male',
#   'masculine',
#   'young adult male',
#   'young male',
#   'transitional gender',
#   'transitional gay',
#   'transitional female',
#   'young boy'],
#  ['Joe DiBlasi',
#   'John Scofield',
#   'John Sykes',
#   'Zakk Wylde',
#   'Joshua Kadison',
#   'Jeff Baxter',
#   'Steve Vai',
#   'Joshua Kear',
#   'Joe Pass',
#   'Joshua Keillor'],
#  ['South Sudan',
#   'Gabon',
#   'Sudan',
#   'Guyana',
#   'Nicaragua',
#   'Venezuela',
#   'Colombia',
#   'Uganda',
#   'South Africa',
#   'South America'],
#  ['midfielder',
#   'defensive back',
#   'Midfielder',
#   'middle blocker',
#   'forward',
#   'goalkeeper',
#   'middle forward',
#   'wide receiver',
#   ' forward',
#   'holding'],
#  ['1892',
#   'the Bronx',
#   'June 15, 1892',
#   '18 August 1892',
#   '1861',
#   '18 August 1886',
#   '1873',
#   '1863',
#   '1872',
#   '18 August 1898'],
#  ['Poland',
#   'China',
#   'Germany',
#   'Spain',
#   'France',
#   'Denmark',
#   'the Netherlands',
#   'the UK',
#   'Hungary',
#   'German'],
#  ['The Last Unicorn',
#   'The Crystal Shard',
#   'The War of the Worlds',
#   'The Crystal Singer',
#   'The Last Guardian',
#   'The Crystal Cave',
#   'The Sword of Summer',
#   'The Silver Chair',
#   'The Vor Game',
#   'The War of the Jewels'],
#  ['Frank Ferrer',
#   'Joe Vitale',
#   'Phil Jones',
#   'Matt Sorum',
#   'Travis Barker',
#   'The Rev',
#   'Steven Adler',
#   'Chad Smith',
#   'Frank Ferrer???',
#   'Frank Ferrer II'],
#  ['aak',
#   'abac',
#   'Ljubljana',
#   'ajetina',
#   'abac, Croatia',
#   'Viegrad',
#   'Kraljevo',
#   'Split, Croatia',
#   'Zagreb',
#   'Knin'],
#  ['Male',
#   'male',
#   'a male',
#   ', male',
#   'Female',
#   ', Male',
#   'a boy',
#   'honorific',
#   'young adult',
#   ','],
#  ['architect',
#   'a lawyer',
#   'Farmer',
#   'illusionist',
#   'a businessman',
#   'a forger',
#   'a journalist',
#   'lawyer',
#   'engineer',
#   'doctor'],
#  ['Manoj Kumar',
#   'Ram Gopal Varma',
#   'Ramesh Sippy',
#   'Ram Gopal Verma',
#   'Vikram Bhatt',
#   'Ramesh Talwar',
#   'Jeetendra',
#   'Mani Kaul',
#   'Kundan Shah',
#   'Jeetu Kohli'],
#  ['Polish',
#   'European Union',
#   'Polish citizenship',
#   'Polish citizen',
#   'Poland',
#   'German',
#   'French',
#   'Polish citizens',
#   'EU citizen',
#   'German citizenship'],
#  ['The Temptations',
#   'T. Graham Brown',
#   '.38 Special',
#   'Carly Simon',
#   'Bo Diddley',
#   'Carrie Underwood',
#   '. RED',
#   'David Porter',
#   '. Yello',
#   'Dean Martin'],
#  ['Beauty and the Beast',
#   'Zootopia',
#   'Planes',
#   'Peter Pan',
#   'Moana',
#   'Peter Rabbit',
#   'August 3, 2018',
#   'Tarzan',
#   'Beauty and The Beast',
#   'August 3, 2017'],
#  ['corning goblet',
#   'corning glass bottle',
#   'corning glass fragment',
#   'a meteor',
#   'corning glass mold',
#   'edifice',
#   'corningware',
#   'a meteorite',
#   'corning glassware',
#   'asteroid'],
#  ['jazz',
#   'bom bip',
#   'bom-bang',
#   'Bomipristi',
#   'bomBom',
#   'Bomipants',
#   'bom bim',
#   'boma',
#   'Bomi',
#   'classical music'],
#  ['Old Norse',
#   'the Hungarian language',
#   'the Bulgarian language',
#   'the Mongol languages',
#   'the original is in Russian',
#   'the original is in Chinese',
#   'the original is in German',
#   'Old High German',
#   'the Czech language',
#   'the original is in Czech'],
#  ['Create a Sim',
#   'Freestyle',
#   'World Adventures',
#   'Single-player',
#   'Free-Range',
#   'Free Play',
#   'Free-form',
#   'Free roam',
#   'Free Mode',
#   'Create a Pet'],
#  ['Shipwrecks',
#   'Steam Locomotives',
#   'Steamships',
#   'Landed gentry',
#   'classified by type',
#   'Classification: Maritime',
#   'Maritime',
#   'Steam locomotives',
#   'Steamship',
#   'Maritime medieval art'],
#  ['American football',
#   'American football team',
#   'American football club',
#   'College football team',
#   'college football team',
#   'American football franchise',
#   'American football teams',
#   'American football Conference',
#   'College football',
#   'college football'],
#  ['the Netherlands',
#   'Netherlands',
#   'the United States',
#   'The Netherlands',
#   'the the Netherlands',
#   'the Low Countries',
#   'the Dutch',
#   'Belgium',
#   'Dutch',
#   'Holland'],
#  ['Citizen Kane',
#   'Of Mice and Men',
#   'The Godfather Part III',
#   'The Public Enemy',
#   'Toys "',
#   '100 Rifles',
#   'Toys"',
#   'Toys',
#   'Toy Story',
#   'Tobruk'],
#  ['Classical crossover',
#   'classical music',
#   'R&B',
#   'acoustic',
#   'a classical crossover artist',
#   'a variety of styles',
#   'adi pop',
#   'Classical',
#   'Classical music',
#   'Pop'],
#  ['American',
#   'United States',
#   'American basketball player',
#   'the United States',
#   'US citizen',
#   'United States citizen',
#   'American former player',
#   'Native American',
#   'American citizen',
#   'American actor'],
#  ['The Great Gatsby',
#   'The Last Picture Show',
#   'The Garden of Allah',
#   'The King and I',
#   'The Last of Sheila',
#   'Night of the Living Dead',
#   'The Carpetbaggers',
#   'The Last of His Tribe',
#   'The Robe',
#   'The Red Shoes'],
#  ['Moscow',
#   'Grodno',
#   'Minsk',
#   'Kiev, Ukraine',
#   'Saint Petersburg, Russia',
#   'Moscow, Russia',
#   'Leningrad',
#   'Moscow, USSR',
#   'the Russian Empire',
#   'Russia'],
#  ['Urban Western',
#   'Drama',
#   'Western',
#   'Narrative',
#   'American Western',
#   'Live Action',
#   'Live-action',
#   'Eastwood Comedy',
#   'Film noir',
#   'Urban western'],
#  ['Canada',
#   'New Zealand',
#   'Los Angeles',
#   'in Toronto',
#   'in Canada',
#   'Toronto',
#   'in Vancouver',
#   'Philippines',
#   'Ireland',
#   'Georgia'],
#  ['Asteroid',
#   'semi-node',
#   'NEO',
#   'asteroid',
#   'Near-Earth Object',
#   'near-Earth object',
#   'near-Earth-Object',
#   'near-earth-object',
#   'comet',
#   'a comet'],
#  ['Jerusalem',
#   'Bethlehem',
#   'Nablus',
#   'the city of Bethlehem',
#   'Nazareth',
#   'Jericho, West Bank',
#   'Jericho, near Jerusalem',
#   'Jericho, North Carolina',
#   'a small town in Israel',
#   'the city of Nablus'],
#  ['Capetian',
#   'the Bourbon family',
#   'the Bourbons',
#   'Bourbon',
#   'House of Bourbon',
#   'the Capetian family',
#   'Capetian family',
#   'Capetians',
#   'Valois',
#   'Capetian line'],
#  ['Norwegian',
#   'Danish',
#   'Church slang',
#   'Church Norwegian',
#   'Church-language',
#   'Swedish',
#   'Icelandic',
#   'Church German',
#   'Finnish',
#   'English'],
#  ['Louisville, Kentucky',
#   'St. Louis',
#   'Pittsburgh, Pennsylvania',
#   'in Louisville, Kentucky',
#   'Cincinnati, Ohio',
#   'Providence, Rhode Island',
#   'Baltimore',
#   'Indianapolis, Indiana',
#   'Memphis, Tennessee',
#   'St. Louis Missouri'],
#  ['Urban contemporary',
#   'Country',
#   'country music',
#   'R&B',
#   'Gospel',
#   'country music album',
#   'Country music',
#   'Country music album',
#   'Urban contemporary album',
#   'Hip hop'],
#  ['a typical Italian',
#   'atypical',
#   'a multi-cultural individual',
#   'a multi-cultural Italian',
#   'a sociologist',
#   'a conservative Christian democratic party',
#   'atypical Italian',
#   'a typical Italian politician',
#   'eunuch',
#   'Type A'],
#  ['Clear and Present Danger',
#   'Jack Reacher',
#   'The Bourne Identity',
#   'The Town',
#   'The Italian Job',
#   'Point Break',
#   'Unknown',
#   'Timecode',
#   'The Usual Suspect',
#   'Unknown (1995)'],
#  ['Akiva Goldsman',
#   'Akhtar',
#   'Quentin Tarantino',
#   'Sidney Sheldon',
#   'Akil Akkineni',
#   'Akil N. Shetty',
#   'Aki Kaurismaki',
#   'Akhtar Sheikh',
#   'William Goldman',
#   'Akiva Goldsman.'],
#  ['professional football player',
#   'a mine worker',
#   'a mining engineer',
#   'mine worker',
#   'mining engineer',
#   'silversmith',
#   'police officer',
#   'a miner',
#   'gold miner',
#   'a mining executive'],
#  ['Male',
#   'male',
#   'both male and female',
#   'Heterosexual',
#   'a male',
#   'young male model',
#   'both male and male',
#   "men's",
# ...
#   'The Little Hut'],
#  ['classical music',
#   'jazz',
#   'chamber music',
#   'Classical music',
#   'Classical',
#   'Chamber music',
#   'Chamber Music',
#   'Jazz',
#   'concertos',
#   'opera'],
#  ['male',
#   'intersex',
#   'both male and female',
#   'two-gender',
#   'a boy',
#   'two-sex',
#   'Intersex',
#   'androgynous',
#   'Métis',
#   'both male and gay'],
#  ['Steven Spielberg',
#   'Ellie Kemper',
#   'Steve Carell',
#   'Danny Trejo',
#   'Douglas Adams',
#   'Peter Dinklage',
#   'Danny Glover',
#   'Daniel Handler',
#   'Ellie Kempner',
#   'Ellie Kempen'],
#  ['New Zealand',
#   'Northern Ireland',
#   'South Africa',
#   'Australia',
#   'United Kingdom',
#   'Canada',
#   'United States',
#   'Scotland',
#   'England',
#   'South African'],
#  ['French',
#   'English',
#   'American English',
#   'Quebec French',
#   'Canadian French',
#   'Portuguese',
#   'Mandarin',
#   'Dutch',
#   'Canadian English',
#   'French Canada'],
#  ['Alex Ross',
#   'Johnny Lange',
#   'Johnny Van Zant',
#   'Dean Jeffries',
#   'Ross Halfin',
#   'Rockwell',
#   'Rock Art',
#   'Johnny Juliano',
#   'artist Ronnie Wood',
#   'Dean'],
#  ['San Francisco',
#   'Los Angeles',
#   'San Diego, California',
#   'Santa Monica, California',
#   'Seattle, Washington',
#   'San Francisco, California',
#   'Vancouver, British Columbia',
#   'Berkeley, California',
#   'San Diego, CA',
#   'Santa Barbara, California'],
#  ['Ludwig van Beethoven',
#   'Ludwig Van Beethoven',
#   'Joseph Haydn',
#   'Wolfgang Amadeus Mozart',
#   'Johannes Brahms',
#   'Ludwig van Beethoven the Elder',
#   'Louis Spohr',
#   'Ludwig van Beethoven the younger',
#   'Ludwig van Beethovens',
#   'Ludwig van Beethoven.'],
#  ['John J. Montgomery',
#   'John Brashear',
#   'Edward A. Calahan',
#   'John Logie Baird',
#   'John Elder Robison',
#   'Professor Moritz von Jacobi',
#   'Professor Moriarty',
#   'John W. Griggs',
#   'Professor Dave Malloy',
#   'Professor Moritz Lazarus'],
#  ['Munich, Germany',
#   'Wiesbaden',
#   'in Bad Nauheim',
#   'Heidelberg, Germany',
#   'Merano',
#   'Graz, Austria',
#   'in Paris, France',
#   'Merano in Italy',
#   'Bad Nauheim',
#   'Munich'],
#  ['Drama',
#   'Gothic',
#   'Gothic fiction',
#   'Classics',
#   'period drama',
#   'Classical',
#   'Classic Drama',
#   'Masterpiece',
#   'Classic',
#   'Fantasy'],
#  ['Louis Vuitton',
#   'Louis Roederer',
#   'Jacques Tortet',
#   'Louis Dreyfus',
#   'Louis XIII',
#   'Hennessy',
#   'Jacques Vert',
#   'Jacques Tortorella',
#   'drogo parent',
#   'Jacques Torte'],
#  ['Female',
#   'male',
#   'she-girl',
#   'she-boy',
#   'she-male',
#   'she/her',
#   'she-',
#   'Male',
#   'female',
#   'she'],
#  ['Stillwater, Minnesota',
#   'Chicago',
#   'from the north of Ireland',
#   'Galway, Ireland',
#   'Chicago, Illinois',
#   'Los Angeles, California',
#   'Wicklow, Ireland',
#   'New Zealand',
#   'from Boston',
#   'from Chicago'],
#  ['Hong Kong',
#   'a new beginning',
#   'Mainland China',
#   'a new start',
#   'a foreign country',
#   'a business trip',
#   'a different country',
#   'hong kong',
#   'HK',
#   ''],
#  ['Cameroon',
#   'South Sudan',
#   'Lubumbashi, Japan',
#   'Zimbabwe',
#   'Mbarara, Zimbabwe',
#   'Lubumbashi, Tanzania',
#   'Kenya',
#   'Tanzania',
#   'Mbarara',
#   'Uganda'],
#  ['United States',
#   'the United States',
#   'Australia',
#   'United Kingdom',
#   'New Zealand',
#   'South Africa',
#   'the United Kingdom',
#   'Grenada',
#   'Canada',
#   'the Bahamas'],
#  ['feature-length drama',
#   'conventional Hollywood Westerns',
#   'Feature film',
#   'conventional Hollywood westerns',
#   'a democratic medium',
#   'socialist Westerns',
#   'assorted creams',
#   'Socialist Realist',
#   'cheap film',
#   'feature film'],
#  ['John Myung',
#   'Jeff Wayne',
#   'Jeff Lynne',
#   'Jeff Buckley',
#   'Maynard Ferguson',
#   'Kerry Livgren',
#   'John Mayer',
#   'John Matthew Thiele',
#   'John Mark Nelson',
#   'John Matthew Thiessen'],
#  ['MCA Nashville',
#   'BNA Records',
#   'MCA Records',
#   'RCA Records',
#   'Sony BMG',
#   'Capitol CMG',
#   'Capitol Records',
#   'Capitol Nashville',
#   'MCA',
#   'RCA Victor'],
#  ['Australia',
#   'United States',
#   'the United States',
#   'England',
#   'native to Australia',
#   'native of Australia',
#   'New Zealand',
#   'Canada',
#   'native of Zimbabwe',
#   'Australian'],
#  ['Florence',
#   'Pesaro',
#   'Bologna, Italy',
#   'Modena',
#   'Modena, Italy',
#   'Arezzo, Italy',
#   'Florence (1537)',
#   'Forl',
#   'Cesena',
#   'Firenze'],
#  ['Male',
#   'male',
#   'a male',
#   'masculine',
#   'a boy',
#   'two males',
#   'Muslim Turks',
#   'Female',
#   'Muslim',
#   'female'],
#  ['male',
#   'Female',
#   'both male and female',
#   'a male',
#   "She's male",
#   'female',
#   'a male zombie',
#   'her male counterpart Timothy',
#   'her male companion Jin',
#   'Male'],
#  ['Brooklyn',
#   'Brooklyn, New York',
#   'New York City',
#   'the Bronx',
#   'The Bronx',
#   'Brooklyn New York City',
#   'Superman',
#   'in Brooklyn',
#   'National City',
#   'Canadian'],
#  ['male',
#   'Female',
#   'Male',
#   'a male',
#   'a boy',
#   'she is male',
#   'she/he',
#   'is male',
#   'she',
#   'female'],
#  ['Documentary',
#   'Comedy',
#   "Children's",
#   "children's",
#   'comedic',
#   'Musicals',
#   'Comedic',
#   'Psych',
#   'Drama',
#   'Musical'],
#  ['Melbourne, Australia',
#   'London',
#   'Brooklyn, New York',
#   'the Bronx',
#   'Sydney, Australia',
#   'New York City',
#   'Brighton Beach, Brooklyn',
#   'Brighton, England',
#   'Toronto, Ontario',
#   'Adelaide, Australia'],
#  ['Intersex',
#   'intersex',
#   'transgender',
#   'Transexual',
#   'a woman',
#   'Bisexual',
#   'bisexual',
#   'MTF',
#   'MINT',
#   'M'],
#  ['defensive back',
#   'Shooting guard',
#   'forward',
#   'left guard',
#   'a forward',
#   'center',
#   'defensive half',
#   'wide receiver',
#   'winger',
#   'wing'],
#  ['Mohsen Namjoo',
#   'Googoosh',
#   'Maryam Akhondy',
#   'Siavash Kasra',
#   'Ebi',
#   'Siavash Kasraian',
#   'Hayedeh',
#   'Maryam Namazie',
#   'Dariush Foroutan',
#   'Siavash Shams'],
#  ['The Kuiper belt',
#   'The asteroids',
#   'The Asteroid belt',
#   'The belt of the Solar System',
#   'The asteroid belt',
#   'The Asteroid Belt',
#   'The Main Belt',
#   'The Main belt',
#   'The belt of the Moon',
#   'The belt of the solar system'],
#  ['Pressburg, Austria',
#   'Vienna',
#   'Eisenstadt, Germany',
#   'Eisenstadt, Austria',
#   'Pressburg, Hungary',
#   'Pressburg, Pennsylvania',
#   'Debrecen',
#   'Wiener Neustadt',
#   'Pressburg, Germany',
#   'Buda'],
#  ['actress',
#   'television personality',
#   'professional basketball player',
#   'professional football player',
#   'professional tennis player',
#   'professional baseball player',
#   'TV presenter',
#   'Polish actress',
#   'political scientist',
#   'police officer'],
#  ['American',
#   'French',
#   'United States',
#   'Scottish',
#   'Canadian',
#   'both Canadian',
#   'Swiss',
#   'British',
#   'English',
#   'both American'],
#  ['male',
#   'both male and female',
#   'a male',
#   'Male',
#   'she-herself',
#   'Female',
#   'He/She',
#   'she-boy',
#   'FTM',
#   'He'],
#  ['The Nutty Professor',
#   'The Skulls',
#   'The Godfather Part III',
#   'The Naked Kiss',
#   'The Five Heartbeats',
#   'The Naked Gun',
#   'The Nanny Diaries',
#   'The Last Detail',
#   'The Graduate',
#   'The Paper'],
#  ['United States',
#   'Milwaukee, Wisconsin',
#   'Australia',
#   'Canada',
#   'the United States',
#   'Wisconsin',
#   'Australian',
#   'American',
#   'native of Wisconsin',
#   'Canadian'],
#  ['United Kingdom',
#   'United States',
#   'South Africa',
#   'Australia',
#   'Canada',
#   'New Zealand',
#   'Czech Republic',
#   'South Korea',
#   'France',
#   'Argentina'],
#  ['United States',
#   'the United States',
#   'Great Britain',
#   'the United Kingdom',
#   'United Kingdom',
#   'the UK',
#   'Britain',
#   'the US',
#   'the United states',
#   'England'],
#  ['Battleme',
#   'the Monkees',
#   'the Temptations',
#   'Public Enemy',
#   'the Residents',
#   'The Aquabats',
#   'Afroman',
#   'the Killers',
#   '??',
#   'the 69 Eyes'],
#  ['Virginia',
#   'Ohio',
#   'Montana',
#   'California',
#   'Kentucky',
#   'Missouri',
#   'Texas',
#   'Arkansas',
#   'Chicago',
#   'Connecticut'],
#  ['Alternative rock',
#   'Jazz',
#   'Pop',
#   'Classical crossover',
#   'Americana',
#   'French romantic album',
#   'jazz',
#   'American romantic pop',
#   'Motown',
#   'New Age'],
#  ['American',
#   'Canadian',
#   'German',
#   'American actress',
#   'Australian',
#   'Austrian',
#   'British',
#   'United States',
#   'american',
#   'American actor'],
#  ['David Puttnam',
#   'David Geffen',
#   'David L. Wolper',
#   'David Dhawan',
#   'David Heyman',
#   'Ashley Samuels',
#   'David Giler',
#   'David Merrick',
#   'Kundan Shah',
#   'David L. Hemphill'],
#  ['John Millington Synge',
#   "John O'Hara",
#   'John Ruskin',
#   'John Green',
#   'D. H. Lawrence',
#   "John O'London",
#   'John Boyne',
#   'John Henry Newman',
#   'John Updike',
#   'John Galsworthy'],
#  ['Nuremberg',
#   'in Basel, Switzerland',
#   'Nuremberg, Germany',
#   'Prussia',
#   'a small German town',
#   'Landshut, Germany',
#   'Danzig, Germany',
#   'Zürich, Switzerland',
#   'in the Palatinate',
#   'Augsburg, Germany'],
#  ['English',
#   'French',
#   'American English',
#   'German',
#   'in German',
#   'in French',
#   'in English',
#   'Polish',
#   'Swedish',
#   'in Norwegian'],
#  ['Königsberg',
#   'Lübeck',
#   'Berlin',
#   'Hamburg',
#   'Magdeburg',
#   'Lüneburg',
#   'Greifswald',
#   'Leipzig, Germany',
#   'Bremen',
#   'Stettin'],
#  ['Earth',
#   'Sun',
#   'asteroid belt',
#   'Ceres',
#   'asteroid',
#   'the Sun',
#   'Jupiter',
#   'Gas Giant Jupiter',
#   'Gas Giants',
#   'Gaspra'],
#  ['Female',
#   'both male and female',
#   'young stockbroker',
#   'young female journalist',
#   'young teenage actress',
#   'young teenage girl',
#   'young female explorer',
#   'young businesswoman',
#   'young female celebrity',
#   'young adult'],
#  ['Turku',
#   'Vyborg, Finland',
#   'Vyborg',
#   'Oulu, Finland',
#   'Vyborg, Sweden',
#   'Vaasa',
#   'Viipuri',
#   'Porvoo, Finland',
#   'Oulu',
#   'Pori, Finland'],
#  ['both male and female',
#   'six',
#   'both gay and straight',
#   'both male and male',
#   'both male and single',
#   'stafford',
#   'in real life',
#   'both young and old',
#   'in reality, younger',
#   'in reality, older'],
#  ['The Girl with the Dragon Tattoo',
#   'Clash of the Titans',
#   'Svengali',
#   'S. Darko',
#   'Friday the 13th',
#   'Snatch',
#   'Entombed',
#   'Slither',
#   'The Girl with The Dragon Tattoo',
#   'Friday the 13th Part III'],
#  ['beat poet',
#   'lawyer',
#   'United States Attorney',
#   'profiling the criminal',
#   'US Attorney',
#   'executive for the company',
#   'executive for the FBI',
#   'white house correspondent',
#   'criminal investigator',
#   'USP'],
#  ['Pop',
#   'R&B',
#   'Alternative rock',
#   'soul',
#   'classical music',
#   'Mostly folk',
#   'Mostly Folk',
#   'jazz',
#   'funk',
#   'Jazz'],
#  ['comet',
#   'Comet',
#   'near-Earth object',
#   'is a comet',
#   'A comet',
#   'Asteroid',
#   'meteorite',
#   'a comet',
#   'near-earth object',
#   'asteroids'],
#  ['liver cirrhosis',
#   'a fatal car accident',
#   'hanging from a hook',
#   'hanging',
#   'undisclosed illness',
#   'an unspecified terminal illness',
#   'from a drug overdose',
#   'hanging incessantly',
#   'hanging glidge',
#   'heart defect'],
#  ['Emily Jane White',
#   'Merrill Garbus',
#   'Regina Spektor',
#   'Erin McKeown',
#   'Emily Haines',
#   'Amanda Palmer',
#   'Irisarri',
#   'Emily King',
#   'Irène Schweizer',
#   'Ira Wolf'],
#  ['Sailor Moon',
#   'Sailor Pluto',
#   'Rihanna',
#   'Rialle',
#   'Sailor V',
#   'Ophelia',
#   'Bella',
#   'Sailor Mars',
#   'Opal',
#   'Elizabeth'],
#  ['challenge mode',
#   'one-touch control',
#   'challenge',
#   'one-player mode',
#   'Bemani',
#   'beyblade',
#   'one-touch mode',
#   'beep mode',
#   'multiple-choice',
#   'one-player'],
#  ['American Samoa',
#   'Samoa',
#   'Samoan',
#   'Samoan Islands',
#   'Tonga',
#   'Samoana',
#   'Auckland, New Zealand',
#   'Samoan American',
#   'American Samoan',
#   'Fiji'],
#  ['United States',
#   'Scotland',
#   'Australia',
#   'Canada',
#   'New Zealand',
#   'Ireland',
#   'England',
#   'United Kingdom',
#   'Scottish',
#   'United states'],
#  ['of a brain tumor',
#   'from a drug overdose',
#   'a drug overdose',
#   'died of a brain tumor',
#   'a fatal car accident',
#   'a plane crash',
#   'in a plane crash',
#   'pancreatic cancer',
#   'drowned',
#   'died of a heart attack'],
#  ['Amadis of Gaul',
#   'King Clovis',
#   'Aiol of France',
#   'King Charlemagne',
#   'Aethelweard',
#   'Aeneas',
#   'Charles the Bald',
#   'Clothar II of France',
#   'Clothar I of France',
#   'Aiol'],
#  ['New York City',
#   'Brooklyn, New York',
#   'the Bronx',
#   'The Bronx',
#   'in New York City',
#   'New York city',
#   'Pittsburgh, Pennsylvania',
#   'New York',
#   'the United States',
#   'New York, NY'],
#  ['a microcontroller',
#   '65C02',
#   'a CPU',
#   '6520 sugawa',
#   '65C02S',
#   '6520 Integrated Circuit',
#   'a CPU assembly tool',
#   '6520 CPU',
#   'a CPU assembly line',
#   'a CPU 6520'],
#  ['guitar',
#   'finger snaps',
#   'electric guitar',
#   'banjo',
#   'Clavinet',
#   'bass',
#   'steel drums',
#   'cello',
#   'celesta',
#   'steel guitar'],
#  ['American Revolutionary War',
#   'American Revolution',
#   'American Civil War',
#   'American War of Independence',
#   'the American Civil War',
#   'War of 1812',
#   'the American Revolution',
#   'Mexican–American War',
#   'Northwest Indian War',
#   'American Revolutionary war'],
#  ['Mexico',
#   'San Diego, California',
#   'Santa Fe, New Mexico',
#   'Monterey, California',
#   'Havana, Cuba',
#   'San Francisco, California',
#   ', Arizona',
#   'San Diego, CA',
#   'Santiago, Chile',
#   'Mexico City'],
#  ['Glasgow, Scotland',
#   'Kingston, New York',
#   'Kingston upon Hull',
#   'Kingston, Jamaica',
#   'Brooklyn, New York',
#   'Lockport, Maryland',
#   'Lockport, Illinois',
#   'Georgetown, Texas',
#   'Belfast',
#   'Glasgow'],
#  ['The Merchant of Four Seasons',
#   'Veronika Voss',
#   'Caligari',
#   'Merchant-Ivory',
#   'Lili Marleen',
#   'Merchant Ivory',
#   'Alien from Lhasa',
#   'The Merchant of Venice',
#   'Night of the Living Dead',
#   'Querelle'],
#  ['Robert Richardson',
#   'Gordon Willis',
#   'Edward Lachman',
#   'Robert Richard Robbins',
#   'Robert Richard Edlund',
#   'Robert Richard Edwin Anderson',
#   'Robert De Niro',
#   'Robert Richard Ray',
#   'Robert Elswit',
#   'Robert Richards'],
#  ['asteroid',
#   'semi-nary particle',
#   'semi-solar planet',
#   'dwarf  comet',
#   'dwarf ecliptic',
#   'a comet',
#   'dwarf skimmer',
#   'dwarf nova',
#   'TNO',
#   'dwarf planet'],
#  ['forward',
#   'central forward',
#   'midfielder',
#   'winger',
#   'goalkeeper',
#   'striker',
#   'centre forward',
#   ' forward',
#   'central forwards',
#   'central midfield'],
#  ['Rama',
#   'the prophet Rama',
#   'Ramesses II',
#   'Aravan',
#   'his grandfather, Ram',
#   'Ram',
#   'prophet Rama',
#   'prophet Ram',
#   'his grandfather Rama',
#   'Aramazd'],
#  ['jazz',
#   'J-pop',
#   'benshi',
#   'Koto',
#   'Jazz',
#   'Japanese silent jazz',
#   'Japanese traditional music',
#   'Japanese classical music',
#   'Japanese silent wave',
#   'J-Pop'],
#  ['Johannes Vermeer',
#   'Nicolas Poussin',
#   'Van Gogh',
#   'Leonardo da Vinci',
#   'Claude Monet',
#   'Jan van Eyck',
#   'Peter Paul Rubens',
#   'El Greco',
#   'van Gogh',
#   'Rembrandt'],
#  ['the jungles of Burma',
#   'the place of Palms',
#   'the United States',
#   'the hospital at Hoboken',
#   'the evergreen state of Georgia',
#   'the glades of Arles',
#   'the Everglades',
#   'the clinic at the end of hallway',
#   'the evergreen state of North Carolina',
#   'the clinic at the university'],
#  ['Alex North',
#   'Ilaiyaraaja',
#   'Julius Packiam',
#   'Kalyanji Anandji',
#   'Laxmikant Pyarelal',
#   'Pentti Saarikoski',
#   '(Lisa Nordenström)',
#   'Pentti Sahni',
#   '(Lisa Nordenstrom)',
#   'Marco Beltrami'],
#  ['English',
#   'American English',
#   'French',
#   'Mandarin',
#   'German',
#   'Norwegian',
#   'English language',
#   'Japanese',
#   'Dutch',
#   'Italian'],
#  ['Joseph Estrada',
#   'Huey P. Long',
#   'Henry Clay',
#   'Hu Jintao',
#   "Martin O'Malley",
#   'Huey Long',
#   'Millicent Fenwick',
#   'Adlai Stevenson',
#   'Huey P. Newton',
#   'Harold Stassen'],
#  ['Chamber music',
#   'World music',
#   'Jazz',
#   'jazz',
#   'world music',
#   'Popular music',
#   'Americana',
#   'Folk',
#   'Pop',
#   'Chamber Music'],
#  ['Tesla, Inc.',
#   'Tesla Motors',
#   'Tesla Inc.',
#   'Tesla, Inc',
#   'Tesla, Ltd.',
#   'Tesla, LLC',
#   'Tesla motors',
#   'Tesla Electric Motors',
#   'The Tesla Motor Company',
#   'the Tesla Motor Company'],
#  ['Collins',
#   'Michael Collins',
#   'Collins Resistor',
#   'Collins Reservoir',
#   'Collins Master Module',
#   'Collins Flight Research Laboratory',
#   'Collins Reservisor',
#   'Collins Flight Facility',
#   'the Collins Camera',
#   'Collins Act'],
#  ['Dzsudzsák',
#   'Dániel Böde',
#   'Dávid',
#   'Márton Fülöp',
#   'Dávid Kovács',
#   'Zoltán Czibor',
#   'Dávid György',
#   'Dávid Gyepes',
#   'Péter Halmosi',
#   'Dániel Berkes'],
#  ...]

# %%
sq_test_answers = np.array([[el] for el in list(np.load("simple_questions_test.npy")[:,2])])
sq_test_answers
# Out:
# array([['Q1637790'],
#        ['Q12152'],
#        ['Q6581097'],
#        ...,
#        ['Q145'],
#        ['Q1748'],
#        ['Q3863']], dtype='<U9')

# %%
rubq_test_answers
# Out:
# array([list(['Q7944', 'Q60186', 'Q167903', 'Q2580904', 'Q5975740', 'Q7692360']),
#        list(['Q102513']), list(['Q692']), ..., list(['Q130777']),
#        list(['Q76432', 'Q76745', 'Q76747']), list(['Q11570'])],
#       dtype=object)

# %% [markdown]
# ### entropy

# %%
num_quantiles = 20

quants = [thresh / num_quantiles for thresh in range(1, num_quantiles+1)]
entropies = [scipy.stats.entropy(i) for i in probas_sq]
thresholds_entropy = [np.quantile(entropies, q) for q in quants]

accuracy_for_each_topk_entropy = []

#top_k pred
for top_k in [1, 2, 5, 10]:
    
    accuracy_for_each_quantile = {}

    for quantile in range(num_quantiles):

        # list of predictions_sq
        list_of_predictions_sq = list(compress(predictions_sq, entropies <= thresholds_entropy[quantile]))
        
        #list of correct answers
        list_of_correct_answers = list(compress(sq_test_answers[:sample_questions], entropies <= thresholds_entropy[quantile]))
        
        # choose top k predictions_sq
        top_k_list_of_predictions_sq = [i[:top_k] for i in list_of_predictions_sq]

        top_k_list_of_predicted_ids= []
        for sample in top_k_list_of_predictions_sq:
            new = []
            for prediction in sample:
                try:
                    x = from_text_to_id(prediction)
                except:
                    x = "None"
                new.append(x)

            top_k_list_of_predicted_ids.append(new)


        right = 0
        for i in range(len(list_of_correct_answers)):
            if any(item in top_k_list_of_predicted_ids[i] for item in list_of_correct_answers[i]):
                right += 1
            else:
                pass

        accuracy = np.round(right/len(list_of_correct_answers), 4)*100
        print(f"Top-{top_k} accuracy on the {(quantile+1)*(int(100/num_quantiles))}% the most confident from the entropy point of view = {accuracy}%")

        accuracy_for_each_quantile[(quantile+1)*(int(100/num_quantiles))] = accuracy
        accuracy_for_each_topk_entropy.append(accuracy_for_each_quantile)
        
    print("\n")
# Out:
# Top-1 accuracy on the 5% the most confident from the entropy point of view = 27.73%
# Top-1 accuracy on the 10% the most confident from the entropy point of view = 23.32%
# Top-1 accuracy on the 15% the most confident from the entropy point of view = 20.06%
# Top-1 accuracy on the 20% the most confident from the entropy point of view = 19.45%
# Top-1 accuracy on the 25% the most confident from the entropy point of view = 18.099999999999998%
# Top-1 accuracy on the 30% the most confident from the entropy point of view = 17.04%
# Top-1 accuracy on the 35% the most confident from the entropy point of view = 16.12%
# Top-1 accuracy on the 40% the most confident from the entropy point of view = 14.99%
# Top-1 accuracy on the 45% the most confident from the entropy point of view = 14.08%
# Top-1 accuracy on the 50% the most confident from the entropy point of view = 13.38%
# Top-1 accuracy on the 55% the most confident from the entropy point of view = 12.32%
# Top-1 accuracy on the 60% the most confident from the entropy point of view = 11.68%
# Top-1 accuracy on the 65% the most confident from the entropy point of view = 11.01%
# Top-1 accuracy on the 70% the most confident from the entropy point of view = 10.34%
# Top-1 accuracy on the 75% the most confident from the entropy point of view = 9.68%
# Top-1 accuracy on the 80% the most confident from the entropy point of view = 9.26%
# Top-1 accuracy on the 85% the most confident from the entropy point of view = 8.77%
# Top-1 accuracy on the 90% the most confident from the entropy point of view = 8.42%
# Top-1 accuracy on the 95% the most confident from the entropy point of view = 8.04%
# Top-1 accuracy on the 100% the most confident from the entropy point of view = 7.68%
#
#
# Top-2 accuracy on the 5% the most confident from the entropy point of view = 36.13%
# Top-2 accuracy on the 10% the most confident from the entropy point of view = 29.830000000000002%
# Top-2 accuracy on the 15% the most confident from the entropy point of view = 27.49%
# Top-2 accuracy on the 20% the most confident from the entropy point of view = 26.71%
# Top-2 accuracy on the 25% the most confident from the entropy point of view = 25.929999999999996%
# Top-2 accuracy on the 30% the most confident from the entropy point of view = 24.610000000000003%
# Top-2 accuracy on the 35% the most confident from the entropy point of view = 23.27%
# Top-2 accuracy on the 40% the most confident from the entropy point of view = 21.67%
# Top-2 accuracy on the 45% the most confident from the entropy point of view = 20.53%
# Top-2 accuracy on the 50% the most confident from the entropy point of view = 19.400000000000002%
# Top-2 accuracy on the 55% the most confident from the entropy point of view = 17.990000000000002%
# Top-2 accuracy on the 60% the most confident from the entropy point of view = 17.080000000000002%
# Top-2 accuracy on the 65% the most confident from the entropy point of view = 16.220000000000002%
# Top-2 accuracy on the 70% the most confident from the entropy point of view = 15.21%
# Top-2 accuracy on the 75% the most confident from the entropy point of view = 14.31%
# Top-2 accuracy on the 80% the most confident from the entropy point of view = 13.71%
# Top-2 accuracy on the 85% the most confident from the entropy point of view = 13.05%
# Top-2 accuracy on the 90% the most confident from the entropy point of view = 12.509999999999998%
# Top-2 accuracy on the 95% the most confident from the entropy point of view = 11.99%
# Top-2 accuracy on the 100% the most confident from the entropy point of view = 11.43%
#
#
# Top-5 accuracy on the 5% the most confident from the entropy point of view = 49.16%
# Top-5 accuracy on the 10% the most confident from the entropy point of view = 40.760000000000005%
# Top-5 accuracy on the 15% the most confident from the entropy point of view = 37.87%
# Top-5 accuracy on the 20% the most confident from the entropy point of view = 36.07%
# Top-5 accuracy on the 25% the most confident from the entropy point of view = 35.099999999999994%
# Top-5 accuracy on the 30% the most confident from the entropy point of view = 33.800000000000004%
# Top-5 accuracy on the 35% the most confident from the entropy point of view = 32.17%
# Top-5 accuracy on the 40% the most confident from the entropy point of view = 30.09%
# Top-5 accuracy on the 45% the most confident from the entropy point of view = 28.389999999999997%
# Top-5 accuracy on the 50% the most confident from the entropy point of view = 26.85%
# Top-5 accuracy on the 55% the most confident from the entropy point of view = 25.069999999999997%
# Top-5 accuracy on the 60% the most confident from the entropy point of view = 23.75%
# Top-5 accuracy on the 65% the most confident from the entropy point of view = 22.64%
# Top-5 accuracy on the 70% the most confident from the entropy point of view = 21.38%
# Top-5 accuracy on the 75% the most confident from the entropy point of view = 20.21%
# Top-5 accuracy on the 80% the most confident from the entropy point of view = 19.36%
# Top-5 accuracy on the 85% the most confident from the entropy point of view = 18.5%
# Top-5 accuracy on the 90% the most confident from the entropy point of view = 17.75%
# Top-5 accuracy on the 95% the most confident from the entropy point of view = 17.11%
# Top-5 accuracy on the 100% the most confident from the entropy point of view = 16.35%
#
#
# Top-10 accuracy on the 5% the most confident from the entropy point of view = 62.61%
# Top-10 accuracy on the 10% the most confident from the entropy point of view = 54.2%
# Top-10 accuracy on the 15% the most confident from the entropy point of view = 49.230000000000004%
# Top-10 accuracy on the 20% the most confident from the entropy point of view = 46.37%
# Top-10 accuracy on the 25% the most confident from the entropy point of view = 44.529999999999994%
# Top-10 accuracy on the 30% the most confident from the entropy point of view = 42.71%
# Top-10 accuracy on the 35% the most confident from the entropy point of view = 40.410000000000004%
# Top-10 accuracy on the 40% the most confident from the entropy point of view = 37.82%
# Top-10 accuracy on the 45% the most confident from the entropy point of view = 35.92%
# Top-10 accuracy on the 50% the most confident from the entropy point of view = 34.01%
# Top-10 accuracy on the 55% the most confident from the entropy point of view = 31.990000000000002%
# Top-10 accuracy on the 60% the most confident from the entropy point of view = 30.240000000000002%
# Top-10 accuracy on the 65% the most confident from the entropy point of view = 28.89%
# Top-10 accuracy on the 70% the most confident from the entropy point of view = 27.3%
# Top-10 accuracy on the 75% the most confident from the entropy point of view = 25.88%
# Top-10 accuracy on the 80% the most confident from the entropy point of view = 24.86%
# Top-10 accuracy on the 85% the most confident from the entropy point of view = 23.82%
# Top-10 accuracy on the 90% the most confident from the entropy point of view = 22.85%
# Top-10 accuracy on the 95% the most confident from the entropy point of view = 22.0%
# Top-10 accuracy on the 100% the most confident from the entropy point of view = 21.09%

# %%
font = {'family': 'serif',
            'color': 'darkred',
            'weight': 'normal',
            'size': 16
            }

font_title = {'family': 'serif',
              'color': 'darkred',
              'weight': 'normal',
              'size': 20
              }

plt.figure(figsize = (15, 9))
plt.title("Rejection curves based on Entropy for test set Simple Questions (4751 questions)", fontdict=font_title)

plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Entropy", c="blue", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Entropy", c="red", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Entropy", c="green", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Entropy", c="orange", marker='.', markersize=13, linewidth=0.8);


accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_Entropy_for_test_set_SQ_4751_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# ### maxprob

# %%
num_quantiles = 20

quants = [thresh / num_quantiles for thresh in range(0, num_quantiles)]
max_probs = [i[0] for i in probas_sq]
thresholds_maxprob = [np.quantile(max_probs, q) for q in quants]
thresholds_maxprob = thresholds_maxprob[::-1]

accuracy_for_each_topk_maxprob = []

#top_k pred
for top_k in [1, 2, 5, 10]:
    
    accuracy_for_each_quantile = {}

    for quantile in range(num_quantiles):

        # list of predictions_sq
        list_of_predictions_sq = list(compress(predictions_sq, max_probs >= thresholds_maxprob[quantile]))
        #print("len(list_of_predictions_sq)", len(list_of_predictions_sq))
        
        #list of correct answers
        list_of_correct_answers = list(compress(sq_test_answers[:sample_questions], max_probs >= thresholds_maxprob[quantile]))
        
        #print("list_of_correct_answers", list_of_correct_answers)
        
        # choose top k predictions_sq
        top_k_list_of_predictions_sq = [i[:top_k] for i in list_of_predictions_sq]

        top_k_list_of_predicted_ids= []
        for sample in top_k_list_of_predictions_sq:
            new = []
            for prediction in sample:
                try:
                    x = from_text_to_id(prediction)
                except:
                    x = "None"
                new.append(x)

            top_k_list_of_predicted_ids.append(new)

        #print("top_k_list_of_predicted_ids", top_k_list_of_predicted_ids)
        right = 0
        for i in range(len(list_of_correct_answers)):
            if any(item in top_k_list_of_predicted_ids[i] for item in list_of_correct_answers[i]):
                right += 1
            else:
                pass

        accuracy = np.round(right/len(list_of_correct_answers), 4)*100
        print(f"Top-{top_k} accuracy on the {(quantile+1)*(int(100/num_quantiles))}% the most confident from the Maxprob point of view = {accuracy}%")

        accuracy_for_each_quantile[(quantile+1)*(int(100/num_quantiles))] = accuracy
        accuracy_for_each_topk_maxprob.append(accuracy_for_each_quantile)
        
    print("\n")
# Out:
# Top-1 accuracy on the 5% the most confident from the Maxprob point of view = 28.15%
# Top-1 accuracy on the 10% the most confident from the Maxprob point of view = 22.900000000000002%
# Top-1 accuracy on the 15% the most confident from the Maxprob point of view = 20.62%
# Top-1 accuracy on the 20% the most confident from the Maxprob point of view = 19.77%
# Top-1 accuracy on the 25% the most confident from the Maxprob point of view = 18.27%
# Top-1 accuracy on the 30% the most confident from the Maxprob point of view = 17.11%
# Top-1 accuracy on the 35% the most confident from the Maxprob point of view = 16.0%
# Top-1 accuracy on the 40% the most confident from the Maxprob point of view = 15.2%
# Top-1 accuracy on the 45% the most confident from the Maxprob point of view = 14.13%
# Top-1 accuracy on the 50% the most confident from the Maxprob point of view = 13.3%
# Top-1 accuracy on the 55% the most confident from the Maxprob point of view = 12.32%
# Top-1 accuracy on the 60% the most confident from the Maxprob point of view = 11.61%
# Top-1 accuracy on the 65% the most confident from the Maxprob point of view = 11.01%
# Top-1 accuracy on the 70% the most confident from the Maxprob point of view = 10.4%
# Top-1 accuracy on the 75% the most confident from the Maxprob point of view = 9.82%
# Top-1 accuracy on the 80% the most confident from the Maxprob point of view = 9.29%
# Top-1 accuracy on the 85% the most confident from the Maxprob point of view = 8.84%
# Top-1 accuracy on the 90% the most confident from the Maxprob point of view = 8.44%
# Top-1 accuracy on the 95% the most confident from the Maxprob point of view = 8.07%
# Top-1 accuracy on the 100% the most confident from the Maxprob point of view = 7.68%
#
#
# Top-2 accuracy on the 5% the most confident from the Maxprob point of view = 36.55%
# Top-2 accuracy on the 10% the most confident from the Maxprob point of view = 29.409999999999997%
# Top-2 accuracy on the 15% the most confident from the Maxprob point of view = 27.21%
# Top-2 accuracy on the 20% the most confident from the Maxprob point of view = 26.5%
# Top-2 accuracy on the 25% the most confident from the Maxprob point of view = 25.169999999999998%
# Top-2 accuracy on the 30% the most confident from the Maxprob point of view = 24.12%
# Top-2 accuracy on the 35% the most confident from the Maxprob point of view = 22.61%
# Top-2 accuracy on the 40% the most confident from the Maxprob point of view = 21.51%
# Top-2 accuracy on the 45% the most confident from the Maxprob point of view = 20.11%
# Top-2 accuracy on the 50% the most confident from the Maxprob point of view = 19.189999999999998%
# Top-2 accuracy on the 55% the most confident from the Maxprob point of view = 17.91%
# Top-2 accuracy on the 60% the most confident from the Maxprob point of view = 16.91%
# Top-2 accuracy on the 65% the most confident from the Maxprob point of view = 16.13%
# Top-2 accuracy on the 70% the most confident from the Maxprob point of view = 15.27%
# Top-2 accuracy on the 75% the most confident from the Maxprob point of view = 14.48%
# Top-2 accuracy on the 80% the most confident from the Maxprob point of view = 13.79%
# Top-2 accuracy on the 85% the most confident from the Maxprob point of view = 13.13%
# Top-2 accuracy on the 90% the most confident from the Maxprob point of view = 12.540000000000001%
# Top-2 accuracy on the 95% the most confident from the Maxprob point of view = 11.99%
# Top-2 accuracy on the 100% the most confident from the Maxprob point of view = 11.43%
#
#
# Top-5 accuracy on the 5% the most confident from the Maxprob point of view = 49.58%
# Top-5 accuracy on the 10% the most confident from the Maxprob point of view = 40.339999999999996%
# Top-5 accuracy on the 15% the most confident from the Maxprob point of view = 36.89%
# Top-5 accuracy on the 20% the most confident from the Maxprob point of view = 35.44%
# Top-5 accuracy on the 25% the most confident from the Maxprob point of view = 33.5%
# Top-5 accuracy on the 30% the most confident from the Maxprob point of view = 32.4%
# Top-5 accuracy on the 35% the most confident from the Maxprob point of view = 31.209999999999997%
# Top-5 accuracy on the 40% the most confident from the Maxprob point of view = 29.459999999999997%
# Top-5 accuracy on the 45% the most confident from the Maxprob point of view = 27.92%
# Top-5 accuracy on the 50% the most confident from the Maxprob point of view = 26.35%
# Top-5 accuracy on the 55% the most confident from the Maxprob point of view = 24.759999999999998%
# Top-5 accuracy on the 60% the most confident from the Maxprob point of view = 23.61%
# Top-5 accuracy on the 65% the most confident from the Maxprob point of view = 22.64%
# Top-5 accuracy on the 70% the most confident from the Maxprob point of view = 21.47%
# Top-5 accuracy on the 75% the most confident from the Maxprob point of view = 20.43%
# Top-5 accuracy on the 80% the most confident from the Maxprob point of view = 19.55%
# Top-5 accuracy on the 85% the most confident from the Maxprob point of view = 18.65%
# Top-5 accuracy on the 90% the most confident from the Maxprob point of view = 17.8%
# Top-5 accuracy on the 95% the most confident from the Maxprob point of view = 17.06%
# Top-5 accuracy on the 100% the most confident from the Maxprob point of view = 16.35%
#
#
# Top-10 accuracy on the 5% the most confident from the Maxprob point of view = 63.870000000000005%
# Top-10 accuracy on the 10% the most confident from the Maxprob point of view = 53.36%
# Top-10 accuracy on the 15% the most confident from the Maxprob point of view = 47.55%
# Top-10 accuracy on the 20% the most confident from the Maxprob point of view = 44.79%
# Top-10 accuracy on the 25% the most confident from the Maxprob point of view = 42.17%
# Top-10 accuracy on the 30% the most confident from the Maxprob point of view = 41.02%
# Top-10 accuracy on the 35% the most confident from the Maxprob point of view = 39.33%
# Top-10 accuracy on the 40% the most confident from the Maxprob point of view = 37.03%
# Top-10 accuracy on the 45% the most confident from the Maxprob point of view = 35.13%
# Top-10 accuracy on the 50% the most confident from the Maxprob point of view = 33.42%
# Top-10 accuracy on the 55% the most confident from the Maxprob point of view = 31.46%
# Top-10 accuracy on the 60% the most confident from the Maxprob point of view = 30.020000000000003%
# Top-10 accuracy on the 65% the most confident from the Maxprob point of view = 28.79%
# Top-10 accuracy on the 70% the most confident from the Maxprob point of view = 27.389999999999997%
# Top-10 accuracy on the 75% the most confident from the Maxprob point of view = 26.16%
# Top-10 accuracy on the 80% the most confident from the Maxprob point of view = 25.069999999999997%
# Top-10 accuracy on the 85% the most confident from the Maxprob point of view = 23.919999999999998%
# Top-10 accuracy on the 90% the most confident from the Maxprob point of view = 22.869999999999997%
# Top-10 accuracy on the 95% the most confident from the Maxprob point of view = 21.98%
# Top-10 accuracy on the 100% the most confident from the Maxprob point of view = 21.09%

# %%
plt.figure(figsize = (15, 9))
plt.title("Rejection curves based on Maxprob for test set Simple Questions (4751 questions)", fontdict=font_title)
plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Maxprob", c="blue", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Maxprob", c="red", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Maxprob", c="green", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Maxprob", c="orange", marker='.', markersize=13, linewidth=0.8);


accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_Maxprob_for_test_set_SQ_4751_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# ### delta

# %%
num_quantiles = 20

quants = [thresh / num_quantiles for thresh in range(0, num_quantiles)]
deltas = [i[0] - i[1] for i in probas_sq]
thresholds_delta = [np.quantile(deltas, q) for q in quants]
thresholds_delta = thresholds_delta[::-1]

accuracy_for_each_topk_delta = []

#top_k pred
for top_k in [1, 2, 5, 10]:
    
    accuracy_for_each_quantile = {}

    for quantile in range(num_quantiles):

        # list of predictions_sq
        list_of_predictions_sq = list(compress(predictions_sq, deltas >= thresholds_delta[quantile]))
        print("len(list_of_predictions_sq)", len(list_of_predictions_sq))
        
        #print("list_of_predictions_sq", list_of_predictions_sq)
        
        #list of correct answers
        list_of_correct_answers = list(compress(sq_test_answers[:sample_questions], deltas >= thresholds_delta[quantile]))
        print("len(list_of_correct_answers)", len(list_of_correct_answers))
        
        # choose top k predictions_sq
        top_k_list_of_predictions_sq = [i[:top_k] for i in list_of_predictions_sq]
        
        top_k_list_of_predicted_ids= []
        for sample in top_k_list_of_predictions_sq:
            new = []
            for prediction in sample:
                try:
                    x = from_text_to_id(prediction)
                except:
                    x = "None"
                new.append(x)

            top_k_list_of_predicted_ids.append(new)
        
        print("len(top_k_list_of_predicted_ids)", len(top_k_list_of_predicted_ids))

        right = 0
        for i in range(len(list_of_correct_answers)):
            if any(item in top_k_list_of_predicted_ids[i] for item in list_of_correct_answers[i]):
                right += 1
            else:
                pass

        accuracy = np.round(right/len(list_of_correct_answers), 4)*100
        print(f"Top-{top_k} accuracy on the {(quantile+1)*(int(100/num_quantiles))}% the most confident from the Delta point of view = {accuracy}%")

        accuracy_for_each_quantile[(quantile+1)*(int(100/num_quantiles))] = accuracy
        accuracy_for_each_topk_delta.append(accuracy_for_each_quantile)
        
    print("\n")
# Out:
# len(list_of_predictions_sq) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-1 accuracy on the 5% the most confident from the Delta point of view = 27.73%
# len(list_of_predictions_sq) 476
# len(list_of_correct_answers) 476
# len(top_k_list_of_predicted_ids) 476
# Top-1 accuracy on the 10% the most confident from the Delta point of view = 21.64%
# len(list_of_predictions_sq) 713
# len(list_of_correct_answers) 713
# len(top_k_list_of_predicted_ids) 713
# Top-1 accuracy on the 15% the most confident from the Delta point of view = 20.9%
# len(list_of_predictions_sq) 951
# len(list_of_correct_answers) 951
# len(top_k_list_of_predicted_ids) 951
# Top-1 accuracy on the 20% the most confident from the Delta point of view = 19.35%
# len(list_of_predictions_sq) 1188
# len(list_of_correct_answers) 1188
# len(top_k_list_of_predicted_ids) 1188
# Top-1 accuracy on the 25% the most confident from the Delta point of view = 17.76%
# len(list_of_predictions_sq) 1426
# len(list_of_correct_answers) 1426
# len(top_k_list_of_predicted_ids) 1426
# Top-1 accuracy on the 30% the most confident from the Delta point of view = 16.689999999999998%
# len(list_of_predictions_sq) 1663
# len(list_of_correct_answers) 1663
# len(top_k_list_of_predicted_ids) 1663
# Top-1 accuracy on the 35% the most confident from the Delta point of view = 15.39%
# len(list_of_predictions_sq) 1901
# len(list_of_correct_answers) 1901
# len(top_k_list_of_predicted_ids) 1901
# Top-1 accuracy on the 40% the most confident from the Delta point of view = 14.469999999999999%
# len(list_of_predictions_sq) 2138
# len(list_of_correct_answers) 2138
# len(top_k_list_of_predicted_ids) 2138
# Top-1 accuracy on the 45% the most confident from the Delta point of view = 13.66%
# len(list_of_predictions_sq) 2376
# len(list_of_correct_answers) 2376
# len(top_k_list_of_predicted_ids) 2376
# Top-1 accuracy on the 50% the most confident from the Delta point of view = 12.790000000000001%
# len(list_of_predictions_sq) 2613
# len(list_of_correct_answers) 2613
# len(top_k_list_of_predicted_ids) 2613
# Top-1 accuracy on the 55% the most confident from the Delta point of view = 12.09%
# len(list_of_predictions_sq) 2851
# len(list_of_correct_answers) 2851
# len(top_k_list_of_predicted_ids) 2851
# Top-1 accuracy on the 60% the most confident from the Delta point of view = 11.26%
# len(list_of_predictions_sq) 3088
# len(list_of_correct_answers) 3088
# len(top_k_list_of_predicted_ids) 3088
# Top-1 accuracy on the 65% the most confident from the Delta point of view = 10.65%
# len(list_of_predictions_sq) 3326
# len(list_of_correct_answers) 3326
# len(top_k_list_of_predicted_ids) 3326
# Top-1 accuracy on the 70% the most confident from the Delta point of view = 10.07%
# len(list_of_predictions_sq) 3563
# len(list_of_correct_answers) 3563
# len(top_k_list_of_predicted_ids) 3563
# Top-1 accuracy on the 75% the most confident from the Delta point of view = 9.68%
# len(list_of_predictions_sq) 3801
# len(list_of_correct_answers) 3801
# len(top_k_list_of_predicted_ids) 3801
# Top-1 accuracy on the 80% the most confident from the Delta point of view = 9.21%
# len(list_of_predictions_sq) 4038
# len(list_of_correct_answers) 4038
# len(top_k_list_of_predicted_ids) 4038
# Top-1 accuracy on the 85% the most confident from the Delta point of view = 8.84%
# len(list_of_predictions_sq) 4276
# len(list_of_correct_answers) 4276
# len(top_k_list_of_predicted_ids) 4276
# Top-1 accuracy on the 90% the most confident from the Delta point of view = 8.44%
# len(list_of_predictions_sq) 4513
# len(list_of_correct_answers) 4513
# len(top_k_list_of_predicted_ids) 4513
# Top-1 accuracy on the 95% the most confident from the Delta point of view = 8.07%
# len(list_of_predictions_sq) 4751
# len(list_of_correct_answers) 4751
# len(top_k_list_of_predicted_ids) 4751
# Top-1 accuracy on the 100% the most confident from the Delta point of view = 7.68%
#
#
# len(list_of_predictions_sq) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-2 accuracy on the 5% the most confident from the Delta point of view = 35.29%
# len(list_of_predictions_sq) 476
# len(list_of_correct_answers) 476
# len(top_k_list_of_predicted_ids) 476
# Top-2 accuracy on the 10% the most confident from the Delta point of view = 28.15%
# len(list_of_predictions_sq) 713
# len(list_of_correct_answers) 713
# len(top_k_list_of_predicted_ids) 713
# Top-2 accuracy on the 15% the most confident from the Delta point of view = 26.650000000000002%
# len(list_of_predictions_sq) 951
# len(list_of_correct_answers) 951
# len(top_k_list_of_predicted_ids) 951
# Top-2 accuracy on the 20% the most confident from the Delta point of view = 25.97%
# len(list_of_predictions_sq) 1188
# len(list_of_correct_answers) 1188
# len(top_k_list_of_predicted_ids) 1188
# Top-2 accuracy on the 25% the most confident from the Delta point of view = 24.240000000000002%
# len(list_of_predictions_sq) 1426
# len(list_of_correct_answers) 1426
# len(top_k_list_of_predicted_ids) 1426
# Top-2 accuracy on the 30% the most confident from the Delta point of view = 23.14%
# len(list_of_predictions_sq) 1663
# len(list_of_correct_answers) 1663
# len(top_k_list_of_predicted_ids) 1663
# Top-2 accuracy on the 35% the most confident from the Delta point of view = 21.47%
# len(list_of_predictions_sq) 1901
# len(list_of_correct_answers) 1901
# len(top_k_list_of_predicted_ids) 1901
# Top-2 accuracy on the 40% the most confident from the Delta point of view = 20.04%
# len(list_of_predictions_sq) 2138
# len(list_of_correct_answers) 2138
# len(top_k_list_of_predicted_ids) 2138
# Top-2 accuracy on the 45% the most confident from the Delta point of view = 18.9%
# len(list_of_predictions_sq) 2376
# len(list_of_correct_answers) 2376
# len(top_k_list_of_predicted_ids) 2376
# Top-2 accuracy on the 50% the most confident from the Delta point of view = 17.72%
# len(list_of_predictions_sq) 2613
# len(list_of_correct_answers) 2613
# len(top_k_list_of_predicted_ids) 2613
# Top-2 accuracy on the 55% the most confident from the Delta point of view = 16.99%
# len(list_of_predictions_sq) 2851
# len(list_of_correct_answers) 2851
# len(top_k_list_of_predicted_ids) 2851
# Top-2 accuracy on the 60% the most confident from the Delta point of view = 16.03%
# len(list_of_predictions_sq) 3088
# len(list_of_correct_answers) 3088
# len(top_k_list_of_predicted_ids) 3088
# Top-2 accuracy on the 65% the most confident from the Delta point of view = 15.32%
# len(list_of_predictions_sq) 3326
# len(list_of_correct_answers) 3326
# len(top_k_list_of_predicted_ids) 3326
# Top-2 accuracy on the 70% the most confident from the Delta point of view = 14.610000000000001%
# len(list_of_predictions_sq) 3563
# len(list_of_correct_answers) 3563
# len(top_k_list_of_predicted_ids) 3563
# Top-2 accuracy on the 75% the most confident from the Delta point of view = 14.030000000000001%
# len(list_of_predictions_sq) 3801
# len(list_of_correct_answers) 3801
# len(top_k_list_of_predicted_ids) 3801
# Top-2 accuracy on the 80% the most confident from the Delta point of view = 13.420000000000002%
# len(list_of_predictions_sq) 4038
# len(list_of_correct_answers) 4038
# len(top_k_list_of_predicted_ids) 4038
# Top-2 accuracy on the 85% the most confident from the Delta point of view = 12.879999999999999%
# len(list_of_predictions_sq) 4276
# len(list_of_correct_answers) 4276
# len(top_k_list_of_predicted_ids) 4276
# Top-2 accuracy on the 90% the most confident from the Delta point of view = 12.370000000000001%
# len(list_of_predictions_sq) 4513
# len(list_of_correct_answers) 4513
# len(top_k_list_of_predicted_ids) 4513
# Top-2 accuracy on the 95% the most confident from the Delta point of view = 11.88%
# len(list_of_predictions_sq) 4751
# len(list_of_correct_answers) 4751
# len(top_k_list_of_predicted_ids) 4751
# Top-2 accuracy on the 100% the most confident from the Delta point of view = 11.43%
#
#
# len(list_of_predictions_sq) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-5 accuracy on the 5% the most confident from the Delta point of view = 48.32%
# len(list_of_predictions_sq) 476
# len(list_of_correct_answers) 476
# len(top_k_list_of_predicted_ids) 476
# Top-5 accuracy on the 10% the most confident from the Delta point of view = 38.87%
# len(list_of_predictions_sq) 713
# len(list_of_correct_answers) 713
# len(top_k_list_of_predicted_ids) 713
# Top-5 accuracy on the 15% the most confident from the Delta point of view = 36.33%
# len(list_of_predictions_sq) 951
# len(list_of_correct_answers) 951
# len(top_k_list_of_predicted_ids) 951
# Top-5 accuracy on the 20% the most confident from the Delta point of view = 34.599999999999994%
# len(list_of_predictions_sq) 1188
# len(list_of_correct_answers) 1188
# len(top_k_list_of_predicted_ids) 1188
# Top-5 accuracy on the 25% the most confident from the Delta point of view = 32.49%
# len(list_of_predictions_sq) 1426
# len(list_of_correct_answers) 1426
# len(top_k_list_of_predicted_ids) 1426
# Top-5 accuracy on the 30% the most confident from the Delta point of view = 30.79%
# len(list_of_predictions_sq) 1663
# len(list_of_correct_answers) 1663
# len(top_k_list_of_predicted_ids) 1663
# Top-5 accuracy on the 35% the most confident from the Delta point of view = 28.92%
# len(list_of_predictions_sq) 1901
# len(list_of_correct_answers) 1901
# len(top_k_list_of_predicted_ids) 1901
# Top-5 accuracy on the 40% the most confident from the Delta point of view = 27.3%
# len(list_of_predictions_sq) 2138
# len(list_of_correct_answers) 2138
# len(top_k_list_of_predicted_ids) 2138
# Top-5 accuracy on the 45% the most confident from the Delta point of view = 26.05%
# len(list_of_predictions_sq) 2376
# len(list_of_correct_answers) 2376
# len(top_k_list_of_predicted_ids) 2376
# Top-5 accuracy on the 50% the most confident from the Delta point of view = 24.54%
# len(list_of_predictions_sq) 2613
# len(list_of_correct_answers) 2613
# len(top_k_list_of_predicted_ids) 2613
# Top-5 accuracy on the 55% the most confident from the Delta point of view = 23.73%
# len(list_of_predictions_sq) 2851
# len(list_of_correct_answers) 2851
# len(top_k_list_of_predicted_ids) 2851
# Top-5 accuracy on the 60% the most confident from the Delta point of view = 22.31%
# len(list_of_predictions_sq) 3088
# len(list_of_correct_answers) 3088
# len(top_k_list_of_predicted_ids) 3088
# Top-5 accuracy on the 65% the most confident from the Delta point of view = 21.37%
# len(list_of_predictions_sq) 3326
# len(list_of_correct_answers) 3326
# len(top_k_list_of_predicted_ids) 3326
# Top-5 accuracy on the 70% the most confident from the Delta point of view = 20.57%
# len(list_of_predictions_sq) 3563
# len(list_of_correct_answers) 3563
# len(top_k_list_of_predicted_ids) 3563
# Top-5 accuracy on the 75% the most confident from the Delta point of view = 19.79%
# len(list_of_predictions_sq) 3801
# len(list_of_correct_answers) 3801
# len(top_k_list_of_predicted_ids) 3801
# Top-5 accuracy on the 80% the most confident from the Delta point of view = 18.94%
# len(list_of_predictions_sq) 4038
# len(list_of_correct_answers) 4038
# len(top_k_list_of_predicted_ids) 4038
# Top-5 accuracy on the 85% the most confident from the Delta point of view = 18.279999999999998%
# len(list_of_predictions_sq) 4276
# len(list_of_correct_answers) 4276
# len(top_k_list_of_predicted_ids) 4276
# Top-5 accuracy on the 90% the most confident from the Delta point of view = 17.52%
# len(list_of_predictions_sq) 4513
# len(list_of_correct_answers) 4513
# len(top_k_list_of_predicted_ids) 4513
# Top-5 accuracy on the 95% the most confident from the Delta point of view = 16.97%
# len(list_of_predictions_sq) 4751
# len(list_of_correct_answers) 4751
# len(top_k_list_of_predicted_ids) 4751
# Top-5 accuracy on the 100% the most confident from the Delta point of view = 16.35%
#
#
# len(list_of_predictions_sq) 238
# len(list_of_correct_answers) 238
# len(top_k_list_of_predicted_ids) 238
# Top-10 accuracy on the 5% the most confident from the Delta point of view = 62.61%
# len(list_of_predictions_sq) 476
# len(list_of_correct_answers) 476
# len(top_k_list_of_predicted_ids) 476
# Top-10 accuracy on the 10% the most confident from the Delta point of view = 51.470000000000006%
# len(list_of_predictions_sq) 713
# len(list_of_correct_answers) 713
# len(top_k_list_of_predicted_ids) 713
# Top-10 accuracy on the 15% the most confident from the Delta point of view = 46.98%
# len(list_of_predictions_sq) 951
# len(list_of_correct_answers) 951
# len(top_k_list_of_predicted_ids) 951
# Top-10 accuracy on the 20% the most confident from the Delta point of view = 43.32%
# len(list_of_predictions_sq) 1188
# len(list_of_correct_answers) 1188
# len(top_k_list_of_predicted_ids) 1188
# Top-10 accuracy on the 25% the most confident from the Delta point of view = 40.82%
# len(list_of_predictions_sq) 1426
# len(list_of_correct_answers) 1426
# len(top_k_list_of_predicted_ids) 1426
# Top-10 accuracy on the 30% the most confident from the Delta point of view = 38.64%
# len(list_of_predictions_sq) 1663
# len(list_of_correct_answers) 1663
# len(top_k_list_of_predicted_ids) 1663
# Top-10 accuracy on the 35% the most confident from the Delta point of view = 36.26%
# len(list_of_predictions_sq) 1901
# len(list_of_correct_answers) 1901
# len(top_k_list_of_predicted_ids) 1901
# Top-10 accuracy on the 40% the most confident from the Delta point of view = 34.089999999999996%
# len(list_of_predictions_sq) 2138
# len(list_of_correct_answers) 2138
# len(top_k_list_of_predicted_ids) 2138
# Top-10 accuracy on the 45% the most confident from the Delta point of view = 32.879999999999995%
# len(list_of_predictions_sq) 2376
# len(list_of_correct_answers) 2376
# len(top_k_list_of_predicted_ids) 2376
# Top-10 accuracy on the 50% the most confident from the Delta point of view = 30.98%
# len(list_of_predictions_sq) 2613
# len(list_of_correct_answers) 2613
# len(top_k_list_of_predicted_ids) 2613
# Top-10 accuracy on the 55% the most confident from the Delta point of view = 29.849999999999998%
# len(list_of_predictions_sq) 2851
# len(list_of_correct_answers) 2851
# len(top_k_list_of_predicted_ids) 2851
# Top-10 accuracy on the 60% the most confident from the Delta point of view = 28.34%
# len(list_of_predictions_sq) 3088
# len(list_of_correct_answers) 3088
# len(top_k_list_of_predicted_ids) 3088
# Top-10 accuracy on the 65% the most confident from the Delta point of view = 27.169999999999998%
# len(list_of_predictions_sq) 3326
# len(list_of_correct_answers) 3326
# len(top_k_list_of_predicted_ids) 3326
# Top-10 accuracy on the 70% the most confident from the Delta point of view = 26.19%
# len(list_of_predictions_sq) 3563
# len(list_of_correct_answers) 3563
# len(top_k_list_of_predicted_ids) 3563
# Top-10 accuracy on the 75% the most confident from the Delta point of view = 25.290000000000003%
# len(list_of_predictions_sq) 3801
# len(list_of_correct_answers) 3801
# len(top_k_list_of_predicted_ids) 3801
# Top-10 accuracy on the 80% the most confident from the Delta point of view = 24.23%
# len(list_of_predictions_sq) 4038
# len(list_of_correct_answers) 4038
# len(top_k_list_of_predicted_ids) 4038
# Top-10 accuracy on the 85% the most confident from the Delta point of view = 23.45%
# len(list_of_predictions_sq) 4276
# len(list_of_correct_answers) 4276
# len(top_k_list_of_predicted_ids) 4276
# Top-10 accuracy on the 90% the most confident from the Delta point of view = 22.52%
# len(list_of_predictions_sq) 4513
# len(list_of_correct_answers) 4513
# len(top_k_list_of_predicted_ids) 4513
# Top-10 accuracy on the 95% the most confident from the Delta point of view = 21.759999999999998%
# len(list_of_predictions_sq) 4751
# len(list_of_correct_answers) 4751
# len(top_k_list_of_predicted_ids) 4751
# Top-10 accuracy on the 100% the most confident from the Delta point of view = 21.09%

# %%
plt.figure(figsize = (15, 9))
plt.title("Rejection curves based on Delta for test set Simple Questions (4751 questions)", fontdict=font_title)
plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Delta", c="blue", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Delta", c="red", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Delta", c="green", marker='.', markersize=13, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Delta", c="orange", marker='.', markersize=13, linewidth=0.8);


accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_Delta_for_test_set_SQ_4751_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# ### aggregation together for Simple Questions

# %%
plt.figure(figsize = (16, 13))
plt.title("Rejection curves based on Single model UE measures for test set Simple Questions (4751 questions)", fontdict=font_title)
plt.xlabel("Rejection rate, %", fontdict=font)
plt.ylabel("Accuracy, %", fontdict=font)
plt.xticks(ticks=np.arange(0, 100, step=5))
plt.grid(color='black', linewidth=0.15)


plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Delta", c="blue", marker='.', markersize=7, linewidth=1.5);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Maxprob", c="blue", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[:num_quantiles][0].values())),
         label=f"Top-{1} Accuracy via Entropy", c="blue", marker='.', markersize=7, linewidth=1.5, linestyle = ':');

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Delta", c="red", marker='.', markersize=9, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Maxprob", c="red", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[num_quantiles:2*num_quantiles][0].values())),
         label=f"Top-{2} Accuracy via Entropy", c="red", marker='.', markersize=7, linewidth=1.5, linestyle = ':');

plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Delta", c="green", marker='.', markersize=9, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Maxprob", c="green", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[2*num_quantiles:3*num_quantiles][0].values())),
         label=f"Top-{5} Accuracy via Entropy", c="green", marker='.', markersize=7, linewidth=1.5, linestyle = ':');


plt.plot(100 - np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Delta", c="orange", marker='.', markersize=9, linewidth=0.8);

plt.plot(100 - np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_maxprob[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Maxprob", c="orange", marker='.', markersize=7, linewidth=1.5, linestyle = '--');

plt.plot(100 - np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].keys())),
         np.array(list(accuracy_for_each_topk_entropy[3*num_quantiles:4*num_quantiles][0].values())),
         label=f"Top-{10} Accuracy via Entropy", c="orange", marker='.', markersize=7, linewidth=1.5, linestyle = ':');



accuracy_on_full_data_top_1 = np.array(list(accuracy_for_each_topk_delta[:num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_2 = np.array(list(accuracy_for_each_topk_delta[num_quantiles:2*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_5 = np.array(list(accuracy_for_each_topk_delta[2*num_quantiles:3*num_quantiles][0].values()))[-1]
accuracy_on_full_data_top_10 = np.array(list(accuracy_for_each_topk_delta[3*num_quantiles:4*num_quantiles][0].values()))[-1]

plt.annotate("{}".format(np.round(accuracy_on_full_data_top_1, 2)), (0 - 4.5, accuracy_on_full_data_top_1));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_2, 2)), (0 - 4.5, accuracy_on_full_data_top_2));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_5, 2)), (0 - 4.5, accuracy_on_full_data_top_5));
plt.annotate("{}".format(np.round(accuracy_on_full_data_top_10, 2)), (0 - 4.5, accuracy_on_full_data_top_10));

plt.legend(fontsize=16);

plt.savefig("QA_Rejection_curves_based_on_single_model_UE_mes_for_test_set_SQ_4751_questions_T5_XL_SSM_NQ_model.png", dpi = 900)

# %% [markdown]
# #### Some preparations

# %%
num_questions = 50
num_quantiles = 10

res = [topkSample(rubq_test["question"][i], model = t5_qa_model, tokenizer = t5_tok, max_output_length=128, num_beams=1, num_samples = 5) for i in range(num_questions)]
probs_for_examples = [[math.exp(float(j[1])) for j in i] for i in res]
quants = [thresh / num_quantiles for thresh in range(1, num_quantiles+1)]


entropies = [scipy.stats.entropy(i) for i in probs_for_examples]
thresholds_entropy = [np.quantile(entropies, q) for q in quants]

# for 5% -> 0
quantile = 0
list_of_predictions_with_log_scores = list(compress(res, entropies <= thresholds_entropy[quantile]))
list_of_correct_answers = list(compress(rubq_answers,  entropies <= thresholds_entropy[quantile]))
list_of_predictions = [[j[0] for j in i] for i in list_of_predictions_with_log_scores]

list_of_predicted_ids = []
for sample in list_of_predictions:
    new = []
    for prediction in sample:
        try:
            x = from_text_to_id(prediction)
        except:
            x = "None"
        new.append(x)

    list_of_predicted_ids.append(new)

# %%
probs_for_examples[0]
# Out:
# [0.053119500258598226,
#  3.5508785966658604e-05,
#  1.768943428297719e-05,
#  5.012966873274316e-06,
#  1.7772552668605872e-06]

# %%
np.round(probs_for_examples[0], 3)
# Out:
# array([0.053, 0.   , 0.   , 0.   , 0.   ])

# %%
scipy.special.softmax(probs_for_examples[0])
# Out:
# array([0.20863221, 0.197846  , 0.19784248, 0.19783997, 0.19783933])

# %%
list_of_predicted_ids
# Out:
# [['Q19660', 'Q46852', 'Q168057', 'Q79808', 'Q143079'],
#  ['None', 'None', 'None', 'None', 'None'],
#  ['Q5513433', 'None', 'None', 'None', 'None'],
#  ['Q174044', 'Q726105', 'Q19002866', 'None', 'None'],
#  ['Q1850', 'Q1854', 'Q1854', 'Q1850', 'Q19675'],
#  ['Q83406', 'Q43718', 'Q524085', 'Q335064', 'None'],
#  ['Q43718', 'Q7996', 'Q923', 'Q31034308', 'None'],
#  ['Q830561', 'None', 'None', 'None', 'None'],
#  ['Q704832', 'Q5794774', 'Q659592', 'None', 'None'],
#  ['None', 'None', 'None', 'None', 'None'],
#  ['None', 'Q4590630', 'None', 'None', 'Q4884552'],
#  ['Q15180', 'Q46118', 'None', 'None', 'None'],
#  ['Q394963', 'None', 'Q914218', 'None', 'None'],
#  ['Q184535', 'None', 'None', 'None', 'None'],
#  ['Q122263', 'Q2918819', 'Q2576', 'None', 'None'],
#  ['Q3427', 'Q313', 'Q793510', 'Q5598740', 'None'],
#  ['Q409760', 'None', 'None', 'Q318657', 'None'],
#  ['Q630823', 'Q2650702', 'Q917829', 'Q4051134', 'None'],
#  ['Q62272', 'None', 'None', 'None', 'None'],
#  ['Q153319', 'None', 'None', 'None', 'None'],
#  ['Q7200', 'Q7200', 'Q1975130', 'Q419866', 'None'],
#  ['Q5582', 'Q39931', 'Q4492684', 'Q650519', 'Q21121474'],
#  ['Q2623285', 'Q165721', 'None', 'Q2081557', 'None'],
#  ['Q18110', 'None', 'None', 'None', 'None'],
#  ['Q82925', 'Q1303942', 'Q5123750', 'None', 'None'],
#  ['Q5284', 'Q4459167', 'None', 'None', 'None'],
#  ['Q5513', 'Q5428', 'Q8060315', 'None', 'None'],
#  ['Q171242', 'Q50309080', 'None', 'None', 'None'],
#  ['Q218400', 'None', 'None', 'None', 'None'],
#  ['None', 'Q7753486', 'None', 'None', 'None'],
#  ['Q316861', 'None', 'None', 'None', 'None'],
#  ['Q7327', 'None', 'None', 'None', 'None'],
#  ['Q23664', 'Q7687', 'None', 'None', 'None'],
#  ['Q148', 'Q422429', 'Q112568', 'None', 'None'],
#  ['Q301219', 'None', 'None', 'Q7080062', 'None'],
#  ['Q1563530', 'Q3918484', 'None', 'None', 'None'],
#  ['Q262909', 'None', 'None', 'None', 'None'],
#  ['Q2313948', 'None', 'None', 'None', 'None'],
#  ['Q650324', 'Q219033', 'None', 'None', 'None'],
#  ['Q17714', 'Q315059', 'Q4352362', 'Q219206', 'Q1823362']]

# %%
list_of_correct_answers
# Out:
# [['Q19660'],
#  ['Q312480'],
#  ['Q43'],
#  ['Q49481'],
#  ['Q1850'],
#  ['Q1860923'],
#  ['Q57966'],
#  ['Q128790'],
#  ['Q11419'],
#  ['Q172911'],
#  ['Q891'],
#  ['Q790'],
#  ['Q149067'],
#  ['Q395', 'Q7754', 'Q41217', 'Q149999', 'Q56114489'],
#  ['Q157623'],
#  ['Q10484'],
#  ['Q130498'],
#  ['Q1918252'],
#  ['Q739362'],
#  ['Q240150'],
#  ['Q192239', 'Q12799318'],
#  ['Q4872'],
#  ['Q1369676'],
#  ['Q130531'],
#  ['Q42831'],
#  ['Q762'],
#  ['Q162737'],
#  ['Q320653'],
#  ['Q8006'],
#  ['Q715281'],
#  ['Q267861', 'Q1323788'],
#  ['Q269668'],
#  ['Q912050', 'Q2453629'],
#  ['Q69060'],
#  ['Q182101'],
#  ['Q711'],
#  ['Q167997'],
#  ['Q204138'],
#  ['Q236132', 'Q456257'],
#  ['Q17714']]

# %%
#top k accuracy
top_k = 5

right=0
for number_of_question, prediction in enumerate(list_of_predicted_ids):
    print("prediction:", prediction)
    top_k_preds = prediction[:top_k]
    print("top_k_preds:", top_k_preds)
    print("correct prediction", list_of_correct_answers[number_of_question])
    if any(item in top_k_preds for item in list_of_correct_answers[number_of_question]):
        right += 1
    else:
        pass
    
accuracy = np.round(right/len(list_of_predicted_ids), 2)*100
print(f"top {top_k} accuracy on the most certain by entropy {10*(quantile+1)}% quantile = ", accuracy)
# Out:
# prediction: ['Q19660', 'Q46852', 'Q168057', 'Q79808', 'Q143079']
# top_k_preds: ['Q19660', 'Q46852', 'Q168057', 'Q79808', 'Q143079']
# correct prediction ['Q19660']
# prediction: ['None', 'None', 'None', 'None', 'None']
# top_k_preds: ['None', 'None', 'None', 'None', 'None']
# correct prediction ['Q312480']
# prediction: ['Q5513433', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q5513433', 'None', 'None', 'None', 'None']
# correct prediction ['Q43']
# prediction: ['Q174044', 'Q726105', 'Q19002866', 'None', 'None']
# top_k_preds: ['Q174044', 'Q726105', 'Q19002866', 'None', 'None']
# correct prediction ['Q49481']
# prediction: ['Q1850', 'Q1854', 'Q1854', 'Q1850', 'Q19675']
# top_k_preds: ['Q1850', 'Q1854', 'Q1854', 'Q1850', 'Q19675']
# correct prediction ['Q1850']
# prediction: ['Q83406', 'Q43718', 'Q524085', 'Q335064', 'None']
# top_k_preds: ['Q83406', 'Q43718', 'Q524085', 'Q335064', 'None']
# correct prediction ['Q1860923']
# prediction: ['Q43718', 'Q7996', 'Q923', 'Q31034308', 'None']
# top_k_preds: ['Q43718', 'Q7996', 'Q923', 'Q31034308', 'None']
# correct prediction ['Q57966']
# prediction: ['Q830561', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q830561', 'None', 'None', 'None', 'None']
# correct prediction ['Q128790']
# prediction: ['Q704832', 'Q5794774', 'Q659592', 'None', 'None']
# top_k_preds: ['Q704832', 'Q5794774', 'Q659592', 'None', 'None']
# correct prediction ['Q11419']
# prediction: ['None', 'None', 'None', 'None', 'None']
# top_k_preds: ['None', 'None', 'None', 'None', 'None']
# correct prediction ['Q172911']
# prediction: ['None', 'Q4590630', 'None', 'None', 'Q4884552']
# top_k_preds: ['None', 'Q4590630', 'None', 'None', 'Q4884552']
# correct prediction ['Q891']
# prediction: ['Q15180', 'Q46118', 'None', 'None', 'None']
# top_k_preds: ['Q15180', 'Q46118', 'None', 'None', 'None']
# correct prediction ['Q790']
# prediction: ['Q394963', 'None', 'Q914218', 'None', 'None']
# top_k_preds: ['Q394963', 'None', 'Q914218', 'None', 'None']
# correct prediction ['Q149067']
# prediction: ['Q184535', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q184535', 'None', 'None', 'None', 'None']
# correct prediction ['Q395', 'Q7754', 'Q41217', 'Q149999', 'Q56114489']
# prediction: ['Q122263', 'Q2918819', 'Q2576', 'None', 'None']
# top_k_preds: ['Q122263', 'Q2918819', 'Q2576', 'None', 'None']
# correct prediction ['Q157623']
# prediction: ['Q3427', 'Q313', 'Q793510', 'Q5598740', 'None']
# top_k_preds: ['Q3427', 'Q313', 'Q793510', 'Q5598740', 'None']
# correct prediction ['Q10484']
# prediction: ['Q409760', 'None', 'None', 'Q318657', 'None']
# top_k_preds: ['Q409760', 'None', 'None', 'Q318657', 'None']
# correct prediction ['Q130498']
# prediction: ['Q630823', 'Q2650702', 'Q917829', 'Q4051134', 'None']
# top_k_preds: ['Q630823', 'Q2650702', 'Q917829', 'Q4051134', 'None']
# correct prediction ['Q1918252']
# prediction: ['Q62272', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q62272', 'None', 'None', 'None', 'None']
# correct prediction ['Q739362']
# prediction: ['Q153319', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q153319', 'None', 'None', 'None', 'None']
# correct prediction ['Q240150']
# prediction: ['Q7200', 'Q7200', 'Q1975130', 'Q419866', 'None']
# top_k_preds: ['Q7200', 'Q7200', 'Q1975130', 'Q419866', 'None']
# correct prediction ['Q192239', 'Q12799318']
# prediction: ['Q5582', 'Q39931', 'Q4492684', 'Q650519', 'Q21121474']
# top_k_preds: ['Q5582', 'Q39931', 'Q4492684', 'Q650519', 'Q21121474']
# correct prediction ['Q4872']
# prediction: ['Q2623285', 'Q165721', 'None', 'Q2081557', 'None']
# top_k_preds: ['Q2623285', 'Q165721', 'None', 'Q2081557', 'None']
# correct prediction ['Q1369676']
# prediction: ['Q18110', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q18110', 'None', 'None', 'None', 'None']
# correct prediction ['Q130531']
# prediction: ['Q82925', 'Q1303942', 'Q5123750', 'None', 'None']
# top_k_preds: ['Q82925', 'Q1303942', 'Q5123750', 'None', 'None']
# correct prediction ['Q42831']
# prediction: ['Q5284', 'Q4459167', 'None', 'None', 'None']
# top_k_preds: ['Q5284', 'Q4459167', 'None', 'None', 'None']
# correct prediction ['Q762']
# prediction: ['Q5513', 'Q5428', 'Q8060315', 'None', 'None']
# top_k_preds: ['Q5513', 'Q5428', 'Q8060315', 'None', 'None']
# correct prediction ['Q162737']
# prediction: ['Q171242', 'Q50309080', 'None', 'None', 'None']
# top_k_preds: ['Q171242', 'Q50309080', 'None', 'None', 'None']
# correct prediction ['Q320653']
# prediction: ['Q218400', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q218400', 'None', 'None', 'None', 'None']
# correct prediction ['Q8006']
# prediction: ['None', 'Q7753486', 'None', 'None', 'None']
# top_k_preds: ['None', 'Q7753486', 'None', 'None', 'None']
# correct prediction ['Q715281']
# prediction: ['Q316861', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q316861', 'None', 'None', 'None', 'None']
# correct prediction ['Q267861', 'Q1323788']
# prediction: ['Q7327', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q7327', 'None', 'None', 'None', 'None']
# correct prediction ['Q269668']
# prediction: ['Q23664', 'Q7687', 'None', 'None', 'None']
# top_k_preds: ['Q23664', 'Q7687', 'None', 'None', 'None']
# correct prediction ['Q912050', 'Q2453629']
# prediction: ['Q148', 'Q422429', 'Q112568', 'None', 'None']
# top_k_preds: ['Q148', 'Q422429', 'Q112568', 'None', 'None']
# correct prediction ['Q69060']
# prediction: ['Q301219', 'None', 'None', 'Q7080062', 'None']
# top_k_preds: ['Q301219', 'None', 'None', 'Q7080062', 'None']
# correct prediction ['Q182101']
# prediction: ['Q1563530', 'Q3918484', 'None', 'None', 'None']
# top_k_preds: ['Q1563530', 'Q3918484', 'None', 'None', 'None']
# correct prediction ['Q711']
# prediction: ['Q262909', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q262909', 'None', 'None', 'None', 'None']
# correct prediction ['Q167997']
# prediction: ['Q2313948', 'None', 'None', 'None', 'None']
# top_k_preds: ['Q2313948', 'None', 'None', 'None', 'None']
# correct prediction ['Q204138']
# prediction: ['Q650324', 'Q219033', 'None', 'None', 'None']
# top_k_preds: ['Q650324', 'Q219033', 'None', 'None', 'None']
# correct prediction ['Q236132', 'Q456257']
# prediction: ['Q17714', 'Q315059', 'Q4352362', 'Q219206', 'Q1823362']
# top_k_preds: ['Q17714', 'Q315059', 'Q4352362', 'Q219206', 'Q1823362']
# correct prediction ['Q17714']
# top 5 accuracy on the most certain by entropy 10% quantile =  8.0

# %%
right
# Out:
# 3

# %%
any(item in [4, 5] for item in [1, 5, 2, 3])
# Out:
# True

# %% [markdown]
# # 2) Experiments with baseline accuracy for different models (t5-3b-ssm, t5-3b-ssm-nq, t5-3b-ssm-nqo, t5-xl-ssm-nq)

# %% [markdown]
# # SQ test T5-3b model QA

# %%
sq_test_data = np.load("simple_questions_test.npy")

# %%
questions = sq_test_data[:,3]

# %%
answers = []
for i in tqdm(range(len(questions))):
    input_ids = t5_tok(questions[i], return_tensors="pt").input_ids
    input_ids = input_ids.to(device)
    gen_output = t5_qa_model.generate(input_ids)[0]
    answers.append(gen_output)
    
    
preds_sq = []
for x in answers:
    preds_sq.append(t5_tok.decode(x, skip_special_tokens=True))
# Out:
# 100%|██████████| 4751/4751 [23:36<00:00,  3.35it/s]

# %%
preds_id_sq = []
for i in range(len(preds_sq)):
    try:
        x = from_text_to_id(preds_sq[i])
    except:
        x = "None"
    
    preds_id_sq.append(x)

# %%
right_sq = 0
for i in tqdm(range(len(preds_id_sq))):
    if preds_id_sq[i] == sq_test_data[i,2]:
        right_sq += 1
    else:
        pass
# Out:
# 100%|██████████| 4751/4751 [00:00<00:00, 275339.40it/s]

# %%
right_sq/len(preds_id_sq)
# Out:
# 0.01768048831824879

# %%
#np.save("predictions_sq_test_t5_3b_vanilla.npy", np.array(preds_sq))

# %% [markdown]
# ## SQ another model

# %%
def check_t5_sq(t5_tok, t5_qa_model):
    
    sq_test_data = np.load("simple_questions_test.npy")
    questions = sq_test_data[:,3]


    answers = []
    for i in tqdm(range(len(questions))):
        input_ids = t5_tok(questions[i], return_tensors="pt").input_ids
        input_ids = input_ids.to(device)
        gen_output = t5_qa_model.generate(input_ids)[0]
        answers.append(gen_output)


    preds_sq = []
    for x in answers:
        preds_sq.append(t5_tok.decode(x, skip_special_tokens=True))


    preds_id_sq = []
    for i in range(len(preds_sq)):
        try:
            x = from_text_to_id(preds_sq[i])
        except:
            x = "None"

        preds_id_sq.append(x)

    right_sq = 0
    for i in tqdm(range(len(preds_id_sq))):
        if preds_id_sq[i] == sq_test_data[i,2]:
            right_sq += 1
        else:
            pass

    acc = right_sq/len(preds_id_sq)
    
    return acc, preds_id_sq

# %%
t5_qa_model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-3b-ssm-nq")#"google/t5-11b-ssm-tqa")
t5_tok = AutoTokenizer.from_pretrained("google/t5-3b-ssm-nq")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
t5_qa_model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
acc, preds_id_sq = check_t5_sq(t5_tok = t5_tok,
                               t5_qa_model = t5_qa_model)
# Out:
# 100%|██████████| 4751/4751 [10:18<00:00,  7.69it/s]
# 100%|██████████| 4751/4751 [00:00<00:00, 852716.77it/s]

# %%
print("top1 accuracy = ", acc)
# Out:
# top1 accuracy =  0.06819616922753105

# %%
np.load("simple_questions_test.npy")
# Out:
# array([['Q7358590', 'P20', 'Q1637790', 'Where did roger marquis die?'],
#        ['Q154335', 'P509', 'Q12152',
#         'what was the cause of death of yves klein?'],
#        ['Q62498', 'P21', 'Q6581097',
#         'how does engelbert zaschka identify?'],
#        ...,
#        ['Q7142651', 'P495', 'Q145',
#         'which country filmed passing shadows?'],
#        ['Q445899', 'P19', 'Q1748',
#         'Where was gunnar johansen born in Denmark??'],
#        ['Q582715', 'P31', 'Q3863',
#         'what celestial object is 2974 holden?']], dtype='<U101')

# %% [markdown]
# ## rubq

# %%
t5_qa_model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-3b-ssm-nq")#"google/t5-11b-ssm-tqa")
t5_tok = AutoTokenizer.from_pretrained("google/t5-3b-ssm-nq")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
t5_qa_model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
rubq_test = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")

answers = []
for i in tqdm(range(len(rubq_test))):
    input_ids = t5_tok(rubq_test[i], return_tensors="pt").input_ids
    input_ids = input_ids.to(device)
    gen_output = t5_qa_model.generate(input_ids)[0]
    answers.append(gen_output)
    
    
final = []
for x in answers:
    final.append(t5_tok.decode(x, skip_special_tokens=True))

    
#rubq_questions = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")
entities_test_rubq = np.load("entities_test_rubq.npy")
rubq_test = pd.DataFrame({"subject":entities_test_rubq, "question":rubq_test})
rubq_test_answers = np.load("all_rubq_test_answers_1_hop_uri.npy", allow_pickle=True)

# answers_rubq = []

# for lis in rubq_test_answers:
#     print(lis)
#     new = []
#     for element in lis:
#         new.append(get_description_name(element))

#     answers_rubq.append(new)
    
preds = []
for i in range(len(final)):
    try:
        x = from_text_to_id(final[i])
    except:
        x = "None"
    
    preds.append(x)
    
np.save("predictions_rubq_test_t5_3b_ssm_nq.npy", np.array(final))

answers_rubq = []

for lis in rubq_test_answers:
    print(lis)
    new = []
    for element in lis:
        new.append(element)

    answers_rubq.append(new)

right = 0

for i, ans in enumerate(answers_rubq):
    if preds[i] in ans:
        right += 1
    else:
        pass
    
print(f"Accuracy = {right/len(preds)}")
# Out:
# 100%|██████████| 1186/1186 [03:03<00:00,  6.46it/s]
# ['Q7944', 'Q60186', 'Q167903', 'Q2580904', 'Q5975740', 'Q7692360']
# ['Q102513']
# ['Q692']
# ['Q19660']
# ['Q6607', 'Q483994', 'Q626035', 'Q2643890', 'Q17172850']
# ['Q142']
# ['Q299687']
# ['Q312480']
# ['Q29']
# ['Q4022']
# ['Q796']
# ['Q38768', 'Q201605', 'Q1676638']
# ['Q22']
# ['Q11420', 'Q106500']
# ['Q4808485']
# ['Q2838011']
# ['Q9299872']
# ['Q2674728']
# ['Q1968651']
# ['Q1088']
# ['Q7737', 'Q29561']
# ['Q36124']
# ['Q43']
# ['Q49481']
# ['Q424', 'Q869', 'Q881']
# ['Q148', 'Q837']
# ['Q232']
# ['Q408']
# ['Q816']
# ['Q847', 'Q5377']
# ['Q30']
# ['Q1792']
# ['Q822290']
# ['Q1603']
# ['Q181306', 'Q213344', 'Q237367', 'Q1326237']
# ['Q237800']
# ['Q106151']
# ['Q201598']
# ['Q223134']
# ['Q106010']
# ['Q29445']
# ['Q40591', 'Q58784', 'Q295347', 'Q470600']
# ['Q1850']
# ['Q4719']
# ['Q157683']
# ['Q158491']
# ['Q62']
# ['Q24861']
# ['Q3787']
# ['Q8338', 'Q202027', 'Q17172850']
# ['Q55']
# ['Q19675']
# ['Q36180', 'Q82955', 'Q185351', 'Q333634', 'Q1209498', 'Q1297719', 'Q4964182', 'Q11774202', 'Q18814623']
# ['Q22']
# ['Q1048']
# ['Q9191']
# ['Q687']
# ['Q1860923']
# ['Q178577']
# ['Q199588']
# ['Q79759']
# ['Q31628']
# ['Q57966']
# ['Q133622']
# ['Q360292']
# ['Q128790']
# ['Q236233']
# ['Q152293']
# ['Q15862']
# ['Q723764']
# ['Q783']
# ['Q767288']
# ['Q31628']
# ['Q142']
# ['Q40357']
# ['Q1048']
# ['Q159']
# ['Q2064699', 'Q4304132']
# ['Q668']
# ['Q112']
# ['Q49111']
# ['Q131026']
# ['Q11419']
# ['Q6502703']
# ['Q172911']
# ['Q212115']
# ['Q1069868']
# ['Q897']
# ['Q869']
# ['Q41']
# ['Q10737']
# ['Q6862']
# ['Q40059']
# ['Q35591']
# ['Q2332']
# ['Q1205']
# ['Q31015', 'Q241214']
# ['Q586']
# ['Q891']
# ['Q1472', 'Q12133', 'Q35869', 'Q41083', 'Q110315', 'Q131742', 'Q147778', 'Q193894', 'Q653078', 'Q2025687', 'Q2035074', 'Q3144986']
# ['Q144144']
# ['Q34981']
# ['Q185027']
# ['Q47369']
# ['Q45']
# ['Q81214']
# ['Q51']
# ['Q4964182']
# ['Q46599']
# ['Q6816']
# ['Q46']
# ['Q1875']
# ['Q5470']
# ['Q165503']
# ['Q25261', 'Q46255']
# ['Q925']
# ['Q790']
# ['Q13695']
# ['Q24826']
# ['Q1035', 'Q82122']
# ['Q2568844']
# ['Q149067']
# ['Q170737']
# ['Q626']
# ['Q395', 'Q7754', 'Q41217', 'Q149999', 'Q56114489']
# ['Q157623']
# ['Q159']
# ['Q5592']
# ['Q626']
# ['Q28244']
# ['Q16559']
# ['Q944527']
# ['Q8027']
# ['Q70']
# ['Q10484']
# ['Q47059']
# ['Q93351']
# ['Q762']
# ['Q214196']
# ['Q130498']
# ['Q30204']
# ['Q157623']
# ['Q31']
# ['Q854']
# ['Q170513']
# ['Q5806']
# ['Q37853']
# ['Q1918252']
# ['Q34']
# ['Q43106']
# ['Q5422']
# ['Q29445']
# ['Q219']
# ['Q664']
# ['Q13989']
# ['Q201330']
# ['Q84']
# ['Q2807']
# ['Q40']
# ['Q949424']
# ['Q935']
# ['Q4181867']
# ['Q109676']
# ['Q155626']
# ['Q1981162']
# ['Q33629']
# ['Q739362']
# ['Q211513', 'Q214666', 'Q319861']
# ['Q38']
# ['Q16']
# ['Q240150']
# ['Q192239', 'Q12799318']
# ['Q2736']
# ['Q2844']
# ['Q804']
# ['Q43105']
# ['Q150445']
# ['Q419']
# ['Q258', 'Q1013', 'Q1030']
# ['Q467118']
# ['Q424']
# ['Q739']
# ['Q38337']
# ['Q2044']
# ['Q44703']
# ['Q4872']
# ['Q145']
# ['Q4534523']
# ['Q7315']
# ['Q887']
# ['Q3114']
# ['Q16']
# ['Q36', 'Q211274']
# ['Q8743']
# ['Q154269', 'Q316417', 'Q336810', 'Q432752', 'Q463833']
# ['Q201330']
# ['Q1265']
# ['Q176371']
# ['Q131233']
# ['Q43279']
# ['Q3904', 'Q101418']
# ['Q9268']
# ['Q408']
# ['Q29']
# ['Q1369676']
# ['Q48103', 'Q857244', 'Q17232562']
# ['Q30']
# ['Q298', 'Q414']
# ['Q191159']
# ['Q9215']
# ['Q183']
# ['Q664']
# ['Q1460']
# ['Q851']
# ['Q40909']
# ['Q656']
# ['Q203236']
# ['Q14515330']
# ['Q8810']
# ['Q42941']
# ['Q1524']
# ['Q181114']
# ['Q129352']
# ['Q14773']
# ['Q36600']
# ['Q167420']
# ['Q83186']
# ['Q130531']
# ['Q167646', 'Q171839', 'Q736813']
# ['Q6585']
# ['Q811']
# ['Q835']
# ['Q45']
# ['Q408']
# ['Q42831']
# ['Q762']
# ['Q10686']
# ['Q1850']
# ['Q15807']
# ['Q1003']
# ['Q183']
# ['Q28']
# ['Q1532068']
# ['Q801']
# ['Q3859']
# ['Q170292', 'Q191105']
# ['Q127888']
# ['Q319708']
# ['Q25328']
# ['Q58035']
# ['Q468621', 'Q15071896']
# ['Q29', 'Q142']
# ['Q9191']
# ['Q38']
# ['Q164761', 'Q165704', 'Q170737', 'Q178108', 'Q180935', 'Q182570', 'Q185027', 'Q191691', 'Q334734', 'Q537769']
# ['Q43114']
# ['Q1726', 'Q131610']
# ['Q4412']
# ['Q501']
# ['Q205375', 'Q1281618', 'Q1930187']
# ['Q134942']
# ['Q4167647']
# ['Q162737']
# ['Q172089']
# ['Q34038']
# ['Q813']
# ['Q7947']
# ['Q215556']
# ['Q6934']
# ['Q33231', 'Q36180', 'Q49757', 'Q161944', 'Q170790', 'Q4853732', 'Q4964182', 'Q6625963', 'Q14565331', 'Q18814623', 'Q18939491']
# ['Q15208']
# ['Q916']
# ['Q35881']
# ['Q38']
# ['Q948']
# ['Q57479']
# ['Q265']
# ['Q320653']
# ['Q275354']
# ['Q8006']
# ['Q8409']
# ['Q60']
# ['Q193592']
# ['Q60']
# ['Q8678']
# ['Q718']
# ['Q1186567']
# ['Q1754954']
# ['Q155856']
# ['Q718']
# ['Q48211', 'Q297032']
# ['Q6574', 'Q6655']
# ['Q715281']
# ['Q47293']
# ['Q47293']
# ['Q4768']
# ['Q110228']
# ['Q193064']
# ['Q762']
# ['Q217128']
# ['Q183']
# ['Q170984', 'Q372254']
# ['Q741157']
# ['Q208008']
# ['Q212']
# ['Q131210']
# ['Q27911']
# ['Q34575']
# ['Q11629']
# ['Q83891']
# ['Q78707']
# ['Q9391']
# ['Q3926', 'Q5465', 'Q37701']
# ['Q44363', 'Q82586']
# ['Q592289']
# ['Q28603']
# ['Q219']
# ['Q32024']
# ['Q10570']
# ['Q188']
# ['Q184222']
# ['Q35657']
# ['Q267861', 'Q1323788']
# ['Q133026']
# ['Q33999', 'Q36834', 'Q49757', 'Q177220', 'Q183945', 'Q488205', 'Q662729', 'Q753110', 'Q1028181', 'Q13235160', 'Q16323111', 'Q29017403']
# ['Q148']
# ['Q36']
# ['Q28389', 'Q36180', 'Q49757', 'Q214917', 'Q482980', 'Q6625963']
# ['Q185118', 'Q81200227']
# ['Q38']
# ['Q164714']
# ['Q269668']
# ['Q4257378']
# ['Q151209']
# ['Q315185']
# ['Q716794']
# ['Q912050', 'Q2453629']
# ['Q6397066']
# ['Q186083']
# ['Q220437']
# ['Q14435']
# ['Q72']
# ['Q69060']
# ['Q182101']
# ['Q403']
# ['Q4202', 'Q5871']
# ['Q302849']
# ['Q326827']
# ['Q192134']
# ['Q183']
# ['Q845210']
# ['Q1773']
# ['Q1205']
# ['Q42574']
# ['Q155']
# ['Q333246']
# ['Q230']
# ['Q23124']
# ['Q170513']
# ['Q408']
# ['Q108316']
# ['Q819']
# ['Q11930']
# ['Q3711']
# ['Q47154']
# ['Q711']
# ['Q5338']
# ['Q200797']
# ['Q7200']
# ['Q21']
# ['Q51641', 'Q2907211', 'Q7311705', 'Q7796966', 'Q7796967', 'Q7796969', 'Q12403826', 'Q12403830', 'Q12404028', 'Q12408472', 'Q12408583', 'Q12408584']
# ['Q36834', 'Q486748']
# ['Q142']
# ['Q36215']
# ['Q167997']
# ['Q3915']
# ['Q3919']
# ['Q38111', 'Q41148', 'Q80966', 'Q160432', 'Q170572', 'Q179414', 'Q188772', 'Q192402', 'Q201842', 'Q223091', 'Q223110', 'Q233882', 'Q236613', 'Q241025', 'Q264996', 'Q310394', 'Q311453', 'Q357762', 'Q437752', 'Q481954', 'Q483379', 'Q536437', 'Q918404', 'Q1189169', 'Q1190406', 'Q1680304', 'Q2865151', 'Q3127916', 'Q3501718', 'Q3573721', 'Q25768136']
# ['Q258']
# ['Q183']
# ['Q1541']
# ['Q220']
# ['Q27']
# ['Q3844']
# ['Q204138']
# ['Q140001']
# ['Q1761', 'Q135501', 'Q659895', 'Q1263215', 'Q1672830', 'Q1766409', 'Q2062702', 'Q2088319', 'Q2350741', 'Q5242183', 'Q5500969', 'Q7417543', 'Q13156901', 'Q28601860']
# ['Q8338', 'Q17172850']
# ['Q2092607']
# ['Q236132', 'Q456257']
# ['Q150']
# ['Q683695']
# ['Q17714']
# ['Q69354']
# ['Q229107']
# ['Q17', 'Q188712']
# ['Q623']
# ['Q167646']
# ['Q212']
# ['Q34990']
# ['Q255']
# ['Q45765']
# ['Q31966']
# ['Q108429']
# ['Q155327']
# ['Q157065']
# ['Q1151']
# ['Q176371']
# ['Q656043']
# ['Q30']
# ['Q133274']
# ['Q935']
# ['Q41484']
# ['Q7364']
# ['Q34404']
# ['Q241']
# ['Q8343']
# ['Q40939']
# ['Q204627']
# ['Q894']
# ['Q170737']
# ['Q79']
# ['Q1554208', 'Q1969437']
# ['Q38']
# ['Q35500']
# ['Q1147806']
# ['Q645']
# ['Q5885', 'Q13267']
# ['Q5776']
# ['Q811']
# ['Q843']
# ['Q8667']
# ['Q152513']
# ['Q2133873']
# ['Q557323']
# ['Q695']
# ['Q7200']
# ['Q6607', 'Q17172850']
# ['Q8686']
# ['Q38']
# ['Q829']
# ['Q4214909']
# ['Q239337']
# ['Q42493']
# ['Q30']
# ['Q1069', 'Q8008', 'Q46255']
# ['Q1016']
# ['Q1029907']
# ['Q92600']
# ['Q326358']
# ['Q19566']
# ['Q25224', 'Q374453']
# ['Q28']
# ['Q2634']
# ['Q90', 'Q1017', 'Q173219']
# ['Q869']
# ['Q884']
# ['Q1472152']
# ['Q847']
# ['Q741710']
# ['Q656']
# ['Q368121']
# ['Q215901']
# ['Q1711']
# ['Q211260']
# ['Q1741']
# ['Q237105']
# ['Q714']
# ['Q171852']
# ['Q490']
# ['Q328523']
# ['Q129987']
# ['Q1962550']
# ['Q18013']
# ['Q3808']
# ['Q1533']
# ['Q76420']
# ['Q106151']
# ['Q37701']
# ['Q37137', 'Q186506']
# ['Q212']
# ['Q229']
# ['Q4321335']
# ['Q40901', 'Q44384']
# ['Q56005']
# ['Q129279']
# ['Q656']
# ['Q80137']
# ['Q836']
# ['Q43399']
# ['Q230']
# ['Q265']
# ['Q47163']
# ['Q53268']
# ['Q6839']
# ['Q408']
# ['Q271398']
# ['Q33999', 'Q36834', 'Q177220']
# ['Q158688']
# ['Q811']
# ['Q499980', 'Q838611']
# ['Q200905']
# ['Q318427']
# ['Q1542521', 'Q2419102']
# ['Q52607']
# ['Q37320']
# ['Q130752']
# ['Q408']
# ['Q45765']
# ['Q11895']
# ['Q272029', 'Q324319', 'Q327717', 'Q333146']
# ['Q8355']
# ['Q367120']
# ['Q460337']
# ['Q148']
# ['Q1213902', 'Q3129651']
# ['Q619584']
# ['Q3210067']
# ['Q276354']
# ['Q672936']
# ['Q44204']
# ['Q4214909']
# ['Q19100']
# ['Q298']
# ['Q2684']
# ['Q52535']
# ['Q15878']
# ['Q47190']
# ['Q379053']
# ['Q211']
# ['Q9726']
# ['Q924']
# ['Q308657']
# ['Q347685']
# ['Q199943']
# ['Q1043128']
# ['Q178780']
# ['Q47670']
# ['Q156711']
# ['Q545844']
# ['Q656']
# ['Q14712']
# ['Q40912']
# ['Q1930']
# ['Q142']
# ['Q914']
# ['Q6955']
# ['Q127429']
# ['Q97']
# ['Q3844557']
# ['Q5426']
# ['Q40640']
# ['Q230']
# ['Q149067', 'Q15072554', 'Q19799931']
# ['Q37030']
# ['Q41466']
# ['Q419']
# ['Q70981']
# ['Q96']
# ['Q2696558']
# ['Q471726', 'Q918057', 'Q1815797', 'Q3284950', 'Q5575842', 'Q21532983', 'Q28406292']
# ['Q502265']
# ['Q1248784']
# ['Q35610']
# ['Q5369']
# ['Q25344']
# ['Q1519']
# ['Q79804']
# ['Q45656']
# ['Q71']
# ['Q48']
# ['Q1780']
# ['Q49080']
# ['Q724254']
# ['Q49686']
# ['Q84']
# ['Q468467']
# ['Q228889']
# ['Q97', 'Q788']
# ['Q898']
# ['Q656']
# ['Q239']
# ['Q41211']
# ['Q668', 'Q843', 'Q889']
# ['Q23436']
# ['Q1218']
# ['Q170649']
# ['Q130777']
# ['Q862992']
# ['Q680161']
# ['Q379612']
# ['Q4329463']
# ['Q597']
# ['Q503166']
# ['Q23661']
# ['Q237']
# ['Q193592']
# ['Q41604']
# ['Q8717']
# ['Q1770']
# ['Q1435']
# ['Q201568']
# ['Q681697']
# ['Q7200']
# ['Q258']
# ['Q179620']
# ['Q1449']
# ['Q935']
# ['Q44395']
# ['Q159']
# ['Q30']
# ['Q9270']
# ['Q183']
# ['Q754837']
# ['Q12100']
# ['Q3783']
# ['Q28']
# ['Q156724']
# ['Q55208']
# ['Q4327225']
# ['Q25363']
# ['Q178']
# ['Q2263']
# ['Q753', 'Q1096']
# ['Q127892']
# ['Q146667']
# ['Q966571', 'Q2026876']
# ['Q1320718']
# ['Q925']
# ['Q727']
# ['Q171416']
# ['Q2625243']
# ['Q33']
# ['Q165769']
# ['Q717']
# ['Q30']
# ['Q29108']
# ['Q805221', 'Q805253', 'Q2490358', 'Q5716684', 'Q15296811', 'Q18939491']
# ['Q765633']
# ['Q571822']
# ['Q9671', 'Q169898']
# ['Q45']
# ['Q47774']
# ['Q913643']
# ['Q16320']
# ['Q2337']
# ['Q83459']
# ['Q36']
# ['Q106807']
# ['Q167551']
# ['Q326499']
# ['Q2981']
# ['Q145']
# ['Q21127485']
# ['Q38']
# ['Q15720844']
# ['Q748296']
# ['Q181678']
# ['Q4925477']
# ['Q155874']
# ['Q215548']
# ['Q140686', 'Q218295', 'Q842386', 'Q4109060', 'Q4127082', 'Q4399975', 'Q14805701', 'Q27494237', 'Q38715304', 'Q38715670', 'Q38715852']
# ['Q193018']
# ['Q202040']
# ['Q50546603']
# ['Q5254470']
# ['Q232']
# ['Q898795']
# ['Q41466']
# ['Q1615333', 'Q41795540']
# ['Q42267']
# ['Q271934']
# ['Q1875']
# ['Q18552177']
# ['Q29']
# ['Q1978556']
# ['Q57327']
# ['Q7205']
# ['Q673075']
# ['Q1417705']
# ['Q96', 'Q115', 'Q774', 'Q800']
# ['Q239']
# ['Q33244']
# ['Q926']
# ['Q2723928']
# ['Q645719']
# ['Q810']
# ['Q47064', 'Q82955']
# ['Q1891']
# ['Q159']
# ['Q840829', 'Q2359372']
# ['Q208588']
# ['Q61']
# ['Q902320']
# ['Q7604']
# ['Q3519259']
# ['Q1741']
# ['Q1761']
# ['Q818467']
# ['Q210287']
# ['Q182059']
# ['Q63991914']
# ['Q2333']
# ['Q35064']
# ['Q34']
# ['Q627508']
# ['Q18502']
# ['Q46']
# ['Q46', 'Q48']
# ['Q656']
# ['Q4183061']
# ['Q169898', 'Q171329', 'Q171367', 'Q172721']
# ['Q2359372']
# ['Q2245347', 'Q2914850', 'Q72553200', 'Q72553961']
# ['Q17501806']
# ['Q21891843', 'Q23820229', 'Q84499835', 'Q84565071', 'Q84566351', 'Q84572475', 'Q84572977', 'Q84593853', 'Q84599401', 'Q84682501', 'Q84763814', 'Q84947682', 'Q174248', 'Q378120', 'Q580728', 'Q600063', 'Q628212', 'Q662985', 'Q693350', 'Q744598', 'Q748211', 'Q753219', 'Q753289', 'Q753292', 'Q840751', 'Q868618', 'Q942842', 'Q1013032', 'Q1013035', 'Q1624461', 'Q1734030', 'Q1810336', 'Q1811143', 'Q1821473', 'Q1822800', 'Q1963689', 'Q1969345', 'Q1987157', 'Q1996280', 'Q2003486', 'Q2041885', 'Q2048241', 'Q2061921', 'Q2078708', 'Q2216373', 'Q2219104', 'Q2297365', 'Q2317527', 'Q2320562', 'Q2331979', 'Q2403918', 'Q2440414', 'Q2442419', 'Q2446033', 'Q2456160', 'Q2460331', 'Q2467285', 'Q2499127', 'Q2501433', 'Q2533951', 'Q2580968', 'Q2612318', 'Q2623877', 'Q2638290', 'Q2661930', 'Q2689681', 'Q2693443', 'Q2709316', 'Q2717469', 'Q2782104', 'Q2786011', 'Q2795720', 'Q2834321', 'Q3176913', 'Q3489924', 'Q3489932', 'Q3489935', 'Q3490214', 'Q3490254', 'Q3490377', 'Q3490395', 'Q3490530', 'Q3490542', 'Q3490548', 'Q3490702', 'Q3497283', 'Q3499350', 'Q3499380', 'Q3499395', 'Q3499402', 'Q3499406', 'Q3509023', 'Q3509048', 'Q3509354', 'Q3509373', 'Q3509425', 'Q3509446', 'Q3509457', 'Q3509657', 'Q3509772', 'Q3509780', 'Q3509815', 'Q3509834', 'Q3563089', 'Q3563100', 'Q3563133', 'Q3563146', 'Q3563211', 'Q3563232', 'Q3564567', 'Q3566327', 'Q3566606']
# ['Q13641190']
# ['Q2084341', 'Q3273932', 'Q4252909', 'Q4262671']
# ['Q612907', 'Q654471', 'Q762844', 'Q1703180', 'Q1967942', 'Q1992013', 'Q1992153', 'Q1992181', 'Q2268261', 'Q3853593', 'Q3885141', 'Q4188115', 'Q4240311', 'Q4286712', 'Q4286829', 'Q4286849', 'Q4286882', 'Q4286937', 'Q4286990', 'Q4287015', 'Q4287082', 'Q4287097', 'Q4287144', 'Q4375455', 'Q4375533', 'Q12756735', 'Q16481642', 'Q16485587', 'Q18080427', 'Q18080429', 'Q18080612', 'Q19399024', 'Q19910703', 'Q21644047', 'Q24932811', 'Q25394795', 'Q57316823', 'Q95000245']
# ['Q21', 'Q22', 'Q25', 'Q26']
# ['Q20183']
# ['Q4151339', 'Q17287317', 'Q17287320', 'Q17287321']
# ['Q165503']
# ['Q28835', 'Q1275243']
# ['Q1396852']
# ['Q70498154']
# ['Q15288']
# ['Q1444', 'Q5994', 'Q8355', 'Q80284', 'Q81982', 'Q191823', 'Q281460', 'Q1521313']
# ['Q10478']
# ['Q4480733']
# ['Q202243']
# ['Q204752']
# ['Q15', 'Q48']
# ['Q27621', 'Q1978570', 'Q2387574', 'Q2495829', 'Q4525174', 'Q4534839', 'Q27430017']
# ['Q90']
# ['Q1982087']
# ['Q239', 'Q12800833']
# ['Q250', 'Q3966', 'Q5300', 'Q7397', 'Q9143', 'Q183484', 'Q2384798']
# ['Q43421']
# ['Q46', 'Q48']
# ['Q5492408']
# ['Q3964988']
# ['Q579431', 'Q2000835']
# ['Q665105']
# ['Q184437']
# ['Q190543']
# ['Q55766251']
# ['Q72614', 'Q104161', 'Q1384655', 'Q2721194']
# ['Q4315520']
# ['Q49481']
# ['Q213067']
# ['Q188', 'Q1860', 'Q7737', 'Q9027']
# ['Q79082']
# ['Q18']
# ['Q46']
# ['Q8338', 'Q202027', 'Q17172850']
# ['Q739', 'Q8965', 'Q199821', 'Q232564', 'Q1055848', 'Q3591854']
# ['Q902', 'Q330158', 'Q842931', 'Q1850485', 'Q2347909']
# ['Q28']
# ['Q162533']
# ['Q48']
# ['Q847']
# ['Q485176']
# ['Q157443', 'Q192881', 'Q319221', 'Q471839', 'Q761469', 'Q2973181', 'Q20443008']
# ['Q98']
# ['Q37068']
# ['Q37853']
# ['Q54111', 'Q170292']
# ['Q332342', 'Q7744473']
# ['Q13394']
# ['Q324867']
# ['Q4411519']
# ['Q486860']
# ['Q656']
# ['Q1218', 'Q187702', 'Q540882', 'Q1494672', 'Q2280628', 'Q7818625']
# ['Q1332307']
# ['Q210398']
# ['Q8261', 'Q128758', 'Q474090']
# ['Q126399', 'Q621364', 'Q984047', 'Q2924461']
# ['Q23633']
# ['Q126399', 'Q2924461', 'Q3011161', 'Q31197934']
# ['Q1200552', 'Q17343562', 'Q18155354', 'Q22807052']
# ['Q13641190']
# ['Q1589009']
# ['Q75', 'Q880371', 'Q56611700']
# ['Q6581097']
# ['Q675765', 'Q845981', 'Q3984081']
# ['Q1506552', 'Q1938341']
# ['Q27621', 'Q322964', 'Q323681']
# ['Q5994', 'Q8355']
# ['Q165503']
# ['Q27621', 'Q1978570', 'Q2387574', 'Q2495829', 'Q4525174', 'Q4534839', 'Q27430017']
# ['Q5064', 'Q12025', 'Q201873', 'Q207875', 'Q231390', 'Q586421']
# ['Q159909', 'Q14906020']
# ['Q299687']
# ['Q124018']
# ['Q778243']
# ['Q158314']
# ['Q62843', 'Q92743']
# ['Q8743', 'Q315422']
# ['Q76468']
# ['Q34286', 'Q77124', 'Q273314', 'Q318449']
# ['Q133544']
# ['Q4143870']
# ['Q552732']
# ['Q5673']
# ['Q4069095', 'Q4321371']
# ['Q380156', 'Q1395520']
# ['Q4934', 'Q92764']
# ['Q19837', 'Q332591', 'Q483382']
# ['Q7738', 'Q12548', 'Q27306', 'Q33296', 'Q34266', 'Q45670', 'Q68518', 'Q70972', 'Q80702', 'Q127318', 'Q131706', 'Q131981', 'Q153136', 'Q156199', 'Q161885', 'Q168651', 'Q170604', 'Q215443', 'Q215530', 'Q256961', 'Q258532', 'Q310650', 'Q318806', 'Q706018', 'Q830084', 'Q4083686']
# ['Q299687']
# ['Q29637']
# ['Q739711', 'Q1799063']
# ['Q75079']
# ['Q2628071']
# ['Q152293']
# ['Q79965', 'Q170770', 'Q1483495', 'Q4318679']
# ['Q76754', 'Q186203', 'Q4349082']
# ['Q26068']
# ['Q22890', 'Q23666', 'Q38272']
# ['Q76925']
# ['Q76925']
# ['Q538']
# ['Q258896']
# ['Q7603']
# ['Q233282']
# ['Q21', 'Q145']
# ['Q380252']
# ['Q42042', 'Q48362']
# ['Q3333484']
# ['Q25624', 'Q193026', 'Q1347099', 'Q1377980', 'Q2217063']
# ['Q785828']
# ['Q1065', 'Q4230', 'Q4264', 'Q7809', 'Q7817', 'Q7825', 'Q8475', 'Q17495', 'Q19771', 'Q47488', 'Q47539', 'Q123209', 'Q123759', 'Q151991', 'Q182500', 'Q191384', 'Q243630', 'Q340195', 'Q467938', 'Q471690', 'Q499151', 'Q535086', 'Q602399', 'Q605595', 'Q607301', 'Q656801', 'Q827525', 'Q838116', 'Q842490', 'Q943105', 'Q1025959', 'Q1043527', 'Q1045401', 'Q1072120', 'Q1480793', 'Q1484463', 'Q1570993', 'Q2836400', 'Q3369762', 'Q5611262', 'Q10283557']
# ['Q9448']
# ['Q41']
# ['Q258748']
# ['Q1781702']
# ['Q260542']
# ['Q49', 'Q538']
# ['Q37068']
# ['Q7291']
# ['Q2245347', 'Q2914850', 'Q72553200', 'Q72553961']
# ['Q2359372']
# ['Q15804']
# ['Q1256223']
# ['Q649', 'Q656', 'Q891', 'Q900', 'Q1874', 'Q5332', 'Q5337', 'Q5540', 'Q5627', 'Q19566', 'Q21197', 'Q156648', 'Q4092262', 'Q4536541', 'Q4538749']
# ['Q1130019']
# ['Q97']
# ['Q33629']
# ['Q24826']
# ['Q3426']
# ['Q1130019']
# ['Q1457437']
# ['Q649']
# ['Q1902692']
# ['Q586']
# ['Q649']
# ['Q5776']
# ['Q133838']
# ['Q174097']
# ['Q34433', 'Q1643454']
# ['Q3630']
# ['Q5994']
# ['Q1990094']
# ['Q4460646']
# ['Q1422', 'Q8682', 'Q18656', 'Q75729', 'Q267245', 'Q1630430', 'Q1772776', 'Q3590754', 'Q3590758', 'Q21079208']
# ['Q59488']
# ['Q133602']
# ['Q81589', 'Q645968']
# ['Q156255']
# ['Q242446']
# ['Q126399', 'Q2924461']
# ['Q159846', 'Q367466']
# ['Q2914786', 'Q4444575']
# ['Q126399', 'Q622668', 'Q3011161', 'Q31197934']
# ['Q2628487']
# ['Q141336']
# ['Q95', 'Q20800404']
# ['Q269792']
# ['Q127552', 'Q191224']
# ['Q20800404']
# ['Q84']
# ['Q16869', 'Q182009']
# ['Q1533']
# ['Q1957']
# ['Q1858']
# ['Q1353', 'Q11739', 'Q42941', 'Q179046', 'Q3242297']
# ['Q2184', 'Q2895', 'Q130229', 'Q130276', 'Q130280', 'Q131337', 'Q132856', 'Q133356', 'Q168811', 'Q170895', 'Q173761', 'Q186888', 'Q192180', 'Q199707', 'Q199711', 'Q484578', 'Q545205']
# ['Q93728', 'Q178473', 'Q185493', 'Q207826', 'Q208167', 'Q278798', 'Q337463', 'Q465316', 'Q530008', 'Q1069798', 'Q1081449', 'Q1710776', 'Q2297431', 'Q2634074', 'Q2760953', 'Q4137459', 'Q4286836', 'Q4335954', 'Q21292820', 'Q59351315', 'Q60130697', 'Q63975126']
# ['Q37922', 'Q278798', 'Q603631', 'Q695106', 'Q950604', 'Q1026769', 'Q1081503', 'Q1340199', 'Q18200478']
# ['Q475482', 'Q1463070']
# ['Q152951']
# ['Q152951']
# ['Q493898']
# ['Q172326']
# ['Q8355', 'Q81982', 'Q281460']
# ['Q27911']
# ['Q31687']
# ['Q27914']
# ['Q1438774']
# ['Q45700']
# ['Q1425861', 'Q7268181']
# ['Q186506']
# ['Q379053']
# ['Q180729', 'Q181951', 'Q1059510', 'Q1277249', 'Q2494846', 'Q4862955']
# ['Q28989']
# ['Q9268']
# ['Q432', 'Q5043']
# ['Q1394287']
# ['Q2498026']
# ['Q23759071']
# ['Q345']
# ['Q7041639']
# ['Q95', 'Q20800404']
# ['Q1966985']
# ['Q1744']
# ['Q377', 'Q191480']
# ['Q42511']
# ['Q15151625']
# ['Q15151625']
# ['Q4069095', 'Q4321371', 'Q4360695']
# ['Q19837', 'Q332591', 'Q483382']
# ['Q40224', 'Q57098', 'Q70788']
# ['Q5284', 'Q162005']
# ['Q40224', 'Q57098', 'Q70788']
# ['Q44412']
# ['Q37064']
# ['Q50224531']
# ['Q3140459']
# ['Q1060165']
# ['Q2283', 'Q1129295']
# ['Q4132607']
# ['Q195719']
# ['Q42574']
# ['Q4934', 'Q92764']
# ['Q76368']
# ['Q4419809', 'Q4498457']
# ['Q929273', 'Q929285', 'Q2071256', 'Q16253333', 'Q57022061']
# ['Q15072147']
# ['Q315188']
# ['Q191598']
# ['Q97']
# ['Q1406', 'Q5014725', 'Q13361286', 'Q64513817']
# ['Q1406', 'Q5014725', 'Q13361286']
# ['Q280658']
# ['Q280658', 'Q8025128']
# ['Q3542']
# ['Q15243', 'Q203462']
# ['Q2160']
# ['Q19686', 'Q19914']
# ['Q166162']
# ['Q1457453']
# ['Q4320732']
# ['Q166162']
# ['Q13199', 'Q15087', 'Q33754', 'Q387066']
# ['Q80284']
# ['Q31561', 'Q79838', 'Q178389', 'Q4501563', 'Q17172850']
# ['Q8343']
# ['Q3238057', 'Q13785927']
# ['Q5710', 'Q809806', 'Q1092754', 'Q1390649', 'Q4479125', 'Q4479136', 'Q15190285']
# ['Q408', 'Q3258', 'Q15577']
# ['Q980', 'Q10544', 'Q10562']
# ['Q1019', 'Q489821', 'Q5501842']
# ['Q225', 'Q11196', 'Q11198', 'Q18276', 'Q208545', 'Q1274468', 'Q2055400']
# ['Q252', 'Q3757', 'Q523435']
# ['Q766', 'Q651453', 'Q2526023']
# ['Q424', 'Q1054184', 'Q3173090']
# ['Q40', 'Q12548', 'Q28513', 'Q42497', 'Q131964', 'Q153136', 'Q176495', 'Q268970', 'Q518101', 'Q699964', 'Q3624335', 'Q16056854']
# ['Q5446', 'Q788066', 'Q2391775', 'Q6671523', 'Q14558462', 'Q18055588']
# ['Q672', 'Q21815222']
# ['Q854']
# ['Q1008', 'Q845706']
# ['Q1368300']
# ['Q432']
# ['Q775909']
# ['Q4239246']
# ['Q1497']
# ['Q371828', 'Q1324152']
# ['Q207706']
# ['Q4218621']
# ['Q2280', 'Q173822', 'Q185700', 'Q188732', 'Q189822', 'Q191061', 'Q192959']
# ['Q5681011']
# ['Q16157447']
# ['Q361', 'Q2140994', 'Q4081756', 'Q4097857', 'Q4255538']
# ['Q9448']
# ['Q656', 'Q9248', 'Q155243', 'Q196388', 'Q1020157', 'Q4322358']
# ['Q917830']
# ['Q27621', 'Q2654435', 'Q4139211']
# ['Q973']
# ['Q1065', 'Q7184', 'Q7785', 'Q7809', 'Q7825', 'Q8475', 'Q17495', 'Q19771', 'Q37143', 'Q38130', 'Q41550', 'Q81299', 'Q123759', 'Q134102', 'Q170481', 'Q181574', 'Q188822', 'Q191384', 'Q233611', 'Q340195', 'Q376150', 'Q656801', 'Q674182', 'Q782942', 'Q826700', 'Q827525', 'Q842490', 'Q899770', 'Q1043527', 'Q1072120', 'Q1480793', 'Q1928989', 'Q2863003', 'Q3772571', 'Q3866537', 'Q4033111', 'Q4426267', 'Q5150848', 'Q5611262', 'Q7768229', 'Q7886981']
# ['Q167541']
# ['Q182165']
# ['Q76751']
# ['Q5284', 'Q162005']
# ['Q557305', 'Q861967']
# ['Q104898']
# ['Q58792', 'Q80919']
# ['Q1189073', 'Q6895015']
# ['Q182994']
# ['Q46']
# ['Q207591']
# ['Q10857409']
# ['Q782363']
# ['Q736587']
# ['Q649', 'Q656', 'Q1731', 'Q4079059', 'Q4471180']
# ['Q234460', 'Q1069725', 'Q1980247']
# ['Q3642350']
# ['Q101978']
# ['Q49542', 'Q79797', 'Q482942', 'Q1129737', 'Q10290517']
# ['Q19831455']
# ['Q372657', 'Q505275', 'Q22032185']
# ['Q134161', 'Q891723']
# ['Q75745', 'Q248756', 'Q785531', 'Q808176', 'Q854686', 'Q1009177', 'Q1054311', 'Q2090382', 'Q2462900', 'Q2921573', 'Q3017105', 'Q3196524', 'Q4074592', 'Q4081114', 'Q4222569', 'Q4246441', 'Q4375034', 'Q4408691', 'Q4424133', 'Q4427701', 'Q4460344', 'Q14915363', 'Q14915364', 'Q14915365', 'Q14915367', 'Q14915368', 'Q14915369', 'Q14915370', 'Q14915425', 'Q14915428', 'Q14915447', 'Q14915448', 'Q14915449', 'Q14915450', 'Q14915451', 'Q14915452', 'Q14915453', 'Q14915454', 'Q14915455', 'Q14915456', 'Q14915457', 'Q14915458', 'Q14915459', 'Q14915460', 'Q14915461', 'Q14915462', 'Q14915463', 'Q14915464', 'Q14915465', 'Q14915466', 'Q14915467', 'Q14915468', 'Q14915469', 'Q14915470', 'Q14915471', 'Q14915472', 'Q14915473', 'Q14915474', 'Q14915475', 'Q14915476', 'Q14915477', 'Q14915478', 'Q14915479', 'Q14915480', 'Q14915481', 'Q14915482', 'Q14915483', 'Q14915484', 'Q14915485', 'Q14915486', 'Q14915489', 'Q14915490', 'Q14943318', 'Q14943338', 'Q14943342', 'Q21036227', 'Q21036228', 'Q21036229', 'Q21036230', 'Q27679334', 'Q35267412']
# ['Q185493', 'Q208167', 'Q241821', 'Q278798', 'Q337463', 'Q530008', 'Q946626', 'Q1067644', 'Q1069798', 'Q1710776', 'Q2329480', 'Q2634074', 'Q4335936', 'Q4335954', 'Q4375624', 'Q21292820', 'Q56669004', 'Q60054123']
# ['Q41144', 'Q41146', 'Q43269', 'Q43271', 'Q130343', 'Q165582', 'Q170453', 'Q190687', 'Q190922', 'Q191164', 'Q191174', 'Q191186', 'Q201121', 'Q201137', 'Q202068', 'Q202071', 'Q202075', 'Q204876', 'Q205460', 'Q205776', 'Q205784', 'Q205796', 'Q205824', 'Q205843', 'Q492791']
# ['Q1085', 'Q46070', 'Q188373', 'Q188399', 'Q190550', 'Q190930', 'Q191091', 'Q192536', 'Q192697', 'Q192702', 'Q193266', 'Q193295', 'Q193307', 'Q193317']
# ['Q1490', 'Q15701', 'Q44843', 'Q47896', 'Q48326', 'Q71699', 'Q71707', 'Q80011', 'Q80434', 'Q81863', 'Q83273', 'Q120730', 'Q122723', 'Q123258', 'Q123376', 'Q125863', 'Q127264', 'Q127513', 'Q127877', 'Q128186', 'Q128196', 'Q129499', 'Q130290', 'Q130300', 'Q130308', 'Q131277', 'Q131281', 'Q131287', 'Q131314', 'Q131320', 'Q131358', 'Q132705', 'Q132720', 'Q132751', 'Q132929', 'Q132936', 'Q133879', 'Q133924', 'Q133935', 'Q134093', 'Q160420', 'Q160734', 'Q161454', 'Q169376', 'Q617375', 'Q766445', 'Q1037393']
# ['Q4156896']
# ['Q7325']
# ['Q6581097']
# ['Q5256775']
# ['Q10693']
# ['Q12482', 'Q44455', 'Q189088', 'Q1554323', 'Q1766038', 'Q1970172', 'Q2895315', 'Q4056286', 'Q4358367', 'Q5498822']
# ['Q928993']
# ['Q20818052']
# ['Q76754', 'Q186203', 'Q4349082']
# ['Q67186598']
# ['Q4035237']
# ['Q52410688']
# ['Q3772']
# ['Q4417863']
# ['Q60100']
# ['Q41602']
# ['Q217925', 'Q2873520']
# ['Q23898959']
# ['Q27621']
# ['Q1566', 'Q199344', 'Q736556']
# ['Q182994']
# ['Q2532727']
# ['Q65032731']
# ['Q47591', 'Q4520962']
# ['Q11297']
# ['Q1370', 'Q523606', 'Q5425102']
# ['Q3279650']
# ['Q6635', 'Q645924']
# ['Q11002', 'Q11254', 'Q41534', 'Q93189', 'Q815740', 'Q4739805', 'Q61503220']
# ['Q50407282']
# ['Q3739104']
# ['Q171558']
# ['Q3739104']
# ['Q3739104']
# ['Q337463']
# ['Q756727', 'Q2747456']
# ['Q202009', 'Q918052', 'Q1167442', 'Q1756055', 'Q3163406']
# ['Q54111']
# ['Q11366', 'Q188450', 'Q484641']
# ['Q3273722']
# ['Q40855']
# ['Q73801', 'Q308913', 'Q611508', 'Q735267', 'Q1046593', 'Q1202130', 'Q2080076', 'Q2469781']
# ['Q157802']
# ['Q4204467']
# ['Q483654']
# ['Q483654', 'Q3333484']
# ['Q547869']
# ['Q27703517']
# ['Q892']
# ['Q1402143']
# ['Q128267', 'Q186350']
# ['Q3415248']
# ['Q4418820']
# ['Q1273278']
# ['Q42574']
# ['Q56008']
# ['Q187364']
# ['Q726105']
# ['Q56005']
# ['Q8877', 'Q6758800']
# ['Q56005']
# ['Q80135']
# ['Q33629']
# ['Q8025128']
# ['Q8025128']
# ['Q8025128']
# ['Q626']
# ['Q3447', 'Q27538353']
# ['Q38', 'Q1282', 'Q18288160']
# ['Q487003']
# ['Q228986']
# ['Q23746012']
# ['Q4301841']
# ['Q1711668']
# ['Q1768082']
# ['Q968028']
# ['Q192239']
# ['Q434841']
# ['Q157802']
# ['Q178473', 'Q185493', 'Q209896', 'Q478850', 'Q530008', 'Q534981', 'Q583881', 'Q612907', 'Q694401', 'Q728960', 'Q791135', 'Q1311063', 'Q1415232', 'Q1428575', 'Q1992013', 'Q2028781', 'Q2268261', 'Q2300740', 'Q2638119', 'Q2660844', 'Q4193236', 'Q9387384', 'Q18080427', 'Q18080429', 'Q18080431', 'Q21405589', 'Q89211387']
# ['Q97']
# ['Q27698']
# ['Q946428']
# ['Q33629']
# ['Q834621']
# ['Q4918']
# ['Q1247']
# ['Q17723']
# ['Q515869', 'Q25060578']
# ['Q44626']
# ['Q393864']
# ['Q4393561']
# ['Q847', 'Q5377', 'Q80131']
# ['Q134307', 'Q170571', 'Q191163']
# ['Q207591']
# ['Q130232', 'Q2254193', 'Q52207399']
# ['Q393']
# ['Q141336']
# ['Q5168']
# ['Q5222']
# ['Q900']
# ['Q33405']
# ['Q3114']
# ['Q748', 'Q427945', 'Q2279088']
# ['Q299687']
# ['Q49481']
# ['Q7349']
# ['Q49481']
# ['Q150', 'Q188', 'Q652', 'Q13199']
# ['Q188']
# ['Q23438']
# ['Q3616']
# ['Q174193']
# ['Q11399', 'Q187760', 'Q598929']
# ['Q8341', 'Q9759', 'Q203775', 'Q207378', 'Q1196752', 'Q1530455']
# ['Q37068']
# ['Q39427']
# ['Q37853']
# ['Q4992220']
# ['Q736587']
# ['Q112707']
# ['Q161179', 'Q177540', 'Q223197', 'Q583582', 'Q1055000']
# ['Q8261']
# ['Q189635']
# ['Q181754']
# ['Q181754']
# ['Q125168', 'Q1501888']
# ['Q1471878', 'Q3983766']
# ['Q31687']
# ['Q1218']
# ['Q1520']
# ['Q1930']
# ['Q28218']
# ['Q31687']
# ['Q2618625']
# ['Q739000']
# ['Q767288']
# ['Q51199', 'Q4228172']
# ['Q240150']
# ['Q8958']
# ['Q762']
# ['Q204138']
# ['Q2382967']
# ['Q358556']
# ['Q700540']
# ['Q314287']
# ['Q4768']
# ['Q1144905']
# ['Q9217']
# ['Q1568', 'Q1860']
# ['Q150', 'Q1860']
# ['Q150']
# ['Q1682', 'Q1684', 'Q161455', 'Q300875', 'Q316287', 'Q324404', 'Q562206', 'Q671428', 'Q694789', 'Q697916', 'Q821135', 'Q1532109', 'Q1538524', 'Q1646276', 'Q3908364']
# ['Q188', 'Q36668']
# ['Q5146', 'Q750553', 'Q3436689']
# ['Q13955']
# ['Q8821']
# ['Q809']
# ['Q37217']
# ['Q78994', 'Q858913', 'Q1025134', 'Q1088879', 'Q1194172', 'Q1347209', 'Q1985387', 'Q2234632', 'Q2372093', 'Q2914954']
# ['Q30']
# ['Q164800']
# ['Q80113', 'Q166713']
# ['Q217128']
# ['Q762']
# ['Q130777']
# ['Q76432', 'Q76745', 'Q76747']
# ['Q11570']
# Accuracy = 0.2765598650927487

# %% [markdown]
# # t5-3b-ssm-nqo

# %%
t5_qa_model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-3b-ssm-nqo")#"google/t5-11b-ssm-tqa")
t5_tok = AutoTokenizer.from_pretrained("google/t5-3b-ssm-nqo")
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
t5_qa_model.to(device)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=4096, bias=False)
#               (k): Linear(in_features=1024, out_features=4096, bias=False)
#               (v): Linear(in_features=1024, out_features=4096, bias=False)
#               (o): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseReluDense(
#               (wi): Linear(in_features=1024, out_features=16384, bias=False)
#               (wo): Linear(in_features=16384, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
acc_o, preds_id_sq_o = check_t5_sq(t5_tok = t5_tok, t5_qa_model = t5_qa_model)
# Out:
# 100%|██████████| 4751/4751 [11:25<00:00,  6.93it/s]
# 100%|██████████| 4751/4751 [00:00<00:00, 827298.47it/s]

# %%
print("top1 accuracy t5-3b-ssm-nqo SQ = ", acc_o)
# Out:
# top1 accuracy t5-3b-ssm-nqo SQ =  0.06735424121237635

# %%
rubq_test = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")

answers = []
for i in tqdm(range(len(rubq_test))):
    input_ids = t5_tok(rubq_test[i], return_tensors="pt").input_ids
    input_ids = input_ids.to(device)
    gen_output = t5_qa_model.generate(input_ids)[0]
    answers.append(gen_output)
    
    
final = []
for x in answers:
    final.append(t5_tok.decode(x, skip_special_tokens=True))

    
#rubq_questions = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")
entities_test_rubq = np.load("entities_test_rubq.npy")
rubq_test = pd.DataFrame({"subject":entities_test_rubq, "question":rubq_test})
rubq_test_answers = np.load("all_rubq_test_answers_1_hop_uri.npy", allow_pickle=True)

# answers_rubq = []

# for lis in rubq_test_answers:
#     print(lis)
#     new = []
#     for element in lis:
#         new.append(get_description_name(element))

#     answers_rubq.append(new)
    
preds = []
for i in range(len(final)):
    try:
        x = from_text_to_id(final[i])
    except:
        x = "None"
    
    preds.append(x)
    
np.save("predictions_rubq_test_t5_3b_ssm_nq.npy", np.array(final))

answers_rubq = []

for lis in rubq_test_answers:
    print(lis)
    new = []
    for element in lis:
        new.append(element)

    answers_rubq.append(new)

right = 0

for i, ans in enumerate(answers_rubq):
    if preds[i] in ans:
        right += 1
    else:
        pass
    
print(f"top1 accuracy t5-3b-ssm-nqo RuBQ =  = {right/len(preds)}")
# Out:
# 100%|██████████| 1186/1186 [03:13<00:00,  6.14it/s]
# ['Q7944', 'Q60186', 'Q167903', 'Q2580904', 'Q5975740', 'Q7692360']
# ['Q102513']
# ['Q692']
# ['Q19660']
# ['Q6607', 'Q483994', 'Q626035', 'Q2643890', 'Q17172850']
# ['Q142']
# ['Q299687']
# ['Q312480']
# ['Q29']
# ['Q4022']
# ['Q796']
# ['Q38768', 'Q201605', 'Q1676638']
# ['Q22']
# ['Q11420', 'Q106500']
# ['Q4808485']
# ['Q2838011']
# ['Q9299872']
# ['Q2674728']
# ['Q1968651']
# ['Q1088']
# ['Q7737', 'Q29561']
# ['Q36124']
# ['Q43']
# ['Q49481']
# ['Q424', 'Q869', 'Q881']
# ['Q148', 'Q837']
# ['Q232']
# ['Q408']
# ['Q816']
# ['Q847', 'Q5377']
# ['Q30']
# ['Q1792']
# ['Q822290']
# ['Q1603']
# ['Q181306', 'Q213344', 'Q237367', 'Q1326237']
# ['Q237800']
# ['Q106151']
# ['Q201598']
# ['Q223134']
# ['Q106010']
# ['Q29445']
# ['Q40591', 'Q58784', 'Q295347', 'Q470600']
# ['Q1850']
# ['Q4719']
# ['Q157683']
# ['Q158491']
# ['Q62']
# ['Q24861']
# ['Q3787']
# ['Q8338', 'Q202027', 'Q17172850']
# ['Q55']
# ['Q19675']
# ['Q36180', 'Q82955', 'Q185351', 'Q333634', 'Q1209498', 'Q1297719', 'Q4964182', 'Q11774202', 'Q18814623']
# ['Q22']
# ['Q1048']
# ['Q9191']
# ['Q687']
# ['Q1860923']
# ['Q178577']
# ['Q199588']
# ['Q79759']
# ['Q31628']
# ['Q57966']
# ['Q133622']
# ['Q360292']
# ['Q128790']
# ['Q236233']
# ['Q152293']
# ['Q15862']
# ['Q723764']
# ['Q783']
# ['Q767288']
# ['Q31628']
# ['Q142']
# ['Q40357']
# ['Q1048']
# ['Q159']
# ['Q2064699', 'Q4304132']
# ['Q668']
# ['Q112']
# ['Q49111']
# ['Q131026']
# ['Q11419']
# ['Q6502703']
# ['Q172911']
# ['Q212115']
# ['Q1069868']
# ['Q897']
# ['Q869']
# ['Q41']
# ['Q10737']
# ['Q6862']
# ['Q40059']
# ['Q35591']
# ['Q2332']
# ['Q1205']
# ['Q31015', 'Q241214']
# ['Q586']
# ['Q891']
# ['Q1472', 'Q12133', 'Q35869', 'Q41083', 'Q110315', 'Q131742', 'Q147778', 'Q193894', 'Q653078', 'Q2025687', 'Q2035074', 'Q3144986']
# ['Q144144']
# ['Q34981']
# ['Q185027']
# ['Q47369']
# ['Q45']
# ['Q81214']
# ['Q51']
# ['Q4964182']
# ['Q46599']
# ['Q6816']
# ['Q46']
# ['Q1875']
# ['Q5470']
# ['Q165503']
# ['Q25261', 'Q46255']
# ['Q925']
# ['Q790']
# ['Q13695']
# ['Q24826']
# ['Q1035', 'Q82122']
# ['Q2568844']
# ['Q149067']
# ['Q170737']
# ['Q626']
# ['Q395', 'Q7754', 'Q41217', 'Q149999', 'Q56114489']
# ['Q157623']
# ['Q159']
# ['Q5592']
# ['Q626']
# ['Q28244']
# ['Q16559']
# ['Q944527']
# ['Q8027']
# ['Q70']
# ['Q10484']
# ['Q47059']
# ['Q93351']
# ['Q762']
# ['Q214196']
# ['Q130498']
# ['Q30204']
# ['Q157623']
# ['Q31']
# ['Q854']
# ['Q170513']
# ['Q5806']
# ['Q37853']
# ['Q1918252']
# ['Q34']
# ['Q43106']
# ['Q5422']
# ['Q29445']
# ['Q219']
# ['Q664']
# ['Q13989']
# ['Q201330']
# ['Q84']
# ['Q2807']
# ['Q40']
# ['Q949424']
# ['Q935']
# ['Q4181867']
# ['Q109676']
# ['Q155626']
# ['Q1981162']
# ['Q33629']
# ['Q739362']
# ['Q211513', 'Q214666', 'Q319861']
# ['Q38']
# ['Q16']
# ['Q240150']
# ['Q192239', 'Q12799318']
# ['Q2736']
# ['Q2844']
# ['Q804']
# ['Q43105']
# ['Q150445']
# ['Q419']
# ['Q258', 'Q1013', 'Q1030']
# ['Q467118']
# ['Q424']
# ['Q739']
# ['Q38337']
# ['Q2044']
# ['Q44703']
# ['Q4872']
# ['Q145']
# ['Q4534523']
# ['Q7315']
# ['Q887']
# ['Q3114']
# ['Q16']
# ['Q36', 'Q211274']
# ['Q8743']
# ['Q154269', 'Q316417', 'Q336810', 'Q432752', 'Q463833']
# ['Q201330']
# ['Q1265']
# ['Q176371']
# ['Q131233']
# ['Q43279']
# ['Q3904', 'Q101418']
# ['Q9268']
# ['Q408']
# ['Q29']
# ['Q1369676']
# ['Q48103', 'Q857244', 'Q17232562']
# ['Q30']
# ['Q298', 'Q414']
# ['Q191159']
# ['Q9215']
# ['Q183']
# ['Q664']
# ['Q1460']
# ['Q851']
# ['Q40909']
# ['Q656']
# ['Q203236']
# ['Q14515330']
# ['Q8810']
# ['Q42941']
# ['Q1524']
# ['Q181114']
# ['Q129352']
# ['Q14773']
# ['Q36600']
# ['Q167420']
# ['Q83186']
# ['Q130531']
# ['Q167646', 'Q171839', 'Q736813']
# ['Q6585']
# ['Q811']
# ['Q835']
# ['Q45']
# ['Q408']
# ['Q42831']
# ['Q762']
# ['Q10686']
# ['Q1850']
# ['Q15807']
# ['Q1003']
# ['Q183']
# ['Q28']
# ['Q1532068']
# ['Q801']
# ['Q3859']
# ['Q170292', 'Q191105']
# ['Q127888']
# ['Q319708']
# ['Q25328']
# ['Q58035']
# ['Q468621', 'Q15071896']
# ['Q29', 'Q142']
# ['Q9191']
# ['Q38']
# ['Q164761', 'Q165704', 'Q170737', 'Q178108', 'Q180935', 'Q182570', 'Q185027', 'Q191691', 'Q334734', 'Q537769']
# ['Q43114']
# ['Q1726', 'Q131610']
# ['Q4412']
# ['Q501']
# ['Q205375', 'Q1281618', 'Q1930187']
# ['Q134942']
# ['Q4167647']
# ['Q162737']
# ['Q172089']
# ['Q34038']
# ['Q813']
# ['Q7947']
# ['Q215556']
# ['Q6934']
# ['Q33231', 'Q36180', 'Q49757', 'Q161944', 'Q170790', 'Q4853732', 'Q4964182', 'Q6625963', 'Q14565331', 'Q18814623', 'Q18939491']
# ['Q15208']
# ['Q916']
# ['Q35881']
# ['Q38']
# ['Q948']
# ['Q57479']
# ['Q265']
# ['Q320653']
# ['Q275354']
# ['Q8006']
# ['Q8409']
# ['Q60']
# ['Q193592']
# ['Q60']
# ['Q8678']
# ['Q718']
# ['Q1186567']
# ['Q1754954']
# ['Q155856']
# ['Q718']
# ['Q48211', 'Q297032']
# ['Q6574', 'Q6655']
# ['Q715281']
# ['Q47293']
# ['Q47293']
# ['Q4768']
# ['Q110228']
# ['Q193064']
# ['Q762']
# ['Q217128']
# ['Q183']
# ['Q170984', 'Q372254']
# ['Q741157']
# ['Q208008']
# ['Q212']
# ['Q131210']
# ['Q27911']
# ['Q34575']
# ['Q11629']
# ['Q83891']
# ['Q78707']
# ['Q9391']
# ['Q3926', 'Q5465', 'Q37701']
# ['Q44363', 'Q82586']
# ['Q592289']
# ['Q28603']
# ['Q219']
# ['Q32024']
# ['Q10570']
# ['Q188']
# ['Q184222']
# ['Q35657']
# ['Q267861', 'Q1323788']
# ['Q133026']
# ['Q33999', 'Q36834', 'Q49757', 'Q177220', 'Q183945', 'Q488205', 'Q662729', 'Q753110', 'Q1028181', 'Q13235160', 'Q16323111', 'Q29017403']
# ['Q148']
# ['Q36']
# ['Q28389', 'Q36180', 'Q49757', 'Q214917', 'Q482980', 'Q6625963']
# ['Q185118', 'Q81200227']
# ['Q38']
# ['Q164714']
# ['Q269668']
# ['Q4257378']
# ['Q151209']
# ['Q315185']
# ['Q716794']
# ['Q912050', 'Q2453629']
# ['Q6397066']
# ['Q186083']
# ['Q220437']
# ['Q14435']
# ['Q72']
# ['Q69060']
# ['Q182101']
# ['Q403']
# ['Q4202', 'Q5871']
# ['Q302849']
# ['Q326827']
# ['Q192134']
# ['Q183']
# ['Q845210']
# ['Q1773']
# ['Q1205']
# ['Q42574']
# ['Q155']
# ['Q333246']
# ['Q230']
# ['Q23124']
# ['Q170513']
# ['Q408']
# ['Q108316']
# ['Q819']
# ['Q11930']
# ['Q3711']
# ['Q47154']
# ['Q711']
# ['Q5338']
# ['Q200797']
# ['Q7200']
# ['Q21']
# ['Q51641', 'Q2907211', 'Q7311705', 'Q7796966', 'Q7796967', 'Q7796969', 'Q12403826', 'Q12403830', 'Q12404028', 'Q12408472', 'Q12408583', 'Q12408584']
# ['Q36834', 'Q486748']
# ['Q142']
# ['Q36215']
# ['Q167997']
# ['Q3915']
# ['Q3919']
# ['Q38111', 'Q41148', 'Q80966', 'Q160432', 'Q170572', 'Q179414', 'Q188772', 'Q192402', 'Q201842', 'Q223091', 'Q223110', 'Q233882', 'Q236613', 'Q241025', 'Q264996', 'Q310394', 'Q311453', 'Q357762', 'Q437752', 'Q481954', 'Q483379', 'Q536437', 'Q918404', 'Q1189169', 'Q1190406', 'Q1680304', 'Q2865151', 'Q3127916', 'Q3501718', 'Q3573721', 'Q25768136']
# ['Q258']
# ['Q183']
# ['Q1541']
# ['Q220']
# ['Q27']
# ['Q3844']
# ['Q204138']
# ['Q140001']
# ['Q1761', 'Q135501', 'Q659895', 'Q1263215', 'Q1672830', 'Q1766409', 'Q2062702', 'Q2088319', 'Q2350741', 'Q5242183', 'Q5500969', 'Q7417543', 'Q13156901', 'Q28601860']
# ['Q8338', 'Q17172850']
# ['Q2092607']
# ['Q236132', 'Q456257']
# ['Q150']
# ['Q683695']
# ['Q17714']
# ['Q69354']
# ['Q229107']
# ['Q17', 'Q188712']
# ['Q623']
# ['Q167646']
# ['Q212']
# ['Q34990']
# ['Q255']
# ['Q45765']
# ['Q31966']
# ['Q108429']
# ['Q155327']
# ['Q157065']
# ['Q1151']
# ['Q176371']
# ['Q656043']
# ['Q30']
# ['Q133274']
# ['Q935']
# ['Q41484']
# ['Q7364']
# ['Q34404']
# ['Q241']
# ['Q8343']
# ['Q40939']
# ['Q204627']
# ['Q894']
# ['Q170737']
# ['Q79']
# ['Q1554208', 'Q1969437']
# ['Q38']
# ['Q35500']
# ['Q1147806']
# ['Q645']
# ['Q5885', 'Q13267']
# ['Q5776']
# ['Q811']
# ['Q843']
# ['Q8667']
# ['Q152513']
# ['Q2133873']
# ['Q557323']
# ['Q695']
# ['Q7200']
# ['Q6607', 'Q17172850']
# ['Q8686']
# ['Q38']
# ['Q829']
# ['Q4214909']
# ['Q239337']
# ['Q42493']
# ['Q30']
# ['Q1069', 'Q8008', 'Q46255']
# ['Q1016']
# ['Q1029907']
# ['Q92600']
# ['Q326358']
# ['Q19566']
# ['Q25224', 'Q374453']
# ['Q28']
# ['Q2634']
# ['Q90', 'Q1017', 'Q173219']
# ['Q869']
# ['Q884']
# ['Q1472152']
# ['Q847']
# ['Q741710']
# ['Q656']
# ['Q368121']
# ['Q215901']
# ['Q1711']
# ['Q211260']
# ['Q1741']
# ['Q237105']
# ['Q714']
# ['Q171852']
# ['Q490']
# ['Q328523']
# ['Q129987']
# ['Q1962550']
# ['Q18013']
# ['Q3808']
# ['Q1533']
# ['Q76420']
# ['Q106151']
# ['Q37701']
# ['Q37137', 'Q186506']
# ['Q212']
# ['Q229']
# ['Q4321335']
# ['Q40901', 'Q44384']
# ['Q56005']
# ['Q129279']
# ['Q656']
# ['Q80137']
# ['Q836']
# ['Q43399']
# ['Q230']
# ['Q265']
# ['Q47163']
# ['Q53268']
# ['Q6839']
# ['Q408']
# ['Q271398']
# ['Q33999', 'Q36834', 'Q177220']
# ['Q158688']
# ['Q811']
# ['Q499980', 'Q838611']
# ['Q200905']
# ['Q318427']
# ['Q1542521', 'Q2419102']
# ['Q52607']
# ['Q37320']
# ['Q130752']
# ['Q408']
# ['Q45765']
# ['Q11895']
# ['Q272029', 'Q324319', 'Q327717', 'Q333146']
# ['Q8355']
# ['Q367120']
# ['Q460337']
# ['Q148']
# ['Q1213902', 'Q3129651']
# ['Q619584']
# ['Q3210067']
# ['Q276354']
# ['Q672936']
# ['Q44204']
# ['Q4214909']
# ['Q19100']
# ['Q298']
# ['Q2684']
# ['Q52535']
# ['Q15878']
# ['Q47190']
# ['Q379053']
# ['Q211']
# ['Q9726']
# ['Q924']
# ['Q308657']
# ['Q347685']
# ['Q199943']
# ['Q1043128']
# ['Q178780']
# ['Q47670']
# ['Q156711']
# ['Q545844']
# ['Q656']
# ['Q14712']
# ['Q40912']
# ['Q1930']
# ['Q142']
# ['Q914']
# ['Q6955']
# ['Q127429']
# ['Q97']
# ['Q3844557']
# ['Q5426']
# ['Q40640']
# ['Q230']
# ['Q149067', 'Q15072554', 'Q19799931']
# ['Q37030']
# ['Q41466']
# ['Q419']
# ['Q70981']
# ['Q96']
# ['Q2696558']
# ['Q471726', 'Q918057', 'Q1815797', 'Q3284950', 'Q5575842', 'Q21532983', 'Q28406292']
# ['Q502265']
# ['Q1248784']
# ['Q35610']
# ['Q5369']
# ['Q25344']
# ['Q1519']
# ['Q79804']
# ['Q45656']
# ['Q71']
# ['Q48']
# ['Q1780']
# ['Q49080']
# ['Q724254']
# ['Q49686']
# ['Q84']
# ['Q468467']
# ['Q228889']
# ['Q97', 'Q788']
# ['Q898']
# ['Q656']
# ['Q239']
# ['Q41211']
# ['Q668', 'Q843', 'Q889']
# ['Q23436']
# ['Q1218']
# ['Q170649']
# ['Q130777']
# ['Q862992']
# ['Q680161']
# ['Q379612']
# ['Q4329463']
# ['Q597']
# ['Q503166']
# ['Q23661']
# ['Q237']
# ['Q193592']
# ['Q41604']
# ['Q8717']
# ['Q1770']
# ['Q1435']
# ['Q201568']
# ['Q681697']
# ['Q7200']
# ['Q258']
# ['Q179620']
# ['Q1449']
# ['Q935']
# ['Q44395']
# ['Q159']
# ['Q30']
# ['Q9270']
# ['Q183']
# ['Q754837']
# ['Q12100']
# ['Q3783']
# ['Q28']
# ['Q156724']
# ['Q55208']
# ['Q4327225']
# ['Q25363']
# ['Q178']
# ['Q2263']
# ['Q753', 'Q1096']
# ['Q127892']
# ['Q146667']
# ['Q966571', 'Q2026876']
# ['Q1320718']
# ['Q925']
# ['Q727']
# ['Q171416']
# ['Q2625243']
# ['Q33']
# ['Q165769']
# ['Q717']
# ['Q30']
# ['Q29108']
# ['Q805221', 'Q805253', 'Q2490358', 'Q5716684', 'Q15296811', 'Q18939491']
# ['Q765633']
# ['Q571822']
# ['Q9671', 'Q169898']
# ['Q45']
# ['Q47774']
# ['Q913643']
# ['Q16320']
# ['Q2337']
# ['Q83459']
# ['Q36']
# ['Q106807']
# ['Q167551']
# ['Q326499']
# ['Q2981']
# ['Q145']
# ['Q21127485']
# ['Q38']
# ['Q15720844']
# ['Q748296']
# ['Q181678']
# ['Q4925477']
# ['Q155874']
# ['Q215548']
# ['Q140686', 'Q218295', 'Q842386', 'Q4109060', 'Q4127082', 'Q4399975', 'Q14805701', 'Q27494237', 'Q38715304', 'Q38715670', 'Q38715852']
# ['Q193018']
# ['Q202040']
# ['Q50546603']
# ['Q5254470']
# ['Q232']
# ['Q898795']
# ['Q41466']
# ['Q1615333', 'Q41795540']
# ['Q42267']
# ['Q271934']
# ['Q1875']
# ['Q18552177']
# ['Q29']
# ['Q1978556']
# ['Q57327']
# ['Q7205']
# ['Q673075']
# ['Q1417705']
# ['Q96', 'Q115', 'Q774', 'Q800']
# ['Q239']
# ['Q33244']
# ['Q926']
# ['Q2723928']
# ['Q645719']
# ['Q810']
# ['Q47064', 'Q82955']
# ['Q1891']
# ['Q159']
# ['Q840829', 'Q2359372']
# ['Q208588']
# ['Q61']
# ['Q902320']
# ['Q7604']
# ['Q3519259']
# ['Q1741']
# ['Q1761']
# ['Q818467']
# ['Q210287']
# ['Q182059']
# ['Q63991914']
# ['Q2333']
# ['Q35064']
# ['Q34']
# ['Q627508']
# ['Q18502']
# ['Q46']
# ['Q46', 'Q48']
# ['Q656']
# ['Q4183061']
# ['Q169898', 'Q171329', 'Q171367', 'Q172721']
# ['Q2359372']
# ['Q2245347', 'Q2914850', 'Q72553200', 'Q72553961']
# ['Q17501806']
# ['Q21891843', 'Q23820229', 'Q84499835', 'Q84565071', 'Q84566351', 'Q84572475', 'Q84572977', 'Q84593853', 'Q84599401', 'Q84682501', 'Q84763814', 'Q84947682', 'Q174248', 'Q378120', 'Q580728', 'Q600063', 'Q628212', 'Q662985', 'Q693350', 'Q744598', 'Q748211', 'Q753219', 'Q753289', 'Q753292', 'Q840751', 'Q868618', 'Q942842', 'Q1013032', 'Q1013035', 'Q1624461', 'Q1734030', 'Q1810336', 'Q1811143', 'Q1821473', 'Q1822800', 'Q1963689', 'Q1969345', 'Q1987157', 'Q1996280', 'Q2003486', 'Q2041885', 'Q2048241', 'Q2061921', 'Q2078708', 'Q2216373', 'Q2219104', 'Q2297365', 'Q2317527', 'Q2320562', 'Q2331979', 'Q2403918', 'Q2440414', 'Q2442419', 'Q2446033', 'Q2456160', 'Q2460331', 'Q2467285', 'Q2499127', 'Q2501433', 'Q2533951', 'Q2580968', 'Q2612318', 'Q2623877', 'Q2638290', 'Q2661930', 'Q2689681', 'Q2693443', 'Q2709316', 'Q2717469', 'Q2782104', 'Q2786011', 'Q2795720', 'Q2834321', 'Q3176913', 'Q3489924', 'Q3489932', 'Q3489935', 'Q3490214', 'Q3490254', 'Q3490377', 'Q3490395', 'Q3490530', 'Q3490542', 'Q3490548', 'Q3490702', 'Q3497283', 'Q3499350', 'Q3499380', 'Q3499395', 'Q3499402', 'Q3499406', 'Q3509023', 'Q3509048', 'Q3509354', 'Q3509373', 'Q3509425', 'Q3509446', 'Q3509457', 'Q3509657', 'Q3509772', 'Q3509780', 'Q3509815', 'Q3509834', 'Q3563089', 'Q3563100', 'Q3563133', 'Q3563146', 'Q3563211', 'Q3563232', 'Q3564567', 'Q3566327', 'Q3566606']
# ['Q13641190']
# ['Q2084341', 'Q3273932', 'Q4252909', 'Q4262671']
# ['Q612907', 'Q654471', 'Q762844', 'Q1703180', 'Q1967942', 'Q1992013', 'Q1992153', 'Q1992181', 'Q2268261', 'Q3853593', 'Q3885141', 'Q4188115', 'Q4240311', 'Q4286712', 'Q4286829', 'Q4286849', 'Q4286882', 'Q4286937', 'Q4286990', 'Q4287015', 'Q4287082', 'Q4287097', 'Q4287144', 'Q4375455', 'Q4375533', 'Q12756735', 'Q16481642', 'Q16485587', 'Q18080427', 'Q18080429', 'Q18080612', 'Q19399024', 'Q19910703', 'Q21644047', 'Q24932811', 'Q25394795', 'Q57316823', 'Q95000245']
# ['Q21', 'Q22', 'Q25', 'Q26']
# ['Q20183']
# ['Q4151339', 'Q17287317', 'Q17287320', 'Q17287321']
# ['Q165503']
# ['Q28835', 'Q1275243']
# ['Q1396852']
# ['Q70498154']
# ['Q15288']
# ['Q1444', 'Q5994', 'Q8355', 'Q80284', 'Q81982', 'Q191823', 'Q281460', 'Q1521313']
# ['Q10478']
# ['Q4480733']
# ['Q202243']
# ['Q204752']
# ['Q15', 'Q48']
# ['Q27621', 'Q1978570', 'Q2387574', 'Q2495829', 'Q4525174', 'Q4534839', 'Q27430017']
# ['Q90']
# ['Q1982087']
# ['Q239', 'Q12800833']
# ['Q250', 'Q3966', 'Q5300', 'Q7397', 'Q9143', 'Q183484', 'Q2384798']
# ['Q43421']
# ['Q46', 'Q48']
# ['Q5492408']
# ['Q3964988']
# ['Q579431', 'Q2000835']
# ['Q665105']
# ['Q184437']
# ['Q190543']
# ['Q55766251']
# ['Q72614', 'Q104161', 'Q1384655', 'Q2721194']
# ['Q4315520']
# ['Q49481']
# ['Q213067']
# ['Q188', 'Q1860', 'Q7737', 'Q9027']
# ['Q79082']
# ['Q18']
# ['Q46']
# ['Q8338', 'Q202027', 'Q17172850']
# ['Q739', 'Q8965', 'Q199821', 'Q232564', 'Q1055848', 'Q3591854']
# ['Q902', 'Q330158', 'Q842931', 'Q1850485', 'Q2347909']
# ['Q28']
# ['Q162533']
# ['Q48']
# ['Q847']
# ['Q485176']
# ['Q157443', 'Q192881', 'Q319221', 'Q471839', 'Q761469', 'Q2973181', 'Q20443008']
# ['Q98']
# ['Q37068']
# ['Q37853']
# ['Q54111', 'Q170292']
# ['Q332342', 'Q7744473']
# ['Q13394']
# ['Q324867']
# ['Q4411519']
# ['Q486860']
# ['Q656']
# ['Q1218', 'Q187702', 'Q540882', 'Q1494672', 'Q2280628', 'Q7818625']
# ['Q1332307']
# ['Q210398']
# ['Q8261', 'Q128758', 'Q474090']
# ['Q126399', 'Q621364', 'Q984047', 'Q2924461']
# ['Q23633']
# ['Q126399', 'Q2924461', 'Q3011161', 'Q31197934']
# ['Q1200552', 'Q17343562', 'Q18155354', 'Q22807052']
# ['Q13641190']
# ['Q1589009']
# ['Q75', 'Q880371', 'Q56611700']
# ['Q6581097']
# ['Q675765', 'Q845981', 'Q3984081']
# ['Q1506552', 'Q1938341']
# ['Q27621', 'Q322964', 'Q323681']
# ['Q5994', 'Q8355']
# ['Q165503']
# ['Q27621', 'Q1978570', 'Q2387574', 'Q2495829', 'Q4525174', 'Q4534839', 'Q27430017']
# ['Q5064', 'Q12025', 'Q201873', 'Q207875', 'Q231390', 'Q586421']
# ['Q159909', 'Q14906020']
# ['Q299687']
# ['Q124018']
# ['Q778243']
# ['Q158314']
# ['Q62843', 'Q92743']
# ['Q8743', 'Q315422']
# ['Q76468']
# ['Q34286', 'Q77124', 'Q273314', 'Q318449']
# ['Q133544']
# ['Q4143870']
# ['Q552732']
# ['Q5673']
# ['Q4069095', 'Q4321371']
# ['Q380156', 'Q1395520']
# ['Q4934', 'Q92764']
# ['Q19837', 'Q332591', 'Q483382']
# ['Q7738', 'Q12548', 'Q27306', 'Q33296', 'Q34266', 'Q45670', 'Q68518', 'Q70972', 'Q80702', 'Q127318', 'Q131706', 'Q131981', 'Q153136', 'Q156199', 'Q161885', 'Q168651', 'Q170604', 'Q215443', 'Q215530', 'Q256961', 'Q258532', 'Q310650', 'Q318806', 'Q706018', 'Q830084', 'Q4083686']
# ['Q299687']
# ['Q29637']
# ['Q739711', 'Q1799063']
# ['Q75079']
# ['Q2628071']
# ['Q152293']
# ['Q79965', 'Q170770', 'Q1483495', 'Q4318679']
# ['Q76754', 'Q186203', 'Q4349082']
# ['Q26068']
# ['Q22890', 'Q23666', 'Q38272']
# ['Q76925']
# ['Q76925']
# ['Q538']
# ['Q258896']
# ['Q7603']
# ['Q233282']
# ['Q21', 'Q145']
# ['Q380252']
# ['Q42042', 'Q48362']
# ['Q3333484']
# ['Q25624', 'Q193026', 'Q1347099', 'Q1377980', 'Q2217063']
# ['Q785828']
# ['Q1065', 'Q4230', 'Q4264', 'Q7809', 'Q7817', 'Q7825', 'Q8475', 'Q17495', 'Q19771', 'Q47488', 'Q47539', 'Q123209', 'Q123759', 'Q151991', 'Q182500', 'Q191384', 'Q243630', 'Q340195', 'Q467938', 'Q471690', 'Q499151', 'Q535086', 'Q602399', 'Q605595', 'Q607301', 'Q656801', 'Q827525', 'Q838116', 'Q842490', 'Q943105', 'Q1025959', 'Q1043527', 'Q1045401', 'Q1072120', 'Q1480793', 'Q1484463', 'Q1570993', 'Q2836400', 'Q3369762', 'Q5611262', 'Q10283557']
# ['Q9448']
# ['Q41']
# ['Q258748']
# ['Q1781702']
# ['Q260542']
# ['Q49', 'Q538']
# ['Q37068']
# ['Q7291']
# ['Q2245347', 'Q2914850', 'Q72553200', 'Q72553961']
# ['Q2359372']
# ['Q15804']
# ['Q1256223']
# ['Q649', 'Q656', 'Q891', 'Q900', 'Q1874', 'Q5332', 'Q5337', 'Q5540', 'Q5627', 'Q19566', 'Q21197', 'Q156648', 'Q4092262', 'Q4536541', 'Q4538749']
# ['Q1130019']
# ['Q97']
# ['Q33629']
# ['Q24826']
# ['Q3426']
# ['Q1130019']
# ['Q1457437']
# ['Q649']
# ['Q1902692']
# ['Q586']
# ['Q649']
# ['Q5776']
# ['Q133838']
# ['Q174097']
# ['Q34433', 'Q1643454']
# ['Q3630']
# ['Q5994']
# ['Q1990094']
# ['Q4460646']
# ['Q1422', 'Q8682', 'Q18656', 'Q75729', 'Q267245', 'Q1630430', 'Q1772776', 'Q3590754', 'Q3590758', 'Q21079208']
# ['Q59488']
# ['Q133602']
# ['Q81589', 'Q645968']
# ['Q156255']
# ['Q242446']
# ['Q126399', 'Q2924461']
# ['Q159846', 'Q367466']
# ['Q2914786', 'Q4444575']
# ['Q126399', 'Q622668', 'Q3011161', 'Q31197934']
# ['Q2628487']
# ['Q141336']
# ['Q95', 'Q20800404']
# ['Q269792']
# ['Q127552', 'Q191224']
# ['Q20800404']
# ['Q84']
# ['Q16869', 'Q182009']
# ['Q1533']
# ['Q1957']
# ['Q1858']
# ['Q1353', 'Q11739', 'Q42941', 'Q179046', 'Q3242297']
# ['Q2184', 'Q2895', 'Q130229', 'Q130276', 'Q130280', 'Q131337', 'Q132856', 'Q133356', 'Q168811', 'Q170895', 'Q173761', 'Q186888', 'Q192180', 'Q199707', 'Q199711', 'Q484578', 'Q545205']
# ['Q93728', 'Q178473', 'Q185493', 'Q207826', 'Q208167', 'Q278798', 'Q337463', 'Q465316', 'Q530008', 'Q1069798', 'Q1081449', 'Q1710776', 'Q2297431', 'Q2634074', 'Q2760953', 'Q4137459', 'Q4286836', 'Q4335954', 'Q21292820', 'Q59351315', 'Q60130697', 'Q63975126']
# ['Q37922', 'Q278798', 'Q603631', 'Q695106', 'Q950604', 'Q1026769', 'Q1081503', 'Q1340199', 'Q18200478']
# ['Q475482', 'Q1463070']
# ['Q152951']
# ['Q152951']
# ['Q493898']
# ['Q172326']
# ['Q8355', 'Q81982', 'Q281460']
# ['Q27911']
# ['Q31687']
# ['Q27914']
# ['Q1438774']
# ['Q45700']
# ['Q1425861', 'Q7268181']
# ['Q186506']
# ['Q379053']
# ['Q180729', 'Q181951', 'Q1059510', 'Q1277249', 'Q2494846', 'Q4862955']
# ['Q28989']
# ['Q9268']
# ['Q432', 'Q5043']
# ['Q1394287']
# ['Q2498026']
# ['Q23759071']
# ['Q345']
# ['Q7041639']
# ['Q95', 'Q20800404']
# ['Q1966985']
# ['Q1744']
# ['Q377', 'Q191480']
# ['Q42511']
# ['Q15151625']
# ['Q15151625']
# ['Q4069095', 'Q4321371', 'Q4360695']
# ['Q19837', 'Q332591', 'Q483382']
# ['Q40224', 'Q57098', 'Q70788']
# ['Q5284', 'Q162005']
# ['Q40224', 'Q57098', 'Q70788']
# ['Q44412']
# ['Q37064']
# ['Q50224531']
# ['Q3140459']
# ['Q1060165']
# ['Q2283', 'Q1129295']
# ['Q4132607']
# ['Q195719']
# ['Q42574']
# ['Q4934', 'Q92764']
# ['Q76368']
# ['Q4419809', 'Q4498457']
# ['Q929273', 'Q929285', 'Q2071256', 'Q16253333', 'Q57022061']
# ['Q15072147']
# ['Q315188']
# ['Q191598']
# ['Q97']
# ['Q1406', 'Q5014725', 'Q13361286', 'Q64513817']
# ['Q1406', 'Q5014725', 'Q13361286']
# ['Q280658']
# ['Q280658', 'Q8025128']
# ['Q3542']
# ['Q15243', 'Q203462']
# ['Q2160']
# ['Q19686', 'Q19914']
# ['Q166162']
# ['Q1457453']
# ['Q4320732']
# ['Q166162']
# ['Q13199', 'Q15087', 'Q33754', 'Q387066']
# ['Q80284']
# ['Q31561', 'Q79838', 'Q178389', 'Q4501563', 'Q17172850']
# ['Q8343']
# ['Q3238057', 'Q13785927']
# ['Q5710', 'Q809806', 'Q1092754', 'Q1390649', 'Q4479125', 'Q4479136', 'Q15190285']
# ['Q408', 'Q3258', 'Q15577']
# ['Q980', 'Q10544', 'Q10562']
# ['Q1019', 'Q489821', 'Q5501842']
# ['Q225', 'Q11196', 'Q11198', 'Q18276', 'Q208545', 'Q1274468', 'Q2055400']
# ['Q252', 'Q3757', 'Q523435']
# ['Q766', 'Q651453', 'Q2526023']
# ['Q424', 'Q1054184', 'Q3173090']
# ['Q40', 'Q12548', 'Q28513', 'Q42497', 'Q131964', 'Q153136', 'Q176495', 'Q268970', 'Q518101', 'Q699964', 'Q3624335', 'Q16056854']
# ['Q5446', 'Q788066', 'Q2391775', 'Q6671523', 'Q14558462', 'Q18055588']
# ['Q672', 'Q21815222']
# ['Q854']
# ['Q1008', 'Q845706']
# ['Q1368300']
# ['Q432']
# ['Q775909']
# ['Q4239246']
# ['Q1497']
# ['Q371828', 'Q1324152']
# ['Q207706']
# ['Q4218621']
# ['Q2280', 'Q173822', 'Q185700', 'Q188732', 'Q189822', 'Q191061', 'Q192959']
# ['Q5681011']
# ['Q16157447']
# ['Q361', 'Q2140994', 'Q4081756', 'Q4097857', 'Q4255538']
# ['Q9448']
# ['Q656', 'Q9248', 'Q155243', 'Q196388', 'Q1020157', 'Q4322358']
# ['Q917830']
# ['Q27621', 'Q2654435', 'Q4139211']
# ['Q973']
# ['Q1065', 'Q7184', 'Q7785', 'Q7809', 'Q7825', 'Q8475', 'Q17495', 'Q19771', 'Q37143', 'Q38130', 'Q41550', 'Q81299', 'Q123759', 'Q134102', 'Q170481', 'Q181574', 'Q188822', 'Q191384', 'Q233611', 'Q340195', 'Q376150', 'Q656801', 'Q674182', 'Q782942', 'Q826700', 'Q827525', 'Q842490', 'Q899770', 'Q1043527', 'Q1072120', 'Q1480793', 'Q1928989', 'Q2863003', 'Q3772571', 'Q3866537', 'Q4033111', 'Q4426267', 'Q5150848', 'Q5611262', 'Q7768229', 'Q7886981']
# ['Q167541']
# ['Q182165']
# ['Q76751']
# ['Q5284', 'Q162005']
# ['Q557305', 'Q861967']
# ['Q104898']
# ['Q58792', 'Q80919']
# ['Q1189073', 'Q6895015']
# ['Q182994']
# ['Q46']
# ['Q207591']
# ['Q10857409']
# ['Q782363']
# ['Q736587']
# ['Q649', 'Q656', 'Q1731', 'Q4079059', 'Q4471180']
# ['Q234460', 'Q1069725', 'Q1980247']
# ['Q3642350']
# ['Q101978']
# ['Q49542', 'Q79797', 'Q482942', 'Q1129737', 'Q10290517']
# ['Q19831455']
# ['Q372657', 'Q505275', 'Q22032185']
# ['Q134161', 'Q891723']
# ['Q75745', 'Q248756', 'Q785531', 'Q808176', 'Q854686', 'Q1009177', 'Q1054311', 'Q2090382', 'Q2462900', 'Q2921573', 'Q3017105', 'Q3196524', 'Q4074592', 'Q4081114', 'Q4222569', 'Q4246441', 'Q4375034', 'Q4408691', 'Q4424133', 'Q4427701', 'Q4460344', 'Q14915363', 'Q14915364', 'Q14915365', 'Q14915367', 'Q14915368', 'Q14915369', 'Q14915370', 'Q14915425', 'Q14915428', 'Q14915447', 'Q14915448', 'Q14915449', 'Q14915450', 'Q14915451', 'Q14915452', 'Q14915453', 'Q14915454', 'Q14915455', 'Q14915456', 'Q14915457', 'Q14915458', 'Q14915459', 'Q14915460', 'Q14915461', 'Q14915462', 'Q14915463', 'Q14915464', 'Q14915465', 'Q14915466', 'Q14915467', 'Q14915468', 'Q14915469', 'Q14915470', 'Q14915471', 'Q14915472', 'Q14915473', 'Q14915474', 'Q14915475', 'Q14915476', 'Q14915477', 'Q14915478', 'Q14915479', 'Q14915480', 'Q14915481', 'Q14915482', 'Q14915483', 'Q14915484', 'Q14915485', 'Q14915486', 'Q14915489', 'Q14915490', 'Q14943318', 'Q14943338', 'Q14943342', 'Q21036227', 'Q21036228', 'Q21036229', 'Q21036230', 'Q27679334', 'Q35267412']
# ['Q185493', 'Q208167', 'Q241821', 'Q278798', 'Q337463', 'Q530008', 'Q946626', 'Q1067644', 'Q1069798', 'Q1710776', 'Q2329480', 'Q2634074', 'Q4335936', 'Q4335954', 'Q4375624', 'Q21292820', 'Q56669004', 'Q60054123']
# ['Q41144', 'Q41146', 'Q43269', 'Q43271', 'Q130343', 'Q165582', 'Q170453', 'Q190687', 'Q190922', 'Q191164', 'Q191174', 'Q191186', 'Q201121', 'Q201137', 'Q202068', 'Q202071', 'Q202075', 'Q204876', 'Q205460', 'Q205776', 'Q205784', 'Q205796', 'Q205824', 'Q205843', 'Q492791']
# ['Q1085', 'Q46070', 'Q188373', 'Q188399', 'Q190550', 'Q190930', 'Q191091', 'Q192536', 'Q192697', 'Q192702', 'Q193266', 'Q193295', 'Q193307', 'Q193317']
# ['Q1490', 'Q15701', 'Q44843', 'Q47896', 'Q48326', 'Q71699', 'Q71707', 'Q80011', 'Q80434', 'Q81863', 'Q83273', 'Q120730', 'Q122723', 'Q123258', 'Q123376', 'Q125863', 'Q127264', 'Q127513', 'Q127877', 'Q128186', 'Q128196', 'Q129499', 'Q130290', 'Q130300', 'Q130308', 'Q131277', 'Q131281', 'Q131287', 'Q131314', 'Q131320', 'Q131358', 'Q132705', 'Q132720', 'Q132751', 'Q132929', 'Q132936', 'Q133879', 'Q133924', 'Q133935', 'Q134093', 'Q160420', 'Q160734', 'Q161454', 'Q169376', 'Q617375', 'Q766445', 'Q1037393']
# ['Q4156896']
# ['Q7325']
# ['Q6581097']
# ['Q5256775']
# ['Q10693']
# ['Q12482', 'Q44455', 'Q189088', 'Q1554323', 'Q1766038', 'Q1970172', 'Q2895315', 'Q4056286', 'Q4358367', 'Q5498822']
# ['Q928993']
# ['Q20818052']
# ['Q76754', 'Q186203', 'Q4349082']
# ['Q67186598']
# ['Q4035237']
# ['Q52410688']
# ['Q3772']
# ['Q4417863']
# ['Q60100']
# ['Q41602']
# ['Q217925', 'Q2873520']
# ['Q23898959']
# ['Q27621']
# ['Q1566', 'Q199344', 'Q736556']
# ['Q182994']
# ['Q2532727']
# ['Q65032731']
# ['Q47591', 'Q4520962']
# ['Q11297']
# ['Q1370', 'Q523606', 'Q5425102']
# ['Q3279650']
# ['Q6635', 'Q645924']
# ['Q11002', 'Q11254', 'Q41534', 'Q93189', 'Q815740', 'Q4739805', 'Q61503220']
# ['Q50407282']
# ['Q3739104']
# ['Q171558']
# ['Q3739104']
# ['Q3739104']
# ['Q337463']
# ['Q756727', 'Q2747456']
# ['Q202009', 'Q918052', 'Q1167442', 'Q1756055', 'Q3163406']
# ['Q54111']
# ['Q11366', 'Q188450', 'Q484641']
# ['Q3273722']
# ['Q40855']
# ['Q73801', 'Q308913', 'Q611508', 'Q735267', 'Q1046593', 'Q1202130', 'Q2080076', 'Q2469781']
# ['Q157802']
# ['Q4204467']
# ['Q483654']
# ['Q483654', 'Q3333484']
# ['Q547869']
# ['Q27703517']
# ['Q892']
# ['Q1402143']
# ['Q128267', 'Q186350']
# ['Q3415248']
# ['Q4418820']
# ['Q1273278']
# ['Q42574']
# ['Q56008']
# ['Q187364']
# ['Q726105']
# ['Q56005']
# ['Q8877', 'Q6758800']
# ['Q56005']
# ['Q80135']
# ['Q33629']
# ['Q8025128']
# ['Q8025128']
# ['Q8025128']
# ['Q626']
# ['Q3447', 'Q27538353']
# ['Q38', 'Q1282', 'Q18288160']
# ['Q487003']
# ['Q228986']
# ['Q23746012']
# ['Q4301841']
# ['Q1711668']
# ['Q1768082']
# ['Q968028']
# ['Q192239']
# ['Q434841']
# ['Q157802']
# ['Q178473', 'Q185493', 'Q209896', 'Q478850', 'Q530008', 'Q534981', 'Q583881', 'Q612907', 'Q694401', 'Q728960', 'Q791135', 'Q1311063', 'Q1415232', 'Q1428575', 'Q1992013', 'Q2028781', 'Q2268261', 'Q2300740', 'Q2638119', 'Q2660844', 'Q4193236', 'Q9387384', 'Q18080427', 'Q18080429', 'Q18080431', 'Q21405589', 'Q89211387']
# ['Q97']
# ['Q27698']
# ['Q946428']
# ['Q33629']
# ['Q834621']
# ['Q4918']
# ['Q1247']
# ['Q17723']
# ['Q515869', 'Q25060578']
# ['Q44626']
# ['Q393864']
# ['Q4393561']
# ['Q847', 'Q5377', 'Q80131']
# ['Q134307', 'Q170571', 'Q191163']
# ['Q207591']
# ['Q130232', 'Q2254193', 'Q52207399']
# ['Q393']
# ['Q141336']
# ['Q5168']
# ['Q5222']
# ['Q900']
# ['Q33405']
# ['Q3114']
# ['Q748', 'Q427945', 'Q2279088']
# ['Q299687']
# ['Q49481']
# ['Q7349']
# ['Q49481']
# ['Q150', 'Q188', 'Q652', 'Q13199']
# ['Q188']
# ['Q23438']
# ['Q3616']
# ['Q174193']
# ['Q11399', 'Q187760', 'Q598929']
# ['Q8341', 'Q9759', 'Q203775', 'Q207378', 'Q1196752', 'Q1530455']
# ['Q37068']
# ['Q39427']
# ['Q37853']
# ['Q4992220']
# ['Q736587']
# ['Q112707']
# ['Q161179', 'Q177540', 'Q223197', 'Q583582', 'Q1055000']
# ['Q8261']
# ['Q189635']
# ['Q181754']
# ['Q181754']
# ['Q125168', 'Q1501888']
# ['Q1471878', 'Q3983766']
# ['Q31687']
# ['Q1218']
# ['Q1520']
# ['Q1930']
# ['Q28218']
# ['Q31687']
# ['Q2618625']
# ['Q739000']
# ['Q767288']
# ['Q51199', 'Q4228172']
# ['Q240150']
# ['Q8958']
# ['Q762']
# ['Q204138']
# ['Q2382967']
# ['Q358556']
# ['Q700540']
# ['Q314287']
# ['Q4768']
# ['Q1144905']
# ['Q9217']
# ['Q1568', 'Q1860']
# ['Q150', 'Q1860']
# ['Q150']
# ['Q1682', 'Q1684', 'Q161455', 'Q300875', 'Q316287', 'Q324404', 'Q562206', 'Q671428', 'Q694789', 'Q697916', 'Q821135', 'Q1532109', 'Q1538524', 'Q1646276', 'Q3908364']
# ['Q188', 'Q36668']
# ['Q5146', 'Q750553', 'Q3436689']
# ['Q13955']
# ['Q8821']
# ['Q809']
# ['Q37217']
# ['Q78994', 'Q858913', 'Q1025134', 'Q1088879', 'Q1194172', 'Q1347209', 'Q1985387', 'Q2234632', 'Q2372093', 'Q2914954']
# ['Q30']
# ['Q164800']
# ['Q80113', 'Q166713']
# ['Q217128']
# ['Q762']
# ['Q130777']
# ['Q76432', 'Q76745', 'Q76747']
# ['Q11570']
# top1 accuracy t5-3b-ssm-nqo RuBQ =  = 0.2765598650927487

# %% [markdown]
# # google/t5-xl-ssm-nq

# %%
# !nvidia-cdl
# Out:
# Driver version: 510.85.02
# ------------------- Device 0 -------------------
# Name: NVIDIA GeForce RTX 3090 Ti
# Memory usage:  4407MiB / 24564MiB
# Temperature: 20C
# Running processes not found
#
# ------------------- Device 1 -------------------
# Name: NVIDIA GeForce RTX 3090 Ti
# Memory usage: 12387MiB / 24564MiB
# Temperature: 20C
# Running processes not found
#
# ------------------- Device 2 -------------------
# Name: NVIDIA GeForce RTX 3090 Ti
# Memory usage: 13837MiB / 24564MiB
# Temperature: 32C
# Running processes not found
#
# ------------------- Device 3 -------------------
# Name: NVIDIA GeForce RTX 3090 Ti
# Memory usage:   316MiB / 24564MiB
# Temperature: 21C
# Running processes not found
#
# ------------------- Device 4 -------------------
# Name: NVIDIA GeForce RTX 2080 Ti
# Memory usage:  9196MiB / 11264MiB
# Temperature: 21C
# Running processes not found
#
# ------------------- Device 5 -------------------
# Name: NVIDIA GeForce RTX 2080 Ti
# Memory usage:  9188MiB / 11264MiB
# Temperature: 21C
# Running processes not found

# %%
t5_qa_model = AutoModelForSeq2SeqLM.from_pretrained("google/t5-xl-ssm-nq")#"google/t5-11b-ssm-tqa")
t5_tok = AutoTokenizer.from_pretrained("google/t5-xl-ssm-nq")
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
t5_qa_model.to(device)
# Out:
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/11.4G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.86k [00:00<?, ?B/s]
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 2048)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 2048)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#               (relative_attention_bias): Embedding(32, 32)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (2): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (3): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (4): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (5): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (6): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (7): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (8): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (9): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (10): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (11): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (12): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (13): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (14): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (15): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (16): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (17): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (18): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (19): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (20): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (21): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (22): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (23): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=2048, out_features=2048, bias=False)
#               (k): Linear(in_features=2048, out_features=2048, bias=False)
#               (v): Linear(in_features=2048, out_features=2048, bias=False)
#               (o): Linear(in_features=2048, out_features=2048, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#               (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#               (wo): Linear(in_features=5120, out_features=2048, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=2048, out_features=32128, bias=False)
# )

# %%
acc_o, preds_id_sq_o = check_t5_sq(t5_tok = t5_tok, t5_qa_model = t5_qa_model)
# Out:
# 100%|██████████| 4751/4751 [11:02<00:00,  7.17it/s]
# 100%|██████████| 4751/4751 [00:00<00:00, 811101.36it/s]

# %%
print("top1 accuracy t5-xl-ssm-nq SQ = ", acc_o)
# Out:
# top1 accuracy t5-xl-ssm-nq SQ =  0.07472111134498001

# %%
rubq_test = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")

answers = []
for i in tqdm(range(len(rubq_test))):
    input_ids = t5_tok(rubq_test[i], return_tensors="pt").input_ids
    input_ids = input_ids.to(device)
    gen_output = t5_qa_model.generate(input_ids)[0]
    answers.append(gen_output)
    
    
final = []
for x in answers:
    final.append(t5_tok.decode(x, skip_special_tokens=True))

    
#rubq_questions = np.load("all_EN_rubq_test_questions_1_hop_uri.npy")
entities_test_rubq = np.load("entities_test_rubq.npy")
rubq_test = pd.DataFrame({"subject":entities_test_rubq, "question":rubq_test})
rubq_test_answers = np.load("all_rubq_test_answers_1_hop_uri.npy", allow_pickle=True)

# answers_rubq = []

# for lis in rubq_test_answers:
#     print(lis)
#     new = []
#     for element in lis:
#         new.append(get_description_name(element))

#     answers_rubq.append(new)
    
preds = []
for i in range(len(final)):
    try:
        x = from_text_to_id(final[i])
    except:
        x = "None"
    
    preds.append(x)
    
np.save("predictions_rubq_test_t5_3b_ssm_nq.npy", np.array(final))

answers_rubq = []

for lis in rubq_test_answers:
    print(lis)
    new = []
    for element in lis:
        new.append(element)

    answers_rubq.append(new)

right = 0

for i, ans in enumerate(answers_rubq):
    if preds[i] in ans:
        right += 1
    else:
        pass
    
print(f"top1 accuracy t5-xl-ssm-nq RuBQ =  = {right/len(preds)}")
# Out:
# 100%|██████████| 1186/1186 [02:57<00:00,  6.68it/s]
# ['Q7944', 'Q60186', 'Q167903', 'Q2580904', 'Q5975740', 'Q7692360']
# ['Q102513']
# ['Q692']
# ['Q19660']
# ['Q6607', 'Q483994', 'Q626035', 'Q2643890', 'Q17172850']
# ['Q142']
# ['Q299687']
# ['Q312480']
# ['Q29']
# ['Q4022']
# ['Q796']
# ['Q38768', 'Q201605', 'Q1676638']
# ['Q22']
# ['Q11420', 'Q106500']
# ['Q4808485']
# ['Q2838011']
# ['Q9299872']
# ['Q2674728']
# ['Q1968651']
# ['Q1088']
# ['Q7737', 'Q29561']
# ['Q36124']
# ['Q43']
# ['Q49481']
# ['Q424', 'Q869', 'Q881']
# ['Q148', 'Q837']
# ['Q232']
# ['Q408']
# ['Q816']
# ['Q847', 'Q5377']
# ['Q30']
# ['Q1792']
# ['Q822290']
# ['Q1603']
# ['Q181306', 'Q213344', 'Q237367', 'Q1326237']
# ['Q237800']
# ['Q106151']
# ['Q201598']
# ['Q223134']
# ['Q106010']
# ['Q29445']
# ['Q40591', 'Q58784', 'Q295347', 'Q470600']
# ['Q1850']
# ['Q4719']
# ['Q157683']
# ['Q158491']
# ['Q62']
# ['Q24861']
# ['Q3787']
# ['Q8338', 'Q202027', 'Q17172850']
# ['Q55']
# ['Q19675']
# ['Q36180', 'Q82955', 'Q185351', 'Q333634', 'Q1209498', 'Q1297719', 'Q4964182', 'Q11774202', 'Q18814623']
# ['Q22']
# ['Q1048']
# ['Q9191']
# ['Q687']
# ['Q1860923']
# ['Q178577']
# ['Q199588']
# ['Q79759']
# ['Q31628']
# ['Q57966']
# ['Q133622']
# ['Q360292']
# ['Q128790']
# ['Q236233']
# ['Q152293']
# ['Q15862']
# ['Q723764']
# ['Q783']
# ['Q767288']
# ['Q31628']
# ['Q142']
# ['Q40357']
# ['Q1048']
# ['Q159']
# ['Q2064699', 'Q4304132']
# ['Q668']
# ['Q112']
# ['Q49111']
# ['Q131026']
# ['Q11419']
# ['Q6502703']
# ['Q172911']
# ['Q212115']
# ['Q1069868']
# ['Q897']
# ['Q869']
# ['Q41']
# ['Q10737']
# ['Q6862']
# ['Q40059']
# ['Q35591']
# ['Q2332']
# ['Q1205']
# ['Q31015', 'Q241214']
# ['Q586']
# ['Q891']
# ['Q1472', 'Q12133', 'Q35869', 'Q41083', 'Q110315', 'Q131742', 'Q147778', 'Q193894', 'Q653078', 'Q2025687', 'Q2035074', 'Q3144986']
# ['Q144144']
# ['Q34981']
# ['Q185027']
# ['Q47369']
# ['Q45']
# ['Q81214']
# ['Q51']
# ['Q4964182']
# ['Q46599']
# ['Q6816']
# ['Q46']
# ['Q1875']
# ['Q5470']
# ['Q165503']
# ['Q25261', 'Q46255']
# ['Q925']
# ['Q790']
# ['Q13695']
# ['Q24826']
# ['Q1035', 'Q82122']
# ['Q2568844']
# ['Q149067']
# ['Q170737']
# ['Q626']
# ['Q395', 'Q7754', 'Q41217', 'Q149999', 'Q56114489']
# ['Q157623']
# ['Q159']
# ['Q5592']
# ['Q626']
# ['Q28244']
# ['Q16559']
# ['Q944527']
# ['Q8027']
# ['Q70']
# ['Q10484']
# ['Q47059']
# ['Q93351']
# ['Q762']
# ['Q214196']
# ['Q130498']
# ['Q30204']
# ['Q157623']
# ['Q31']
# ['Q854']
# ['Q170513']
# ['Q5806']
# ['Q37853']
# ['Q1918252']
# ['Q34']
# ['Q43106']
# ['Q5422']
# ['Q29445']
# ['Q219']
# ['Q664']
# ['Q13989']
# ['Q201330']
# ['Q84']
# ['Q2807']
# ['Q40']
# ['Q949424']
# ['Q935']
# ['Q4181867']
# ['Q109676']
# ['Q155626']
# ['Q1981162']
# ['Q33629']
# ['Q739362']
# ['Q211513', 'Q214666', 'Q319861']
# ['Q38']
# ['Q16']
# ['Q240150']
# ['Q192239', 'Q12799318']
# ['Q2736']
# ['Q2844']
# ['Q804']
# ['Q43105']
# ['Q150445']
# ['Q419']
# ['Q258', 'Q1013', 'Q1030']
# ['Q467118']
# ['Q424']
# ['Q739']
# ['Q38337']
# ['Q2044']
# ['Q44703']
# ['Q4872']
# ['Q145']
# ['Q4534523']
# ['Q7315']
# ['Q887']
# ['Q3114']
# ['Q16']
# ['Q36', 'Q211274']
# ['Q8743']
# ['Q154269', 'Q316417', 'Q336810', 'Q432752', 'Q463833']
# ['Q201330']
# ['Q1265']
# ['Q176371']
# ['Q131233']
# ['Q43279']
# ['Q3904', 'Q101418']
# ['Q9268']
# ['Q408']
# ['Q29']
# ['Q1369676']
# ['Q48103', 'Q857244', 'Q17232562']
# ['Q30']
# ['Q298', 'Q414']
# ['Q191159']
# ['Q9215']
# ['Q183']
# ['Q664']
# ['Q1460']
# ['Q851']
# ['Q40909']
# ['Q656']
# ['Q203236']
# ['Q14515330']
# ['Q8810']
# ['Q42941']
# ['Q1524']
# ['Q181114']
# ['Q129352']
# ['Q14773']
# ['Q36600']
# ['Q167420']
# ['Q83186']
# ['Q130531']
# ['Q167646', 'Q171839', 'Q736813']
# ['Q6585']
# ['Q811']
# ['Q835']
# ['Q45']
# ['Q408']
# ['Q42831']
# ['Q762']
# ['Q10686']
# ['Q1850']
# ['Q15807']
# ['Q1003']
# ['Q183']
# ['Q28']
# ['Q1532068']
# ['Q801']
# ['Q3859']
# ['Q170292', 'Q191105']
# ['Q127888']
# ['Q319708']
# ['Q25328']
# ['Q58035']
# ['Q468621', 'Q15071896']
# ['Q29', 'Q142']
# ['Q9191']
# ['Q38']
# ['Q164761', 'Q165704', 'Q170737', 'Q178108', 'Q180935', 'Q182570', 'Q185027', 'Q191691', 'Q334734', 'Q537769']
# ['Q43114']
# ['Q1726', 'Q131610']
# ['Q4412']
# ['Q501']
# ['Q205375', 'Q1281618', 'Q1930187']
# ['Q134942']
# ['Q4167647']
# ['Q162737']
# ['Q172089']
# ['Q34038']
# ['Q813']
# ['Q7947']
# ['Q215556']
# ['Q6934']
# ['Q33231', 'Q36180', 'Q49757', 'Q161944', 'Q170790', 'Q4853732', 'Q4964182', 'Q6625963', 'Q14565331', 'Q18814623', 'Q18939491']
# ['Q15208']
# ['Q916']
# ['Q35881']
# ['Q38']
# ['Q948']
# ['Q57479']
# ['Q265']
# ['Q320653']
# ['Q275354']
# ['Q8006']
# ['Q8409']
# ['Q60']
# ['Q193592']
# ['Q60']
# ['Q8678']
# ['Q718']
# ['Q1186567']
# ['Q1754954']
# ['Q155856']
# ['Q718']
# ['Q48211', 'Q297032']
# ['Q6574', 'Q6655']
# ['Q715281']
# ['Q47293']
# ['Q47293']
# ['Q4768']
# ['Q110228']
# ['Q193064']
# ['Q762']
# ['Q217128']
# ['Q183']
# ['Q170984', 'Q372254']
# ['Q741157']
# ['Q208008']
# ['Q212']
# ['Q131210']
# ['Q27911']
# ['Q34575']
# ['Q11629']
# ['Q83891']
# ['Q78707']
# ['Q9391']
# ['Q3926', 'Q5465', 'Q37701']
# ['Q44363', 'Q82586']
# ['Q592289']
# ['Q28603']
# ['Q219']
# ['Q32024']
# ['Q10570']
# ['Q188']
# ['Q184222']
# ['Q35657']
# ['Q267861', 'Q1323788']
# ['Q133026']
# ['Q33999', 'Q36834', 'Q49757', 'Q177220', 'Q183945', 'Q488205', 'Q662729', 'Q753110', 'Q1028181', 'Q13235160', 'Q16323111', 'Q29017403']
# ['Q148']
# ['Q36']
# ['Q28389', 'Q36180', 'Q49757', 'Q214917', 'Q482980', 'Q6625963']
# ['Q185118', 'Q81200227']
# ['Q38']
# ['Q164714']
# ['Q269668']
# ['Q4257378']
# ['Q151209']
# ['Q315185']
# ['Q716794']
# ['Q912050', 'Q2453629']
# ['Q6397066']
# ['Q186083']
# ['Q220437']
# ['Q14435']
# ['Q72']
# ['Q69060']
# ['Q182101']
# ['Q403']
# ['Q4202', 'Q5871']
# ['Q302849']
# ['Q326827']
# ['Q192134']
# ['Q183']
# ['Q845210']
# ['Q1773']
# ['Q1205']
# ['Q42574']
# ['Q155']
# ['Q333246']
# ['Q230']
# ['Q23124']
# ['Q170513']
# ['Q408']
# ['Q108316']
# ['Q819']
# ['Q11930']
# ['Q3711']
# ['Q47154']
# ['Q711']
# ['Q5338']
# ['Q200797']
# ['Q7200']
# ['Q21']
# ['Q51641', 'Q2907211', 'Q7311705', 'Q7796966', 'Q7796967', 'Q7796969', 'Q12403826', 'Q12403830', 'Q12404028', 'Q12408472', 'Q12408583', 'Q12408584']
# ['Q36834', 'Q486748']
# ['Q142']
# ['Q36215']
# ['Q167997']
# ['Q3915']
# ['Q3919']
# ['Q38111', 'Q41148', 'Q80966', 'Q160432', 'Q170572', 'Q179414', 'Q188772', 'Q192402', 'Q201842', 'Q223091', 'Q223110', 'Q233882', 'Q236613', 'Q241025', 'Q264996', 'Q310394', 'Q311453', 'Q357762', 'Q437752', 'Q481954', 'Q483379', 'Q536437', 'Q918404', 'Q1189169', 'Q1190406', 'Q1680304', 'Q2865151', 'Q3127916', 'Q3501718', 'Q3573721', 'Q25768136']
# ['Q258']
# ['Q183']
# ['Q1541']
# ['Q220']
# ['Q27']
# ['Q3844']
# ['Q204138']
# ['Q140001']
# ['Q1761', 'Q135501', 'Q659895', 'Q1263215', 'Q1672830', 'Q1766409', 'Q2062702', 'Q2088319', 'Q2350741', 'Q5242183', 'Q5500969', 'Q7417543', 'Q13156901', 'Q28601860']
# ['Q8338', 'Q17172850']
# ['Q2092607']
# ['Q236132', 'Q456257']
# ['Q150']
# ['Q683695']
# ['Q17714']
# ['Q69354']
# ['Q229107']
# ['Q17', 'Q188712']
# ['Q623']
# ['Q167646']
# ['Q212']
# ['Q34990']
# ['Q255']
# ['Q45765']
# ['Q31966']
# ['Q108429']
# ['Q155327']
# ['Q157065']
# ['Q1151']
# ['Q176371']
# ['Q656043']
# ['Q30']
# ['Q133274']
# ['Q935']
# ['Q41484']
# ['Q7364']
# ['Q34404']
# ['Q241']
# ['Q8343']
# ['Q40939']
# ['Q204627']
# ['Q894']
# ['Q170737']
# ['Q79']
# ['Q1554208', 'Q1969437']
# ['Q38']
# ['Q35500']
# ['Q1147806']
# ['Q645']
# ['Q5885', 'Q13267']
# ['Q5776']
# ['Q811']
# ['Q843']
# ['Q8667']
# ['Q152513']
# ['Q2133873']
# ['Q557323']
# ['Q695']
# ['Q7200']
# ['Q6607', 'Q17172850']
# ['Q8686']
# ['Q38']
# ['Q829']
# ['Q4214909']
# ['Q239337']
# ['Q42493']
# ['Q30']
# ['Q1069', 'Q8008', 'Q46255']
# ['Q1016']
# ['Q1029907']
# ['Q92600']
# ['Q326358']
# ['Q19566']
# ['Q25224', 'Q374453']
# ['Q28']
# ['Q2634']
# ['Q90', 'Q1017', 'Q173219']
# ['Q869']
# ['Q884']
# ['Q1472152']
# ['Q847']
# ['Q741710']
# ['Q656']
# ['Q368121']
# ['Q215901']
# ['Q1711']
# ['Q211260']
# ['Q1741']
# ['Q237105']
# ['Q714']
# ['Q171852']
# ['Q490']
# ['Q328523']
# ['Q129987']
# ['Q1962550']
# ['Q18013']
# ['Q3808']
# ['Q1533']
# ['Q76420']
# ['Q106151']
# ['Q37701']
# ['Q37137', 'Q186506']
# ['Q212']
# ['Q229']
# ['Q4321335']
# ['Q40901', 'Q44384']
# ['Q56005']
# ['Q129279']
# ['Q656']
# ['Q80137']
# ['Q836']
# ['Q43399']
# ['Q230']
# ['Q265']
# ['Q47163']
# ['Q53268']
# ['Q6839']
# ['Q408']
# ['Q271398']
# ['Q33999', 'Q36834', 'Q177220']
# ['Q158688']
# ['Q811']
# ['Q499980', 'Q838611']
# ['Q200905']
# ['Q318427']
# ['Q1542521', 'Q2419102']
# ['Q52607']
# ['Q37320']
# ['Q130752']
# ['Q408']
# ['Q45765']
# ['Q11895']
# ['Q272029', 'Q324319', 'Q327717', 'Q333146']
# ['Q8355']
# ['Q367120']
# ['Q460337']
# ['Q148']
# ['Q1213902', 'Q3129651']
# ['Q619584']
# ['Q3210067']
# ['Q276354']
# ['Q672936']
# ['Q44204']
# ['Q4214909']
# ['Q19100']
# ['Q298']
# ['Q2684']
# ['Q52535']
# ['Q15878']
# ['Q47190']
# ['Q379053']
# ['Q211']
# ['Q9726']
# ['Q924']
# ['Q308657']
# ['Q347685']
# ['Q199943']
# ['Q1043128']
# ['Q178780']
# ['Q47670']
# ['Q156711']
# ['Q545844']
# ['Q656']
# ['Q14712']
# ['Q40912']
# ['Q1930']
# ['Q142']
# ['Q914']
# ['Q6955']
# ['Q127429']
# ['Q97']
# ['Q3844557']
# ['Q5426']
# ['Q40640']
# ['Q230']
# ['Q149067', 'Q15072554', 'Q19799931']
# ['Q37030']
# ['Q41466']
# ['Q419']
# ['Q70981']
# ['Q96']
# ['Q2696558']
# ['Q471726', 'Q918057', 'Q1815797', 'Q3284950', 'Q5575842', 'Q21532983', 'Q28406292']
# ['Q502265']
# ['Q1248784']
# ['Q35610']
# ['Q5369']
# ['Q25344']
# ['Q1519']
# ['Q79804']
# ['Q45656']
# ['Q71']
# ['Q48']
# ['Q1780']
# ['Q49080']
# ['Q724254']
# ['Q49686']
# ['Q84']
# ['Q468467']
# ['Q228889']
# ['Q97', 'Q788']
# ['Q898']
# ['Q656']
# ['Q239']
# ['Q41211']
# ['Q668', 'Q843', 'Q889']
# ['Q23436']
# ['Q1218']
# ['Q170649']
# ['Q130777']
# ['Q862992']
# ['Q680161']
# ['Q379612']
# ['Q4329463']
# ['Q597']
# ['Q503166']
# ['Q23661']
# ['Q237']
# ['Q193592']
# ['Q41604']
# ['Q8717']
# ['Q1770']
# ['Q1435']
# ['Q201568']
# ['Q681697']
# ['Q7200']
# ['Q258']
# ['Q179620']
# ['Q1449']
# ['Q935']
# ['Q44395']
# ['Q159']
# ['Q30']
# ['Q9270']
# ['Q183']
# ['Q754837']
# ['Q12100']
# ['Q3783']
# ['Q28']
# ['Q156724']
# ['Q55208']
# ['Q4327225']
# ['Q25363']
# ['Q178']
# ['Q2263']
# ['Q753', 'Q1096']
# ['Q127892']
# ['Q146667']
# ['Q966571', 'Q2026876']
# ['Q1320718']
# ['Q925']
# ['Q727']
# ['Q171416']
# ['Q2625243']
# ['Q33']
# ['Q165769']
# ['Q717']
# ['Q30']
# ['Q29108']
# ['Q805221', 'Q805253', 'Q2490358', 'Q5716684', 'Q15296811', 'Q18939491']
# ['Q765633']
# ['Q571822']
# ['Q9671', 'Q169898']
# ['Q45']
# ['Q47774']
# ['Q913643']
# ['Q16320']
# ['Q2337']
# ['Q83459']
# ['Q36']
# ['Q106807']
# ['Q167551']
# ['Q326499']
# ['Q2981']
# ['Q145']
# ['Q21127485']
# ['Q38']
# ['Q15720844']
# ['Q748296']
# ['Q181678']
# ['Q4925477']
# ['Q155874']
# ['Q215548']
# ['Q140686', 'Q218295', 'Q842386', 'Q4109060', 'Q4127082', 'Q4399975', 'Q14805701', 'Q27494237', 'Q38715304', 'Q38715670', 'Q38715852']
# ['Q193018']
# ['Q202040']
# ['Q50546603']
# ['Q5254470']
# ['Q232']
# ['Q898795']
# ['Q41466']
# ['Q1615333', 'Q41795540']
# ['Q42267']
# ['Q271934']
# ['Q1875']
# ['Q18552177']
# ['Q29']
# ['Q1978556']
# ['Q57327']
# ['Q7205']
# ['Q673075']
# ['Q1417705']
# ['Q96', 'Q115', 'Q774', 'Q800']
# ['Q239']
# ['Q33244']
# ['Q926']
# ['Q2723928']
# ['Q645719']
# ['Q810']
# ['Q47064', 'Q82955']
# ['Q1891']
# ['Q159']
# ['Q840829', 'Q2359372']
# ['Q208588']
# ['Q61']
# ['Q902320']
# ['Q7604']
# ['Q3519259']
# ['Q1741']
# ['Q1761']
# ['Q818467']
# ['Q210287']
# ['Q182059']
# ['Q63991914']
# ['Q2333']
# ['Q35064']
# ['Q34']
# ['Q627508']
# ['Q18502']
# ['Q46']
# ['Q46', 'Q48']
# ['Q656']
# ['Q4183061']
# ['Q169898', 'Q171329', 'Q171367', 'Q172721']
# ['Q2359372']
# ['Q2245347', 'Q2914850', 'Q72553200', 'Q72553961']
# ['Q17501806']
# ['Q21891843', 'Q23820229', 'Q84499835', 'Q84565071', 'Q84566351', 'Q84572475', 'Q84572977', 'Q84593853', 'Q84599401', 'Q84682501', 'Q84763814', 'Q84947682', 'Q174248', 'Q378120', 'Q580728', 'Q600063', 'Q628212', 'Q662985', 'Q693350', 'Q744598', 'Q748211', 'Q753219', 'Q753289', 'Q753292', 'Q840751', 'Q868618', 'Q942842', 'Q1013032', 'Q1013035', 'Q1624461', 'Q1734030', 'Q1810336', 'Q1811143', 'Q1821473', 'Q1822800', 'Q1963689', 'Q1969345', 'Q1987157', 'Q1996280', 'Q2003486', 'Q2041885', 'Q2048241', 'Q2061921', 'Q2078708', 'Q2216373', 'Q2219104', 'Q2297365', 'Q2317527', 'Q2320562', 'Q2331979', 'Q2403918', 'Q2440414', 'Q2442419', 'Q2446033', 'Q2456160', 'Q2460331', 'Q2467285', 'Q2499127', 'Q2501433', 'Q2533951', 'Q2580968', 'Q2612318', 'Q2623877', 'Q2638290', 'Q2661930', 'Q2689681', 'Q2693443', 'Q2709316', 'Q2717469', 'Q2782104', 'Q2786011', 'Q2795720', 'Q2834321', 'Q3176913', 'Q3489924', 'Q3489932', 'Q3489935', 'Q3490214', 'Q3490254', 'Q3490377', 'Q3490395', 'Q3490530', 'Q3490542', 'Q3490548', 'Q3490702', 'Q3497283', 'Q3499350', 'Q3499380', 'Q3499395', 'Q3499402', 'Q3499406', 'Q3509023', 'Q3509048', 'Q3509354', 'Q3509373', 'Q3509425', 'Q3509446', 'Q3509457', 'Q3509657', 'Q3509772', 'Q3509780', 'Q3509815', 'Q3509834', 'Q3563089', 'Q3563100', 'Q3563133', 'Q3563146', 'Q3563211', 'Q3563232', 'Q3564567', 'Q3566327', 'Q3566606']
# ['Q13641190']
# ['Q2084341', 'Q3273932', 'Q4252909', 'Q4262671']
# ['Q612907', 'Q654471', 'Q762844', 'Q1703180', 'Q1967942', 'Q1992013', 'Q1992153', 'Q1992181', 'Q2268261', 'Q3853593', 'Q3885141', 'Q4188115', 'Q4240311', 'Q4286712', 'Q4286829', 'Q4286849', 'Q4286882', 'Q4286937', 'Q4286990', 'Q4287015', 'Q4287082', 'Q4287097', 'Q4287144', 'Q4375455', 'Q4375533', 'Q12756735', 'Q16481642', 'Q16485587', 'Q18080427', 'Q18080429', 'Q18080612', 'Q19399024', 'Q19910703', 'Q21644047', 'Q24932811', 'Q25394795', 'Q57316823', 'Q95000245']
# ['Q21', 'Q22', 'Q25', 'Q26']
# ['Q20183']
# ['Q4151339', 'Q17287317', 'Q17287320', 'Q17287321']
# ['Q165503']
# ['Q28835', 'Q1275243']
# ['Q1396852']
# ['Q70498154']
# ['Q15288']
# ['Q1444', 'Q5994', 'Q8355', 'Q80284', 'Q81982', 'Q191823', 'Q281460', 'Q1521313']
# ['Q10478']
# ['Q4480733']
# ['Q202243']
# ['Q204752']
# ['Q15', 'Q48']
# ['Q27621', 'Q1978570', 'Q2387574', 'Q2495829', 'Q4525174', 'Q4534839', 'Q27430017']
# ['Q90']
# ['Q1982087']
# ['Q239', 'Q12800833']
# ['Q250', 'Q3966', 'Q5300', 'Q7397', 'Q9143', 'Q183484', 'Q2384798']
# ['Q43421']
# ['Q46', 'Q48']
# ['Q5492408']
# ['Q3964988']
# ['Q579431', 'Q2000835']
# ['Q665105']
# ['Q184437']
# ['Q190543']
# ['Q55766251']
# ['Q72614', 'Q104161', 'Q1384655', 'Q2721194']
# ['Q4315520']
# ['Q49481']
# ['Q213067']
# ['Q188', 'Q1860', 'Q7737', 'Q9027']
# ['Q79082']
# ['Q18']
# ['Q46']
# ['Q8338', 'Q202027', 'Q17172850']
# ['Q739', 'Q8965', 'Q199821', 'Q232564', 'Q1055848', 'Q3591854']
# ['Q902', 'Q330158', 'Q842931', 'Q1850485', 'Q2347909']
# ['Q28']
# ['Q162533']
# ['Q48']
# ['Q847']
# ['Q485176']
# ['Q157443', 'Q192881', 'Q319221', 'Q471839', 'Q761469', 'Q2973181', 'Q20443008']
# ['Q98']
# ['Q37068']
# ['Q37853']
# ['Q54111', 'Q170292']
# ['Q332342', 'Q7744473']
# ['Q13394']
# ['Q324867']
# ['Q4411519']
# ['Q486860']
# ['Q656']
# ['Q1218', 'Q187702', 'Q540882', 'Q1494672', 'Q2280628', 'Q7818625']
# ['Q1332307']
# ['Q210398']
# ['Q8261', 'Q128758', 'Q474090']
# ['Q126399', 'Q621364', 'Q984047', 'Q2924461']
# ['Q23633']
# ['Q126399', 'Q2924461', 'Q3011161', 'Q31197934']
# ['Q1200552', 'Q17343562', 'Q18155354', 'Q22807052']
# ['Q13641190']
# ['Q1589009']
# ['Q75', 'Q880371', 'Q56611700']
# ['Q6581097']
# ['Q675765', 'Q845981', 'Q3984081']
# ['Q1506552', 'Q1938341']
# ['Q27621', 'Q322964', 'Q323681']
# ['Q5994', 'Q8355']
# ['Q165503']
# ['Q27621', 'Q1978570', 'Q2387574', 'Q2495829', 'Q4525174', 'Q4534839', 'Q27430017']
# ['Q5064', 'Q12025', 'Q201873', 'Q207875', 'Q231390', 'Q586421']
# ['Q159909', 'Q14906020']
# ['Q299687']
# ['Q124018']
# ['Q778243']
# ['Q158314']
# ['Q62843', 'Q92743']
# ['Q8743', 'Q315422']
# ['Q76468']
# ['Q34286', 'Q77124', 'Q273314', 'Q318449']
# ['Q133544']
# ['Q4143870']
# ['Q552732']
# ['Q5673']
# ['Q4069095', 'Q4321371']
# ['Q380156', 'Q1395520']
# ['Q4934', 'Q92764']
# ['Q19837', 'Q332591', 'Q483382']
# ['Q7738', 'Q12548', 'Q27306', 'Q33296', 'Q34266', 'Q45670', 'Q68518', 'Q70972', 'Q80702', 'Q127318', 'Q131706', 'Q131981', 'Q153136', 'Q156199', 'Q161885', 'Q168651', 'Q170604', 'Q215443', 'Q215530', 'Q256961', 'Q258532', 'Q310650', 'Q318806', 'Q706018', 'Q830084', 'Q4083686']
# ['Q299687']
# ['Q29637']
# ['Q739711', 'Q1799063']
# ['Q75079']
# ['Q2628071']
# ['Q152293']
# ['Q79965', 'Q170770', 'Q1483495', 'Q4318679']
# ['Q76754', 'Q186203', 'Q4349082']
# ['Q26068']
# ['Q22890', 'Q23666', 'Q38272']
# ['Q76925']
# ['Q76925']
# ['Q538']
# ['Q258896']
# ['Q7603']
# ['Q233282']
# ['Q21', 'Q145']
# ['Q380252']
# ['Q42042', 'Q48362']
# ['Q3333484']
# ['Q25624', 'Q193026', 'Q1347099', 'Q1377980', 'Q2217063']
# ['Q785828']
# ['Q1065', 'Q4230', 'Q4264', 'Q7809', 'Q7817', 'Q7825', 'Q8475', 'Q17495', 'Q19771', 'Q47488', 'Q47539', 'Q123209', 'Q123759', 'Q151991', 'Q182500', 'Q191384', 'Q243630', 'Q340195', 'Q467938', 'Q471690', 'Q499151', 'Q535086', 'Q602399', 'Q605595', 'Q607301', 'Q656801', 'Q827525', 'Q838116', 'Q842490', 'Q943105', 'Q1025959', 'Q1043527', 'Q1045401', 'Q1072120', 'Q1480793', 'Q1484463', 'Q1570993', 'Q2836400', 'Q3369762', 'Q5611262', 'Q10283557']
# ['Q9448']
# ['Q41']
# ['Q258748']
# ['Q1781702']
# ['Q260542']
# ['Q49', 'Q538']
# ['Q37068']
# ['Q7291']
# ['Q2245347', 'Q2914850', 'Q72553200', 'Q72553961']
# ['Q2359372']
# ['Q15804']
# ['Q1256223']
# ['Q649', 'Q656', 'Q891', 'Q900', 'Q1874', 'Q5332', 'Q5337', 'Q5540', 'Q5627', 'Q19566', 'Q21197', 'Q156648', 'Q4092262', 'Q4536541', 'Q4538749']
# ['Q1130019']
# ['Q97']
# ['Q33629']
# ['Q24826']
# ['Q3426']
# ['Q1130019']
# ['Q1457437']
# ['Q649']
# ['Q1902692']
# ['Q586']
# ['Q649']
# ['Q5776']
# ['Q133838']
# ['Q174097']
# ['Q34433', 'Q1643454']
# ['Q3630']
# ['Q5994']
# ['Q1990094']
# ['Q4460646']
# ['Q1422', 'Q8682', 'Q18656', 'Q75729', 'Q267245', 'Q1630430', 'Q1772776', 'Q3590754', 'Q3590758', 'Q21079208']
# ['Q59488']
# ['Q133602']
# ['Q81589', 'Q645968']
# ['Q156255']
# ['Q242446']
# ['Q126399', 'Q2924461']
# ['Q159846', 'Q367466']
# ['Q2914786', 'Q4444575']
# ['Q126399', 'Q622668', 'Q3011161', 'Q31197934']
# ['Q2628487']
# ['Q141336']
# ['Q95', 'Q20800404']
# ['Q269792']
# ['Q127552', 'Q191224']
# ['Q20800404']
# ['Q84']
# ['Q16869', 'Q182009']
# ['Q1533']
# ['Q1957']
# ['Q1858']
# ['Q1353', 'Q11739', 'Q42941', 'Q179046', 'Q3242297']
# ['Q2184', 'Q2895', 'Q130229', 'Q130276', 'Q130280', 'Q131337', 'Q132856', 'Q133356', 'Q168811', 'Q170895', 'Q173761', 'Q186888', 'Q192180', 'Q199707', 'Q199711', 'Q484578', 'Q545205']
# ['Q93728', 'Q178473', 'Q185493', 'Q207826', 'Q208167', 'Q278798', 'Q337463', 'Q465316', 'Q530008', 'Q1069798', 'Q1081449', 'Q1710776', 'Q2297431', 'Q2634074', 'Q2760953', 'Q4137459', 'Q4286836', 'Q4335954', 'Q21292820', 'Q59351315', 'Q60130697', 'Q63975126']
# ['Q37922', 'Q278798', 'Q603631', 'Q695106', 'Q950604', 'Q1026769', 'Q1081503', 'Q1340199', 'Q18200478']
# ['Q475482', 'Q1463070']
# ['Q152951']
# ['Q152951']
# ['Q493898']
# ['Q172326']
# ['Q8355', 'Q81982', 'Q281460']
# ['Q27911']
# ['Q31687']
# ['Q27914']
# ['Q1438774']
# ['Q45700']
# ['Q1425861', 'Q7268181']
# ['Q186506']
# ['Q379053']
# ['Q180729', 'Q181951', 'Q1059510', 'Q1277249', 'Q2494846', 'Q4862955']
# ['Q28989']
# ['Q9268']
# ['Q432', 'Q5043']
# ['Q1394287']
# ['Q2498026']
# ['Q23759071']
# ['Q345']
# ['Q7041639']
# ['Q95', 'Q20800404']
# ['Q1966985']
# ['Q1744']
# ['Q377', 'Q191480']
# ['Q42511']
# ['Q15151625']
# ['Q15151625']
# ['Q4069095', 'Q4321371', 'Q4360695']
# ['Q19837', 'Q332591', 'Q483382']
# ['Q40224', 'Q57098', 'Q70788']
# ['Q5284', 'Q162005']
# ['Q40224', 'Q57098', 'Q70788']
# ['Q44412']
# ['Q37064']
# ['Q50224531']
# ['Q3140459']
# ['Q1060165']
# ['Q2283', 'Q1129295']
# ['Q4132607']
# ['Q195719']
# ['Q42574']
# ['Q4934', 'Q92764']
# ['Q76368']
# ['Q4419809', 'Q4498457']
# ['Q929273', 'Q929285', 'Q2071256', 'Q16253333', 'Q57022061']
# ['Q15072147']
# ['Q315188']
# ['Q191598']
# ['Q97']
# ['Q1406', 'Q5014725', 'Q13361286', 'Q64513817']
# ['Q1406', 'Q5014725', 'Q13361286']
# ['Q280658']
# ['Q280658', 'Q8025128']
# ['Q3542']
# ['Q15243', 'Q203462']
# ['Q2160']
# ['Q19686', 'Q19914']
# ['Q166162']
# ['Q1457453']
# ['Q4320732']
# ['Q166162']
# ['Q13199', 'Q15087', 'Q33754', 'Q387066']
# ['Q80284']
# ['Q31561', 'Q79838', 'Q178389', 'Q4501563', 'Q17172850']
# ['Q8343']
# ['Q3238057', 'Q13785927']
# ['Q5710', 'Q809806', 'Q1092754', 'Q1390649', 'Q4479125', 'Q4479136', 'Q15190285']
# ['Q408', 'Q3258', 'Q15577']
# ['Q980', 'Q10544', 'Q10562']
# ['Q1019', 'Q489821', 'Q5501842']
# ['Q225', 'Q11196', 'Q11198', 'Q18276', 'Q208545', 'Q1274468', 'Q2055400']
# ['Q252', 'Q3757', 'Q523435']
# ['Q766', 'Q651453', 'Q2526023']
# ['Q424', 'Q1054184', 'Q3173090']
# ['Q40', 'Q12548', 'Q28513', 'Q42497', 'Q131964', 'Q153136', 'Q176495', 'Q268970', 'Q518101', 'Q699964', 'Q3624335', 'Q16056854']
# ['Q5446', 'Q788066', 'Q2391775', 'Q6671523', 'Q14558462', 'Q18055588']
# ['Q672', 'Q21815222']
# ['Q854']
# ['Q1008', 'Q845706']
# ['Q1368300']
# ['Q432']
# ['Q775909']
# ['Q4239246']
# ['Q1497']
# ['Q371828', 'Q1324152']
# ['Q207706']
# ['Q4218621']
# ['Q2280', 'Q173822', 'Q185700', 'Q188732', 'Q189822', 'Q191061', 'Q192959']
# ['Q5681011']
# ['Q16157447']
# ['Q361', 'Q2140994', 'Q4081756', 'Q4097857', 'Q4255538']
# ['Q9448']
# ['Q656', 'Q9248', 'Q155243', 'Q196388', 'Q1020157', 'Q4322358']
# ['Q917830']
# ['Q27621', 'Q2654435', 'Q4139211']
# ['Q973']
# ['Q1065', 'Q7184', 'Q7785', 'Q7809', 'Q7825', 'Q8475', 'Q17495', 'Q19771', 'Q37143', 'Q38130', 'Q41550', 'Q81299', 'Q123759', 'Q134102', 'Q170481', 'Q181574', 'Q188822', 'Q191384', 'Q233611', 'Q340195', 'Q376150', 'Q656801', 'Q674182', 'Q782942', 'Q826700', 'Q827525', 'Q842490', 'Q899770', 'Q1043527', 'Q1072120', 'Q1480793', 'Q1928989', 'Q2863003', 'Q3772571', 'Q3866537', 'Q4033111', 'Q4426267', 'Q5150848', 'Q5611262', 'Q7768229', 'Q7886981']
# ['Q167541']
# ['Q182165']
# ['Q76751']
# ['Q5284', 'Q162005']
# ['Q557305', 'Q861967']
# ['Q104898']
# ['Q58792', 'Q80919']
# ['Q1189073', 'Q6895015']
# ['Q182994']
# ['Q46']
# ['Q207591']
# ['Q10857409']
# ['Q782363']
# ['Q736587']
# ['Q649', 'Q656', 'Q1731', 'Q4079059', 'Q4471180']
# ['Q234460', 'Q1069725', 'Q1980247']
# ['Q3642350']
# ['Q101978']
# ['Q49542', 'Q79797', 'Q482942', 'Q1129737', 'Q10290517']
# ['Q19831455']
# ['Q372657', 'Q505275', 'Q22032185']
# ['Q134161', 'Q891723']
# ['Q75745', 'Q248756', 'Q785531', 'Q808176', 'Q854686', 'Q1009177', 'Q1054311', 'Q2090382', 'Q2462900', 'Q2921573', 'Q3017105', 'Q3196524', 'Q4074592', 'Q4081114', 'Q4222569', 'Q4246441', 'Q4375034', 'Q4408691', 'Q4424133', 'Q4427701', 'Q4460344', 'Q14915363', 'Q14915364', 'Q14915365', 'Q14915367', 'Q14915368', 'Q14915369', 'Q14915370', 'Q14915425', 'Q14915428', 'Q14915447', 'Q14915448', 'Q14915449', 'Q14915450', 'Q14915451', 'Q14915452', 'Q14915453', 'Q14915454', 'Q14915455', 'Q14915456', 'Q14915457', 'Q14915458', 'Q14915459', 'Q14915460', 'Q14915461', 'Q14915462', 'Q14915463', 'Q14915464', 'Q14915465', 'Q14915466', 'Q14915467', 'Q14915468', 'Q14915469', 'Q14915470', 'Q14915471', 'Q14915472', 'Q14915473', 'Q14915474', 'Q14915475', 'Q14915476', 'Q14915477', 'Q14915478', 'Q14915479', 'Q14915480', 'Q14915481', 'Q14915482', 'Q14915483', 'Q14915484', 'Q14915485', 'Q14915486', 'Q14915489', 'Q14915490', 'Q14943318', 'Q14943338', 'Q14943342', 'Q21036227', 'Q21036228', 'Q21036229', 'Q21036230', 'Q27679334', 'Q35267412']
# ['Q185493', 'Q208167', 'Q241821', 'Q278798', 'Q337463', 'Q530008', 'Q946626', 'Q1067644', 'Q1069798', 'Q1710776', 'Q2329480', 'Q2634074', 'Q4335936', 'Q4335954', 'Q4375624', 'Q21292820', 'Q56669004', 'Q60054123']
# ['Q41144', 'Q41146', 'Q43269', 'Q43271', 'Q130343', 'Q165582', 'Q170453', 'Q190687', 'Q190922', 'Q191164', 'Q191174', 'Q191186', 'Q201121', 'Q201137', 'Q202068', 'Q202071', 'Q202075', 'Q204876', 'Q205460', 'Q205776', 'Q205784', 'Q205796', 'Q205824', 'Q205843', 'Q492791']
# ['Q1085', 'Q46070', 'Q188373', 'Q188399', 'Q190550', 'Q190930', 'Q191091', 'Q192536', 'Q192697', 'Q192702', 'Q193266', 'Q193295', 'Q193307', 'Q193317']
# ['Q1490', 'Q15701', 'Q44843', 'Q47896', 'Q48326', 'Q71699', 'Q71707', 'Q80011', 'Q80434', 'Q81863', 'Q83273', 'Q120730', 'Q122723', 'Q123258', 'Q123376', 'Q125863', 'Q127264', 'Q127513', 'Q127877', 'Q128186', 'Q128196', 'Q129499', 'Q130290', 'Q130300', 'Q130308', 'Q131277', 'Q131281', 'Q131287', 'Q131314', 'Q131320', 'Q131358', 'Q132705', 'Q132720', 'Q132751', 'Q132929', 'Q132936', 'Q133879', 'Q133924', 'Q133935', 'Q134093', 'Q160420', 'Q160734', 'Q161454', 'Q169376', 'Q617375', 'Q766445', 'Q1037393']
# ['Q4156896']
# ['Q7325']
# ['Q6581097']
# ['Q5256775']
# ['Q10693']
# ['Q12482', 'Q44455', 'Q189088', 'Q1554323', 'Q1766038', 'Q1970172', 'Q2895315', 'Q4056286', 'Q4358367', 'Q5498822']
# ['Q928993']
# ['Q20818052']
# ['Q76754', 'Q186203', 'Q4349082']
# ['Q67186598']
# ['Q4035237']
# ['Q52410688']
# ['Q3772']
# ['Q4417863']
# ['Q60100']
# ['Q41602']
# ['Q217925', 'Q2873520']
# ['Q23898959']
# ['Q27621']
# ['Q1566', 'Q199344', 'Q736556']
# ['Q182994']
# ['Q2532727']
# ['Q65032731']
# ['Q47591', 'Q4520962']
# ['Q11297']
# ['Q1370', 'Q523606', 'Q5425102']
# ['Q3279650']
# ['Q6635', 'Q645924']
# ['Q11002', 'Q11254', 'Q41534', 'Q93189', 'Q815740', 'Q4739805', 'Q61503220']
# ['Q50407282']
# ['Q3739104']
# ['Q171558']
# ['Q3739104']
# ['Q3739104']
# ['Q337463']
# ['Q756727', 'Q2747456']
# ['Q202009', 'Q918052', 'Q1167442', 'Q1756055', 'Q3163406']
# ['Q54111']
# ['Q11366', 'Q188450', 'Q484641']
# ['Q3273722']
# ['Q40855']
# ['Q73801', 'Q308913', 'Q611508', 'Q735267', 'Q1046593', 'Q1202130', 'Q2080076', 'Q2469781']
# ['Q157802']
# ['Q4204467']
# ['Q483654']
# ['Q483654', 'Q3333484']
# ['Q547869']
# ['Q27703517']
# ['Q892']
# ['Q1402143']
# ['Q128267', 'Q186350']
# ['Q3415248']
# ['Q4418820']
# ['Q1273278']
# ['Q42574']
# ['Q56008']
# ['Q187364']
# ['Q726105']
# ['Q56005']
# ['Q8877', 'Q6758800']
# ['Q56005']
# ['Q80135']
# ['Q33629']
# ['Q8025128']
# ['Q8025128']
# ['Q8025128']
# ['Q626']
# ['Q3447', 'Q27538353']
# ['Q38', 'Q1282', 'Q18288160']
# ['Q487003']
# ['Q228986']
# ['Q23746012']
# ['Q4301841']
# ['Q1711668']
# ['Q1768082']
# ['Q968028']
# ['Q192239']
# ['Q434841']
# ['Q157802']
# ['Q178473', 'Q185493', 'Q209896', 'Q478850', 'Q530008', 'Q534981', 'Q583881', 'Q612907', 'Q694401', 'Q728960', 'Q791135', 'Q1311063', 'Q1415232', 'Q1428575', 'Q1992013', 'Q2028781', 'Q2268261', 'Q2300740', 'Q2638119', 'Q2660844', 'Q4193236', 'Q9387384', 'Q18080427', 'Q18080429', 'Q18080431', 'Q21405589', 'Q89211387']
# ['Q97']
# ['Q27698']
# ['Q946428']
# ['Q33629']
# ['Q834621']
# ['Q4918']
# ['Q1247']
# ['Q17723']
# ['Q515869', 'Q25060578']
# ['Q44626']
# ['Q393864']
# ['Q4393561']
# ['Q847', 'Q5377', 'Q80131']
# ['Q134307', 'Q170571', 'Q191163']
# ['Q207591']
# ['Q130232', 'Q2254193', 'Q52207399']
# ['Q393']
# ['Q141336']
# ['Q5168']
# ['Q5222']
# ['Q900']
# ['Q33405']
# ['Q3114']
# ['Q748', 'Q427945', 'Q2279088']
# ['Q299687']
# ['Q49481']
# ['Q7349']
# ['Q49481']
# ['Q150', 'Q188', 'Q652', 'Q13199']
# ['Q188']
# ['Q23438']
# ['Q3616']
# ['Q174193']
# ['Q11399', 'Q187760', 'Q598929']
# ['Q8341', 'Q9759', 'Q203775', 'Q207378', 'Q1196752', 'Q1530455']
# ['Q37068']
# ['Q39427']
# ['Q37853']
# ['Q4992220']
# ['Q736587']
# ['Q112707']
# ['Q161179', 'Q177540', 'Q223197', 'Q583582', 'Q1055000']
# ['Q8261']
# ['Q189635']
# ['Q181754']
# ['Q181754']
# ['Q125168', 'Q1501888']
# ['Q1471878', 'Q3983766']
# ['Q31687']
# ['Q1218']
# ['Q1520']
# ['Q1930']
# ['Q28218']
# ['Q31687']
# ['Q2618625']
# ['Q739000']
# ['Q767288']
# ['Q51199', 'Q4228172']
# ['Q240150']
# ['Q8958']
# ['Q762']
# ['Q204138']
# ['Q2382967']
# ['Q358556']
# ['Q700540']
# ['Q314287']
# ['Q4768']
# ['Q1144905']
# ['Q9217']
# ['Q1568', 'Q1860']
# ['Q150', 'Q1860']
# ['Q150']
# ['Q1682', 'Q1684', 'Q161455', 'Q300875', 'Q316287', 'Q324404', 'Q562206', 'Q671428', 'Q694789', 'Q697916', 'Q821135', 'Q1532109', 'Q1538524', 'Q1646276', 'Q3908364']
# ['Q188', 'Q36668']
# ['Q5146', 'Q750553', 'Q3436689']
# ['Q13955']
# ['Q8821']
# ['Q809']
# ['Q37217']
# ['Q78994', 'Q858913', 'Q1025134', 'Q1088879', 'Q1194172', 'Q1347209', 'Q1985387', 'Q2234632', 'Q2372093', 'Q2914954']
# ['Q30']
# ['Q164800']
# ['Q80113', 'Q166713']
# ['Q217128']
# ['Q762']
# ['Q130777']
# ['Q76432', 'Q76745', 'Q76747']
# ['Q11570']
# top1 accuracy t5-3b-ssm-nqo RuBQ =  = 0.33811129848229343

# %%
torch.cuda.empty_cache()
